# %% [markdown]
# # Welcome to Lab: Similarity 🧍🧍‍♂️🧍‍♀️
#
# Many of you already know your tablemates in this class. However, have you ever wondered if there is someone **even more similar** to you than the people you already know?
#
# In this lab, we'll once again explore the dataset from the **Hello Survey** you've completed, utilizing some new Python skills to calculate your similarity to your peers!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant, your Course Aides, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Peng"
ca1_name = "Sophia"
ca2_name = "Qiran"
ca3_name = ""


# Say hello to each other!
# - Groups of 3 are ideal :)
# - However, groups of 2 or 4 are fine too!

# QOTD to ask your group: What's your favorite (or least favorite) building on campus? 
partner1_name = "shivani"
partner1_netid = ""
partner1_favbuilding = "bif"

partner2_name = "sofia"
partner2_netid = ""
partner2_favbuilding = "main library"

partner3_name = "tori"
partner3_netid = ""
partner3_favbuilding = "main library"

partne4_name = "jenny"
partner4_netid = ""
partner4_favbuilding = "cif"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Hello, Again

# %% [markdown]
# ## Load the Hello Dataset
# To find those most similar to you in this course, we're going to need the good old Hello Dataset.
#
#
# The "Hello Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/hello-sp24.csv
# ```
#
# Use Python to load this dataset into a DataFrame `df`:

# %%
import pandas as pd

# %%
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-sp24.csv")
df
# Out:
#             Name Section Do you like sweet or savory food?  \
# 0    Prof. Karle     AL1                            Savory
# 1     Prof. Wade     AL1                            Savory
# 2        Raymond     Y17                            Savory
# 3          Keiji     Y13                             Sweet
# 4            Ash     Y17                             Sweet
# ..           ...     ...                               ...
# 606     Jonathan     Y20                             Sweet
# 607          Leo     Y19                             Sweet
# 608       Afnaan     Y01                            Savory
# 609       Nathan     Y17                             Sweet
# 610        Ellyn     Y2-                            Savory
#
#     Do you use Windows or Mac?  \
# 0                          Mac
# 1                      Windows
# 2                      Windows
# 3                      Windows
# 4                      Windows
# ..                         ...
# 606                        Mac
# 607                        Mac
# 608                        Mac
# 609                    Windows
# 610                        Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 0                                         Near the end
# 1                                   When it's released
# 2                                   When it's released
# 3                                   When it's released
# 4                                   When it's released
# ..                                                 ...
# 606                                 When it's released
# 607                                       Near the end
# 608                                       Near the end
# 609                                 When it's released
# 610                                       Near the end
#
#     Are you a morning person?  \
# 0        NOT a Morning Person
# 1        NOT a Morning Person
# 2              Morning Person
# 3              Morning Person
# 4        NOT a Morning Person
# ..                        ...
# 606            Morning Person
# 607      NOT a Morning Person
# 608      NOT a Morning Person
# 609            Morning Person
# 610      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                   No
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 606                                                 No
# 607                                                 No
# 608                                                 No
# 609                                                 No
# 610                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 0                 Dairy                                     In-State
# 1                 Dairy                                     In-State
# 2                 Dairy                                     In-State
# 3                 Dairy                                     In-State
# 4                 Dairy                                     In-State
# ..                  ...                                          ...
# 606           Non-dairy                                 Out-of-State
# 607               Dairy                                 Out-of-State
# 608               Dairy                                     In-State
# 609               Dairy                                     In-State
# 610               Dairy                                 Out-of-State
#
#     Have you watched Saltburn?  ...  \
# 0                          Yes  ...
# 1                           No  ...
# 2                           No  ...
# 3                           No  ...
# 4                           No  ...
# ..                         ...  ...
# 606                         No  ...
# 607                         No  ...
# 608                        Yes  ...
# 609                         No  ...
# 610                        Yes  ...
#
#     Besides the US, what country would you like to live in?  \
# 0                                             Maldives
# 1                                              Sweeden
# 2                                                China
# 3                                                japan
# 4                                                Italy
# ..                                                 ...
# 606                                              Japan
# 607                                             Taiwan
# 608                                              India
# 609                                             Norway
# 610                                              Korea
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 0                              Za's                      Cafe Paradiso
# 1                    Shawarma Joint                      Siebel Center
# 2                       Kung Fu BBQ                               Home
# 3                              yogi                               main
# 4                      Burrito King                      Cafe Paradiso
# ..                              ...                                ...
# 606                             Evo                               Dorm
# 607                Northern Cuisine                            My dorm
# 608                    Bangkok Thai                                CIF
# 609                       McDonalds                            Library
# 610                 Northern Cusine                                CIF
#
#     What genre of music do you like the most?  \
# 0                                         pop
# 1                                         Pop
# 2                                         RnB
# 3                                         rap
# 4                                         Pop
# ..                                        ...
# 606                                       Pop
# 607                                     J-pop
# 608                                       pop
# 609                                     R & B
# 610                                       Rap
#
#     What is your favorite school subject?  \
# 0                                    math
# 1                                      CS
# 2                                 History
# 3                                    math
# 4                                   Stats
# ..                                    ...
# 606                               Finance
# 607                                  Math
# 608                               Science
# 609                        Social Studies
# 610                               English
#
#     What do you think is the hardest major at UIUC?  \
# 0                                  Computer Science
# 1                                  Computer Science
# 2                                               ECE
# 3                                          pre med
# 4                                       Engineering
# ..                                              ...
# 606                                              EE
# 607                          Electrical Engineering
# 608                                              CS
# 609                            Computer Engineering
# 610                                        Comp Sci
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 0                         Taylor Swift                              instagram
# 1                         Taylor Swift                                YouTube
# 2                          Alan Walker                              Instagram
# 3                          post malone                                  insta
# 4           TAYLOR SWIFT!!!!!!!!!!!!!!                              Instagram
# ..                                 ...                                    ...
# 606                            Yoasobi                                   Line
# 607                Lilas Ikuta (Ikura)                               Facebook
# 608                              Drake                              Instagram
# 609                      Daniel Ceaser                              Instagram
# 610                        Don Toliver                                 Tiktok
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                           Code Names
# 1                                             Factorio
# 2                                            Minecraft
# 3                                      clash of clans
# 4                                              Pokemon
# ..                                                 ...
# 606                                            Genshin
# 607                                     Genshin Impact
# 608                                         Mario Kart
# 609                                           Fortnite
# 610                                      Hide and Seek
#
#     Where is your dream vacation spot?
# 0                             Maldives
# 1                            Mountains
# 2                                China
# 3                               greece
# 4                              Itality
# ..                                 ...
# 606                             Europe
# 607                             Hawaii
# 608                               Bali
# 609                      Venice, Italy
# 610                        Switzerland
#
# [611 rows x 133 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert("df" in vars()), "This is not the Hello Dataset you're looking for. Check the URL."
assert("Dairy or non-dairy?" in df), "This is not the Hello Dataset you're looking for. Check the URL."
assert(len(df) >= 611), "This is not the Hello Dataset you're looking for. Check the URL."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Finding Yourself
# Before finding people you are **similar to**, you have to find **yourself** - literally!
#
# ### Puzzle 1.1: Your Row
# In the following cell, write the Python code to create a **new** DataFrame with only yourself, named `df_me`:
#
# *Note: if you cannot find yourself in the Hello Dataset, try adding a space after your name within the string. If you did not fill out the Hello Survey, pick one of your TAs, CAs, or Professor Karle or Wade! Their names are in the survey in the format of "TA Alex" or "Prof. Karle".*

# %%
df_me = df[(df.Name == "Liz") & (df.Section == "Y02")]
df_me
# Out:
#     Name Section Do you like sweet or savory food? Do you use Windows or Mac?  \
# 362  Liz     Y02                            Savory                        Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 362                                       Near the end
#
#     Are you a morning person?  \
# 362      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 362                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 362           Non-dairy                                     In-State
#
#     Have you watched Saltburn?  ...  \
# 362                        Yes  ...
#
#     Besides the US, what country would you like to live in?  \
# 362                                             Mexico
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 362                             NaN                    psych building
#
#     What genre of music do you like the most?  \
# 362                                       NaN
#
#     What is your favorite school subject?  \
# 362                                  Math
#
#     What do you think is the hardest major at UIUC?  \
# 362                                             NaN
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 362                                NaN                                    NaN
#
#     What is your favorite game to play (either video game or IRL)?  \
# 362                                                NaN
#
#     Where is your dream vacation spot?
# 362                                NaN
#
# [1 rows x 133 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 1.1 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert("df_me" in vars()), "Make sure you named the DataFrame with just you `df_me`."
assert("Dairy or non-dairy?" in df_me), "Your `df_me` should have the same columns as our `df`."
assert(len(df_me.columns.to_list()) == 133), "Your `df_me` should have the same number of columns as our original `df`."
assert(len(df_me) == 1), "Your `df_me` should only have one row: yourself."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Dataframe vs. Series
#
# Before we continue, a brief lesson on some of the datatypes you'll encounter in this class.
#
# In `pandas`, there are three data structures we will be using, two of which you have already seen:
#
# - A **DataFrame** is similar to an Excel sheet. It contains zero or more rows and zero or more columns. It can contain up to an unlimited number of rows and columns and is the basic data structure we've worked with from the start of this course
#
# - A **GroupBy** is a grouping of rows within a DataFrame. This "three dimensional data" requires us to use `agg` to reduce it back down to a DataFrame - which you've been doing in homeworks and labs thus far!
#
# - A **Series** is a single row with zero or more values (columns). You can think of a DataFrame as a collection of **Series** objects. When we deal with a single row, we will usually want to deal with a **Series** instead of a **one row DataFrame**
#
# In this lab, we will learn how to convert from a **one row DataFrame** to a **Series**, but here's a quick rundown on how to convert from types:

# %% [markdown]
# ### Converting Types
#
# The `pandas` library makes it easy to convert between a **Series**, **DataFrame**, and **GroupBy**.
#
# - From a **Series** (`row`) to a **DataFrame**:
#     - `row.to_frame()`
# - From a **DataFrame** (`df`) to a **GroupBy**:
#     - `df.groupby('columnName')` -- (You know this already!)
# - From a **GroupBy** (`group`) to a **DataFrame**:
#     - `group.agg( function )` -- (You know this already!)
# - From a **DataFrame** (`df`) to a **Series**:
#     - `df.iloc[0]`, if the DataFrame has one row
#
# See this guide, https://discovery.cs.illinois.edu/guides/DataFrame-Fundamentals/dataframe-loc-vs-iloc/, for more information about `iloc[]`.

# %% [markdown]
# ### Puzzle 1.2: Transform your row into a Series
# Using the correct function from above, **transform** the `df_me` row containing only you from a **one-row DataFrame** into a **Series**.
#
# Make sure the Series is named `my_row` (this will match up with code we provide you with later):

# %%
my_row = df_me.iloc[0]
my_row
# Out:
# Name                                                                          Liz
# Section                                                                       Y02
# Do you like sweet or savory food?                                          Savory
# Do you use Windows or Mac?                                                    Mac
# Do you like doing your homework when it's released or in the end?    Near the end
#                                                                          ...
# What do you think is the hardest major at UIUC?                               NaN
# Who is your favorite music artist?                                            NaN
# What's your favorite social media app?                                        NaN
# What is your favorite game to play (either video game or IRL)?                NaN
# Where is your dream vacation spot?                                            NaN
# Name: 362, Length: 133, dtype: object

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 1.2 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('my_row' in vars()), "Your series should be named `my_row`."
assert(type(my_row) == pd.core.series.Series), "Make sure you've correctly converted your one-row DataFrame into a Series..."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Choosing Your Columns

# %% [markdown]
# Before we begin, we have to think about our approach to finding your DISCOVERY twin.
#
# You may have noticed our Hello Dataset has **more than 100 questions**. Instead of finding the most similar person to you using **every question**, we'll pick out a few questions to analyze.
#
# **But first, we need to revisit the questions.**
#
# Recall the function `df.columns.tolist()`. To recap, this command will list **all of the columns** (in this case, our questions) in a DataFrame.
#
#  Use `df.columns.tolist()` in the cell below.
#
# You will likely see the message: Output exceeds the __size limit__. Open the full output data __in a text editor__.
#
# If you do, click the **in a text editor** link to open the whole list in a new tab of VSCode.

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Section',
#  'Do you like sweet or savory food?',
#  'Do you use Windows or Mac?',
#  "Do you like doing your homework when it's released or in the end?",
#  'Are you a morning person?',
#  'Are you following the data science duo on Instagram? @datascienceduo',
#  'Dairy or non-dairy?',
#  'Are you an In-State or Out-of-State student?',
#  'Have you watched Saltburn?',
#  "In the last lecture, did you sit on the left side or the right of the lecture room (if you're facing Karle and Wade)?",
#  'KAMS (Key Axioms in Mathematical Statistics) or LION (Linearly Independent Orthogonal Nullspaces)',
#  'Cool Ranch Doritos or Nacho Cheese Doritos? ',
#  'Do you like math or not?',
#  'Chocolate or Vanilla Ice Cream?',
#  'Flip a coin, is it heads or tails?',
#  'Did you live in the six-pack/IKE your freshman year?',
#  'Do you prefer pizza or burgers?',
#  'Are you an introvert or extrovert?',
#  'Do you prefer coffee or tea?',
#  'Check the time -- is it even or odd?',
#  'Do you prefer waffles or pancakes?',
#  'Do you prefer to wear dark colors or light colors?',
#  'What came first, the chicken or the egg?',
#  'Do you prefer Taylor Swift or Beyoncé?',
#  'Do you prefer shows or movies?',
#  'Are you a Swiftie?',
#  'Is water wet?',
#  'Do you like pineapple on pizza?',
#  'Do you prefer Home Alone 1 or Home Alone 2?',
#  'Do you prefer salty or sweet snacks?',
#  'Do you think there are more doors or wheels in the world?',
#  'Do you prefer summer or winter?',
#  'Would you rather the super power of invisibility or of reading minds?',
#  'Did you go to DISCOVERY on Friday?',
#  'Out of these 2 numbers which one do you like more? 239,238,134,821 or 239,238,124,821?',
#  'Is your major in the college of LAS?',
#  'Are you from the greater Chicagoland area?',
#  'Do you have a pet?',
#  'Did you watch SpongeBob growing up?',
#  'Is this your first year in college?',
#  'What is scarier: Snakes or Spiders?',
#  'Pick one A or B?',
#  'American Football or Basketball?',
#  'Are you male?',
#  'Do you like Barbie or Oppenheimer more?',
#  'Do you prefer Spring or Fall?',
#  'McDonalds or Burger King?',
#  'What type of weather do you prefer, hot or cold?',
#  'Do you prefer Pop or Hip-Hop music?',
#  'Is DISCOVERY hard?',
#  'What is your favorite baseball team?',
#  'Are all of your class buildings on the main quad?',
#  'Do you prefer red or blue?',
#  'Do you prefer Dr. Pepper or Pepsi?',
#  'Coke or Pepsi? ',
#  'Does your UIN end in an even or odd number?',
#  'Do you prefer eating chicken or beef?',
#  'Have you attend a football game in UIUC?',
#  'Do you like breakfast or lunch better?',
#  'Which number do you like more, 3 or 5?',
#  'Is DISCOVERY required for you?',
#  'Do you prefer Ketchup or Mustard?',
#  'Statistics or Computer Science',
#  'Is the dress debate from 2015 blue/black or white/gold?  (Search "the dress" to find the picture if you don\'t remember it!)',
#  'Do you prefer the color black or white?',
#  'Do you have a birthday in the first 6 month or the last 6 months?',
#  'Do you prefer spicy or sweet food?',
#  'Do you prefer tacos or burgers?',
#  'Would you rather drink coke or sprite for the rest of your life?',
#  'Do you prefer Christmas or Halloween?',
#  'Would you rather be able to forget your worst memory or be able to remember your best memory better?',
#  'Would you rather attend classes in the morning or in the afternoon?',
#  'Would you rather drive or be the passenger?',
#  'Are you a morning or night person?',
#  'Do you like iced or hot coffee?',
#  'Do you like your dad more or your mom more?',
#  'Do you prefer Italian food or Mexican food?',
#  'Do you have hair long hair?',
#  'Light mode or dark mode?',
#  'Do you prefer cool colors or warm colors?',
#  'Do you listen to music on your way to classes?',
#  'Do you have a job?',
#  'Is math red or blue?',
#  'Would you prefer group work or solo work?',
#  'Do you prefer pop or rap music?',
#  'Do you prefer math or english more?',
#  'Do you prefer coffee or milk? ',
#  'Do you like dogs?',
#  'Were you born in China?',
#  'Do you like exercising?',
#  'Are you a statistics major?',
#  'Where you born in 2004? ',
#  'Do you prefer books or movies?',
#  'Do you prefer pasta or pizza?',
#  'Is your weekly STAT107 lab session before or after 10:55 am on Thursday?',
#  'Are you in Gies or trying to get into Gies?',
#  'Dark Chocolate or Milk Chocolate?',
#  'Starbucks or Dunkin?',
#  'Do you live a dorm?',
#  'Do you prefer apple juice or orange juice?',
#  'Do you like ice cream in winter?',
#  'Do you sleep more than 7 hours a night?',
#  'Do you need a prescription to see?',
#  'Do you play games?',
#  'Apples or pears?',
#  'Do you plan to double major?',
#  'Are you an international student or a domestic student?',
#  'Do you prefer to sit in the front or the back of a class?',
#  'Do you prefer Nike or Adidas?',
#  'Do you take the bus to class?',
#  'Do you prefer in-person or online classes? ',
#  'Do you prefer the zoo or the aquarium?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking?',
#  'How many hours do you sleep in a night?',
#  'How many siblings do you have?',
#  'Pick a number between 1 and 10. ',
#  'What is your shoe size (US size)?',
#  'How many cups (8 oz.) of water do you drink a day?',
#  'From 1 to 10, how happy are you right now?',
#  'How many people is the ideal number of people at a party?',
#  'What is your phone battery percentage currently at?',
#  'Besides the US, what country would you like to live in?',
#  'Favorite on campus restaurant? ',
#  'Favorite place to study on campus?',
#  'What genre of music do you like the most?',
#  'What is your favorite school subject?',
#  'What do you think is the hardest major at UIUC?',
#  'Who is your favorite music artist?',
#  "What's your favorite social media app?",
#  'What is your favorite game to play (either video game or IRL)?',
#  'Where is your dream vacation spot?']

# %% [markdown]
# ### Puzzle 1.3: Choosing Your Columns
# From the above list of **columns** (questions), choose **at least 12 questions** to work with moving forward. Please use **only questions with binary answers** for this part of the analysis :)
#
# These will be the questions used to **calculate your similarity** to other people in DISCOVERY! Feel free to include more if you'd like.
#
# Store them as a **list** of **strings** named `questions` in the Python cell below:

# %%
questions = [
  "Are you an introvert or extrovert?",
  'Do you have a job?',
  "Are you a Swiftie?",
  "Do you like pineapple on pizza?",
  'Are you male?',
  "Do you like dogs?",
  'Are you a statistics major?',
  'Do you take the bus to class?', 
  'Are you a morning person?', 
  'Have you watched Saltburn?', 
  'Are you following the data science duo on Instagram? @datascienceduo', 
  'Is water wet?'
]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 1.3 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('questions' in vars()), "Please name your list of questions `questions`."
assert(type(questions) == list and type(questions[0]) == str), "Make sure your `questions` variable is a list of strings."
assert(len(questions) >= 12), "Do you have at least 12 questions in your columns list?"
for q in questions:
   assert(q in df), "Double check that you've copied each question correctly. The question texts should match up EXACTLY with the output from `df.columns.to_list()`."
for q in questions:
   assert(len(df[q].value_counts()) == 2), "Make sure that you've only included questions with binary answers in your columns list."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Analysis: Question Choice
#
# **Q1: Explain why you chose the questions you did to evaluate similarity. Is there a question or questions you think that say more about someone than others?**

# %% [markdown]
# I chose the questions that I have strong opinons about and my likes. I think the questions that are more opinion based say more about someone than others.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 2: The Similarity Function

# %% [markdown]
# Now that we have chosen the **questions** we'd like to evaluate, it's time to create a **function** to calculate a similarity value for each person, or each row in `df`.
#
# In lecture, remember learning that a Python **function** takes an **input** in and **returns** a **value**.
#
# For this specific function, we will take a **row** and calculate a **similarity score** for that row.
#
# But first, **print your list of questions** using the Python cell below for reference:

# %%
questions
# Out:
# ['Are you an introvert or extrovert?',
#  'Do you have a job?',
#  'Are you a Swiftie?',
#  'Do you like pineapple on pizza?',
#  'Are you male?',
#  'Do you like dogs?',
#  'Are you a statistics major?',
#  'Do you take the bus to class?',
#  'Are you a morning person?',
#  'Have you watched Saltburn?',
#  'Are you following the data science duo on Instagram? @datascienceduo',
#  'Is water wet?']

# %% [markdown]
# ### Puzzle 2.1: The Similarity Function
# We have provided the basic outline for the `similarity` function below. Follow the **commented details** and **complete the function** using all of your questions below:

# %%
def similarity(row):
    # This function will keep track of a `score` of how similar two rows are with each other.
    # The score begins at zero and we will add to it every time a row matches.
    score = 0 

    # This if statement below checks to see if the `row` shares your choice between Coffee and Tea
    # - If the values are the same (==), we add one to the score.
    for q in questions:
        if row[q] == my_row[q]:
            score += 1
    

    # if row["Coffee or Tea?"] == my_row["Coffee or Tea?"]:
    #     score = score + 1

    # Repeat this syntax many times for EACH question (column) that you have chosen in your list
    # IMPORTANT: Make sure to keep your lines all at this same level of tabbing out from the start.    
    # ALSO: Delete or the replace the "Coffee or Tea?" question,
    #       (unless you've decided that is one of your evaluating questions). 

    # Finally, return the `score`.
    # ...this line (the return statement) should always be the LAST line. 
    return score

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 2.1 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert(similarity(my_row) == len(questions) or similarity(my_row) == my_row[questions].count()), "Ensure you've added all the questions from your list and ONLY questions from your list correctly to your similarity function."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 2.2: Applying the Similarity Function
# Now that you've properly defined the similarity function, we need to **apply** it to the rest of the Hello Dataset DataFrame so we can produce a **similarity score** for each person who took the survey!
#
# Luckily, `pandas` provides a useful function for our use case: `df.apply()`.
#
# Quick lesson: `df.apply(some_function)` applies a pre-defined function named `some_function` along an axis of your DataFrame.
#
# Because we want to run our `similarity` function on all **rows**, when you call `df.apply()`, ensure you use **`axis=1`**. This would look something like:
# ```
# df["score"] = df.apply(some_function, axis=1)
# ```
#
# Using the above explanation as reference, **add a column** named `Similarity Score` to your original DataFrame that contains the value after running your similarity function you defined earlier across all rows:

# %%
df["Similarity Score"] = df.apply(similarity, axis = 1)

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 2.2 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('Similarity Score' in df), "Make sure you've named and added the Similarity Score column to your original df."
assert(df['Similarity Score'].dtype == 'int64'), "Double check that you've called the similarity function correctly in your df.apply()."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Finding your Twin(s)

# %% [markdown]
# Your last column `Similarity Score` in `df` is now a metric (a measurement) of how **similar** you are to everyone else in the class, based on the **questions you've chosen**!
#
# Finally, we can do analytical Data Science!

# %% [markdown]
# ### Puzzle 3.1: Your Twin in 107
#
# Using the Python cell below, find the **person most similar to you in the entire course** (having the largest `Similarity Score`).
#
# Note that **you should be most similar to yourself** (you will always match yourself)! This is not the right answer. Find the person with the highest score ***aside from yourself***.

# %%
df.nlargest(2, "Similarity Score").iloc[[1]]
# Out:
#      Name Section Do you like sweet or savory food?  \
# 21  Lhaye     Y14                            Savory
#
#    Do you use Windows or Mac?  \
# 21                        Mac
#
#    Do you like doing your homework when it's released or in the end?  \
# 21                                 When it's released
#
#    Are you a morning person?  \
# 21      NOT a Morning Person
#
#    Are you following the data science duo on Instagram? @datascienceduo  \
# 21                                                 No
#
#    Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 21           Non-dairy                                     In-State
#
#    Have you watched Saltburn?  ... Favorite on campus restaurant?   \
# 21                        Yes  ...                      Basil Thai
#
#    Favorite place to study on campus?  \
# 21                      Main Library
#
#    What genre of music do you like the most?  \
# 21                                     Indie
#
#    What is your favorite school subject?  \
# 21                               Science
#
#    What do you think is the hardest major at UIUC?  \
# 21                          Aerospace Engineering
#
#    Who is your favorite music artist? What's your favorite social media app?  \
# 21                       Beabadoobee                                  Tiktok
#
#    What is your favorite game to play (either video game or IRL)?  \
# 21                                               Sims
#
#    Where is your dream vacation spot? Similarity Score
# 21                            Palawan               11
#
# [1 rows x 134 columns]

# %% [markdown]
# ### Analysis: True Twin?
#
# **Q2: If you picked twelve or more other questions to evaluate similarity, do you think you'd find a different twin in the course overall?**

# %% [markdown]
# It is possible that I could find a different person with similar answers because there are more questions to evaluate. There's also the possibility that because there is a larger pool of questions, there are less people that share the same answers as me because not everyone has the same answers.

# %% [markdown]
# ### Puzzle 3.2: Your Lab Twin
#
# Now, chances are your twin isn't in your lab section. Because we conveniently have our row, `Similarity Score` applied to the **entire** set of responses to the survey, we can create smaller DataFrames to answer more questions.
#
# We want to find the person most similar to you in **your lab section**, otherwise known as your lab twin! We can create a new DataFrame to answer this question.
#
# However, some of your CAs and TAs, who are part of your lab section, are in more than one lab section! Those who have multiple sections have `Y##, Y##...` in their Sections column. How can we create a DataFrame that includes the CAs and TAs who are in more than one lab section? Python saves the day again.
#
# #### **The `contains` Function**
# In Python, the `contains` function can be used to check if a specific **substring** is present in a **string**.
#
# This will come in handy for us, because we can see if `Y##` is in the **names** of any rows in our DataFrame.
#
# Using the `contains` function, create a **new DataFrame** with everyone in your lab section: `df_section`.
#
# Part of the statement has been completed for you to show you how to use `contains`. Complete it.
#
# *Note that we have to cast our `Name` column of `df` to a **string** by using `.str`.

# %%
df_section = df[(df['Section'].str.contains('Y02'))]
df_section
# Out:
#                 Name Section Do you like sweet or savory food?  \
# 5          CA Sophia     Y02                            Savory
# 6                Max     Y02                            Savory
# 13            Isaiah     Y02                             Sweet
# 79            Joseph     Y02                             Sweet
# 93            Clivia     Y02                             Sweet
# 130        CA Qiran      Y02                             Sweet
# 155            Sofia     Y02                             Sweet
# 192            Peter     Y02                            Savory
# 193            Suvid     Y02                            Savory
# 209             Luke     Y02                             Sweet
# 226              Amy     Y02                            Savory
# 296           Amogh      Y02                             Sweet
# 312              Om      Y02                            Savory
# 318            Tyler     Y02                            Savory
# 327         Jennifer     Y02                             Sweet
# 362              Liz     Y02                            Savory
# 398           Steven     Y02                            Savory
# 410           George     Y02                            Savory
# 418          Sanjana     Y02                            Savory
# 438          Shivani     Y02                             Sweet
# 446              mia     Y02                             Sweet
# 474             Josh     Y02                             Sweet
# 490              Sam     Y02                             Sweet
# 521            Julia     Y02                            Savory
# 524  Marc Quillin Jr     Y02                            Savory
# 537            Yifei     Y02                             Sweet
# 552             Ryan     Y02                            Savory
# 584          TA Peng     Y02                            Savory
# 597         Anushree     Y02                               NaN
#
#     Do you use Windows or Mac?  \
# 5                          Mac
# 6                      Windows
# 13                         Mac
# 79                         Mac
# 93                         Mac
# 130                        Mac
# 155                        Mac
# 192                        Mac
# 193                    Windows
# 209                        Mac
# 226                        Mac
# 296                    Windows
# 312                    Windows
# 318                    Windows
# 327                        Mac
# 362                        Mac
# 398                    Windows
# 410                    Windows
# 418                    Windows
# 438                        Mac
# 446                        Mac
# 474                        Mac
# 490                        Mac
# 521                    Windows
# 524                        Mac
# 537                    Windows
# 552                    Windows
# 584                    Windows
# 597                        NaN
#
#     Do you like doing your homework when it's released or in the end?  \
# 5                                   When it's released
# 6                                         Near the end
# 13                                  When it's released
# 79                                        Near the end
# 93                                        Near the end
# 130                                 When it's released
# 155                                 When it's released
# 192                                 When it's released
# 193                                 When it's released
# 209                                 When it's released
# 226                                 When it's released
# 296                                 When it's released
# 312                                 When it's released
# 318                                 When it's released
# 327                                 When it's released
# 362                                       Near the end
# 398                                 When it's released
# 410                                 When it's released
# 418                                 When it's released
# 438                                       Near the end
# 446                                 When it's released
# 474                                 When it's released
# 490                                       Near the end
# 521                                       Near the end
# 524                                       Near the end
# 537                                       Near the end
# 552                                 When it's released
# 584                                       Near the end
# 597                                       Near the end
#
#     Are you a morning person?  \
# 5              Morning Person
# 6        NOT a Morning Person
# 13       NOT a Morning Person
# 79       NOT a Morning Person
# 93       NOT a Morning Person
# 130            Morning Person
# 155      NOT a Morning Person
# 192      NOT a Morning Person
# 193      NOT a Morning Person
# 209      NOT a Morning Person
# 226      NOT a Morning Person
# 296      NOT a Morning Person
# 312            Morning Person
# 318      NOT a Morning Person
# 327      NOT a Morning Person
# 362      NOT a Morning Person
# 398      NOT a Morning Person
# 410      NOT a Morning Person
# 418      NOT a Morning Person
# 438      NOT a Morning Person
# 446            Morning Person
# 474            Morning Person
# 490      NOT a Morning Person
# 521      NOT a Morning Person
# 524            Morning Person
# 537      NOT a Morning Person
# 552      NOT a Morning Person
# 584      NOT a Morning Person
# 597      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 5                                                  Yes
# 6                                                  Yes
# 13                                                  No
# 79                                                  No
# 93                                                  No
# 130                                                Yes
# 155                                                 No
# 192                                                 No
# 193                                                 No
# 209                                                 No
# 226                                                 No
# 296                                                 No
# 312                                                 No
# 318                                                 No
# 327                                                 No
# 362                                                 No
# 398                                                 No
# 410                                                 No
# 418                                                 No
# 438                                                 No
# 446                                                 No
# 474                                                 No
# 490                                                 No
# 521                                                 No
# 524                                                 No
# 537                                                 No
# 552                                                Yes
# 584                                                 No
# 597                                                NaN
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 5             Non-dairy                                     In-State
# 6                 Dairy                                 Out-of-State
# 13                Dairy                                     In-State
# 79                Dairy                                     In-State
# 93            Non-dairy                                 Out-of-State
# 130               Dairy                                 Out-of-State
# 155               Dairy                                     In-State
# 192               Dairy                                     In-State
# 193               Dairy                                 Out-of-State
# 209               Dairy                                     In-State
# 226               Dairy                                     In-State
# 296               Dairy                                 Out-of-State
# 312               Dairy                                     In-State
# 318               Dairy                                     In-State
# 327               Dairy                                     In-State
# 362           Non-dairy                                     In-State
# 398               Dairy                                     In-State
# 410               Dairy                                     In-State
# 418               Dairy                                 Out-of-State
# 438               Dairy                                 Out-of-State
# 446               Dairy                                     In-State
# 474               Dairy                                     In-State
# 490               Dairy                                     In-State
# 521           Non-dairy                                     In-State
# 524           Non-dairy                                     In-State
# 537           Non-dairy                                 Out-of-State
# 552               Dairy                                     In-State
# 584               Dairy                                 Out-of-State
# 597                 NaN                                          NaN
#
#     Have you watched Saltburn?  ... Favorite on campus restaurant?   \
# 5                          Yes  ...                     thai fusion
# 6                           No  ...                        Chipotle
# 13                          No  ...                     Mcdonald’s
# 79                          No  ...              pho noodle station
# 93                          No  ...                      McDonald's
# 130                         No  ...                           Iken
# 155                         No  ...                midsummer lounge
# 192                         No  ...               Mid Summer Lounge
# 193                        Yes  ...                     Ambar India
# 209                        Yes  ...                        conrad's
# 226                        Yes  ...                    Bangkok Thai
# 296                         No  ...                  Shawarma Joint
# 312                         No  ...                           Nayas
# 318                         No  ...                        Cravings
# 327                         No  ...                           Canes
# 362                        Yes  ...                             NaN
# 398                         No  ...                   sushi ichiban
# 410                         No  ...                         Mia Zas
# 418                         No  ...                          Subway
# 438                        Yes  ...                 signature grill
# 446                         No  ...                            yogi
# 474                        Yes  ...                           Canes
# 490                         No  ...                        Mia Za's
# 521                         No  ...                        Mia Za's
# 524                        Yes  ...                        ChopStix
# 537                         No  ...                        Sushiman
# 552                        Yes  ...                        Chipotle
# 584                         No  ...                Northern Cuisine
# 597                        NaN  ...                    Burrito King
#
#     Favorite place to study on campus?  \
# 5                                  CIF
# 6                                 Home
# 13                             My room
# 79                                 cif
# 93                                home
# 130                                CIF
# 155                       main library
# 192                       ACES Library
# 193                           Grainger
# 209                             armory
# 226                    Espresso Royale
# 296                   Grainger Library
# 312                    Grainger libary
# 318                           My couch
# 327                             Union
# 362                    psych building
# 398                                BIF
# 410                                BIF
# 418                                CIF
# 438                           grainger
# 446                          i school
# 474                                BIF
# 490                                Bif
# 521             Lincoln Hall Courtyard
# 524                Engineering library
# 537                       Main library
# 552                             My bed
# 584                             office
# 597                           Grainger
#
#     What genre of music do you like the most?  \
# 5                                   pop/indie
# 6                                         Pop
# 13                                        Rap
# 79                                    Hip hop
# 93                                        pop
# 130                                   Country
# 155                                     indie
# 192                                       NaN
# 193                                       Pop
# 209                                psych rock
# 226                              Folk/Country
# 296                                       rap
# 312                                       Rap
# 318                                       Rap
# 327                               Latin music
# 362                                       NaN
# 398                                   country
# 410                                       Rap
# 418                                       Pop
# 438                                    hiphop
# 446                               indie, pop
# 474                                   Country
# 490                                       Pop
# 521                                     Metal
# 524                                   Hip-Hop
# 537                                 pop music
# 552                                     House
# 584                                       pop
# 597                                   Hip Hop
#
#     What is your favorite school subject?  \
# 5                                    Math
# 6                                   Stats
# 13                                  Stats
# 79                                   Math
# 93                                    ESL
# 130                              Science
# 155                                  math
# 192                                  Math
# 193                                    CS
# 209                                  math
# 226                               History
# 296                               english
# 312                   Information Science
# 318                            Philosophy
# 327                                  Math
# 362                                  Math
# 398                                   gym
# 410                               FINANCE
# 418                             Economics
# 438                               english
# 446                                  math
# 474                               Finance
# 490                                  Math
# 521                                   Art
# 524                            Calculus 2
# 537                                   art
# 552                                  Accy
# 584                                  math
# 597                               Science
#
#     What do you think is the hardest major at UIUC?  \
# 5                                              ECE
# 6                                           Physics
# 13                                         Comp Sci
# 79                          Electrical Engineering
# 93                                      Mathematics
# 130                                Computer Science
# 155                                computer science
# 192                             Nuclear Engineering
# 193                            Computer Engineering
# 209                                chem engineering
# 226                                              CS
# 296                            chemical engineering
# 312                                         Physics
# 318                          Electrical Engineering
# 327                                    Engineering
# 362                                             NaN
# 398                                computer science
# 410                                              CS
# 418                                              CS
# 438                            computer engineering
# 446                                              cs
# 474                                              CS
# 490                                Computer Science
# 521                                Computer Science
# 524                                Computer Science
# 537                                              CS
# 552                                Computer Science
# 584                                            math
# 597                           Chemical Engineering
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 5                      Phoebe Bridgers                              Instagram
# 6                             Coldplay                                WeChat
# 13                              J Cole                                Twitter
# 79                               Kanye                              Instagram
# 93                           TF family                                 Wechat
# 130                       Taylor Swift                                Discord
# 155                      daniel caesar                              pinterest
# 192                        Cody Carnes                               Snapchat
# 193                         Juice WRLD                              Instagram
# 209                         Pink Floyd                              instagram
# 226                         Noah Kahan                              Instagram
# 296                   Childish Gambino                              instagram
# 312                        The Weekend                                 Tiktok
# 318                         Mac Miller                              Instagram
# 327                          Bad Bunny                              Instagram
# 362                                NaN                                    NaN
# 398                        post malone                               snapchat
# 410                       Travis Scott                              Instagram
# 418                              Adele                              Instagram
# 438                              drake                                 tiktok
# 446                     don't have one                              instagram
# 474                         Zach Bryan                              Instagram
# 490                              Kanye                                Tik Tok
# 521                              BONES                               Snapchat
# 524                     Kendrick Lamar                                 TikTok
# 537                       Lana del ray                              Instagram
# 552                             Fisher                                Tik tok
# 584                     hall and oates                                 reddit
# 597                              Jcole                               SnapChat
#
#     What is your favorite game to play (either video game or IRL)?  \
# 5                                             Fortnite
# 6                                          Hearthstone
# 13                                          Basketball
# 79                                            Terraria
# 93                                             Genshin
# 130                                              Chess
# 155                                             sudoku
# 192                                          Minecraft
# 193                                           Valorant
# 209                                         basketball
# 226                                       Hungry Hippo
# 296                                           fortnite
# 312                                       Call of Duty
# 318                                            Valheim
# 327                                         Volleyball
# 362                                                NaN
# 398                                              gta 5
# 410                                         Basketball
# 418                                          Badminton
# 438                                             wordle
# 446                                            no game
# 474                                             Madden
# 490                                          Ping Pong
# 521                                          Minecraft
# 524                                             Skyrim
# 537                                The legend of Zelda
# 552                                               Chel
# 584                                          Cyberpunk
# 597                                       Clash Royale
#
#     Where is your dream vacation spot? Similarity Score
# 5                               Greece                5
# 6                             Maldives                4
# 13                              Brazil                4
# 79                              Hawaii                7
# 93                              Canada               10
# 130                            Hawaii                 5
# 155                             taiwan                9
# 192                               Maui                8
# 193                             Norway                9
# 209       probably somewhere in Canada                7
# 226                            Iceland                9
# 296                             london                8
# 312                            Greece                 8
# 318                             Norway                9
# 327                           Acapulco                9
# 362                                NaN               12
# 398                              spain                6
# 410                           Maldives                7
# 418                            Austria                8
# 438                             greece                7
# 446                            iceland                7
# 474                           Maldives                8
# 490                              Tokyo                7
# 521                               Bali                8
# 524                    Turks and cacos                8
# 537                              Italy               10
# 552                          Bora Bora               10
# 584                             Hawaii                6
# 597                            Iceland                3
#
# [29 rows x 134 columns]

# %% [markdown]
# ### Puzzle 3.3: Your Lab Twin!
#
# Similarly to Puzzle 3.1, find your lab section twin (the person in your lab section who has the **highest Similarity Score** to you).

# %%
df_section.nlargest(2, "Similarity Score").iloc[[1]]
# Out:
#       Name Section Do you like sweet or savory food?  \
# 93  Clivia     Y02                             Sweet
#
#    Do you use Windows or Mac?  \
# 93                        Mac
#
#    Do you like doing your homework when it's released or in the end?  \
# 93                                       Near the end
#
#    Are you a morning person?  \
# 93      NOT a Morning Person
#
#    Are you following the data science duo on Instagram? @datascienceduo  \
# 93                                                 No
#
#    Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 93           Non-dairy                                 Out-of-State
#
#    Have you watched Saltburn?  ... Favorite on campus restaurant?   \
# 93                         No  ...                      McDonald's
#
#    Favorite place to study on campus?  \
# 93                               home
#
#    What genre of music do you like the most?  \
# 93                                       pop
#
#    What is your favorite school subject?  \
# 93                                   ESL
#
#    What do you think is the hardest major at UIUC?  \
# 93                                     Mathematics
#
#    Who is your favorite music artist? What's your favorite social media app?  \
# 93                          TF family                                 Wechat
#
#    What is your favorite game to play (either video game or IRL)?  \
# 93                                            Genshin
#
#    Where is your dream vacation spot? Similarity Score
# 93                             Canada               10
#
# [1 rows x 134 columns]

# %% [markdown]
# #### **➡️ Right now, once you have that person, find them in lab!**<br>➡️ *(If they're not here, look for the next similar person.)*
#
# Help them get up to this point in the lab and let them find their DISCOVERY twin!  *(Are you twins of each other?)*
#
# ➡️ Once you are **BOTH** to this section, introduce yourself and your DISCOVERY lab section "twin" to your lab TA. <br>
# ➡️ Make sure you know what your "Similarity Score" to your twin is! <br>
# ➡️ If you do this introduction to your TA **in-person during your lab section, you will earn +1 EC**! :)
#
# Note that there may be ties in `Similarity Score` due to the usage of only parts of the dataset. If you're curious, you can go back and **add more questions** to your `questions` list and `similarity(row)` function, rerunning the code to have more evaluative similarity scores.

# %% [markdown]
# ### Puzzle 3.4: The Course Staff
# A lot of wonderful course staff work together to bring you all the content for Data Science Discovery.
#
# The course staff of 107 consists of the **Professors, TAs, and CAs**. As you saw in the previous parts, they've all completed the Hello Survey too!
#
# Their response under the `name` column is standardized and follows these formats:
# - `Prof. [Name]`,
# - `TA [Name]`, or
# - `CA [Name]`
#
# The `contains` function will come in handy for us once again, because we can see if `"CA "`, `"TA "`, or `"Prof. "` is in the **names** of any rows in our DataFrame.
#
# Using the `contains` function, create a **new DataFrame** with just the course staff: `df_staff`.
#
# Part of the statement has been completed for you to show you how to use `contains`. Complete it.
#
# *Note that we have to cast our `Name` column of `df` to a **string** by using `.str`.

# %%
df_staff = df[(df['Name'].str.contains('CA ')) + (df['Name'].str.contains('TA ')) + (df['Name'].str.contains('Prof. '))] 
df_staff
# IMPORTANT: Make sure you include a whitespace in "CA "" and "TA "" so that people with those
# #          letters in their name aren't included.  Whitespace matters! :)
# Out:
#              Name   Section Do you like sweet or savory food?  \
# 0     Prof. Karle       AL1                            Savory
# 1      Prof. Wade       AL1                            Savory
# 5       CA Sophia       Y02                            Savory
# 7       CA Alyssa       Y07                             Sweet
# 31         CA Ram       Y15                            Savory
# 32     CA Jackson         Y                            Savory
# 41      CA Lauren       Y18                            Savory
# 44      CA Gerald       Y09                            Savory
# 70     CA Kaitlyn       Y11                             Sweet
# 73        CA Lara       Y09                             Sweet
# 75        CA Evan       Y03                            Savory
# 77      TA Steven  Y04, Y19                             Sweet
# 86       CA Amaan       Y12                            Savory
# 109      CA Annie       Y20                            Savory
# 130     CA Qiran        Y02                             Sweet
# 137      CA Subbu       Y18                            Savory
# 144       CA Urvi       Y04                            Savory
# 146       TA Alex  Y03, Y20                             Sweet
# 160      CA Talia       Y13                             Sweet
# 164     CA Vikram   Y08 Y17                            Savory
# 175     CA Eliana       Y20                            Savory
# 189    CA Shannon       Y11                             Sweet
# 196    CA Sangjun       Y06                            Savory
# 204       CA Sri   Y01, Y19                            Savory
# 205      CA Bella       Y10                            Savory
# 229     CA Anagha       Y--                            Savory
# 231      CA Sneha       Y19                            Savory
# 236      CA Paige       Y10                             Sweet
# 249     CA Eeshan       Y03                            Savory
# 285      CA Helen       Y06                             Sweet
# 395        CA Mia       Y07                            Savory
# 427  CA Victoria        Y20                             Sweet
# 460       CA Soph       Y08                            Savory
# 466  TA Chenyang    Y05 Y15                            Savory
# 480  TA Evangelos  Y07, Y13                            Savory
# 554      CA Tyler       Y15                             Sweet
# 559        CA Jai  Y01, Y16                             Sweet
# 560       CA Sony  Y05, Y12                            Savory
# 569    TA Shuning  Y06, Y12                            Savory
# 570    CA Jessica  Y05, Y18                             Sweet
# 571        CA Xin       Y11                             Sweet
# 579       CA Jake       Y13                             Sweet
# 580      TA Omkar       Y14                             Sweet
# 581      TA Ridha  Y09, Y16                            Savory
# 582     TA Mukhil       Y01                            Savory
# 583     CA Anchal       Y04                            Savory
# 584       TA Peng       Y02                            Savory
# 585     CA Sophia       Y17                            Savory
# 586   CA Anushree       Y10                            Savory
# 587     CA Yuheng       Y16                            Savory
# 589      CA Subin       Y19                             Sweet
# 590     CA Areeba       Y14                             Sweet
# 592    TA Aakriti       Y08                             Sweet
#
#     Do you use Windows or Mac?  \
# 0                          Mac
# 1                      Windows
# 5                          Mac
# 7                          Mac
# 31                         Mac
# 32                         Mac
# 41                         Mac
# 44                         Mac
# 70                         Mac
# 73                     Windows
# 75                     Windows
# 77                     Windows
# 86                         Mac
# 109                        Mac
# 130                        Mac
# 137                    Windows
# 144                    Windows
# 146                        Mac
# 160                        Mac
# 164                        Mac
# 175                    Windows
# 189                        Mac
# 196                    Windows
# 204                        Mac
# 205                    Windows
# 229                        Mac
# 231                        Mac
# 236                    Windows
# 249                    Windows
# 285                    Windows
# 395                        Mac
# 427                    Windows
# 460                        Mac
# 466                    Windows
# 480                    Windows
# 554                    Windows
# 559                        Mac
# 560                        Mac
# 569                        Mac
# 570                        Mac
# 571                        Mac
# 579                        Mac
# 580                        Mac
# 581                        Mac
# 582                        Mac
# 583                        Mac
# 584                    Windows
# 585                        Mac
# 586                    Windows
# 587                        Mac
# 589                    Windows
# 590                    Windows
# 592                    Windows
#
#     Do you like doing your homework when it's released or in the end?  \
# 0                                         Near the end
# 1                                   When it's released
# 5                                   When it's released
# 7                                         Near the end
# 31                                        Near the end
# 32                                  When it's released
# 41                                  When it's released
# 44                                  When it's released
# 70                                  When it's released
# 73                                        Near the end
# 75                                  When it's released
# 77                                        Near the end
# 86                                  When it's released
# 109                                 When it's released
# 130                                 When it's released
# 137                                 When it's released
# 144                                       Near the end
# 146                                 When it's released
# 160                                 When it's released
# 164                                       Near the end
# 175                                       Near the end
# 189                                 When it's released
# 196                                 When it's released
# 204                                       Near the end
# 205                                 When it's released
# 229                                       Near the end
# 231                                 When it's released
# 236                                 When it's released
# 249                                 When it's released
# 285                                 When it's released
# 395                                       Near the end
# 427                                 When it's released
# 460                                       Near the end
# 466                                       Near the end
# 480                                 When it's released
# 554                                 When it's released
# 559                                       Near the end
# 560                                       Near the end
# 569                                       Near the end
# 570                                 When it's released
# 571                                       Near the end
# 579                                       Near the end
# 580                                       Near the end
# 581                                 When it's released
# 582                                       Near the end
# 583                                       Near the end
# 584                                       Near the end
# 585                                       Near the end
# 586                                       Near the end
# 587                                       Near the end
# 589                                       Near the end
# 590                                 When it's released
# 592                                 When it's released
#
#     Are you a morning person?  \
# 0        NOT a Morning Person
# 1        NOT a Morning Person
# 5              Morning Person
# 7              Morning Person
# 31             Morning Person
# 32             Morning Person
# 41             Morning Person
# 44       NOT a Morning Person
# 70       NOT a Morning Person
# 73       NOT a Morning Person
# 75       NOT a Morning Person
# 77       NOT a Morning Person
# 86             Morning Person
# 109      NOT a Morning Person
# 130            Morning Person
# 137            Morning Person
# 144      NOT a Morning Person
# 146            Morning Person
# 160      NOT a Morning Person
# 164      NOT a Morning Person
# 175      NOT a Morning Person
# 189      NOT a Morning Person
# 196      NOT a Morning Person
# 204      NOT a Morning Person
# 205            Morning Person
# 229      NOT a Morning Person
# 231      NOT a Morning Person
# 236            Morning Person
# 249            Morning Person
# 285            Morning Person
# 395      NOT a Morning Person
# 427      NOT a Morning Person
# 460            Morning Person
# 466      NOT a Morning Person
# 480            Morning Person
# 554      NOT a Morning Person
# 559      NOT a Morning Person
# 560            Morning Person
# 569      NOT a Morning Person
# 570      NOT a Morning Person
# 571            Morning Person
# 579            Morning Person
# 580      NOT a Morning Person
# 581            Morning Person
# 582            Morning Person
# 583      NOT a Morning Person
# 584      NOT a Morning Person
# 585      NOT a Morning Person
# 586            Morning Person
# 587      NOT a Morning Person
# 589      NOT a Morning Person
# 590            Morning Person
# 592      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 0                                                  Yes
# 1                                                  Yes
# 5                                                  Yes
# 7                                                  Yes
# 31                                                 Yes
# 32                                                 Yes
# 41                                                 Yes
# 44                                                 Yes
# 70                                                 Yes
# 73                                                 Yes
# 75                                                 Yes
# 77                                                  No
# 86                                                 Yes
# 109                                                 No
# 130                                                Yes
# 137                                                Yes
# 144                                                Yes
# 146                                                 No
# 160                                                Yes
# 164                                                Yes
# 175                                                Yes
# 189                                                 No
# 196                                                Yes
# 204                                                 No
# 205                                                Yes
# 229                                                Yes
# 231                                                Yes
# 236                                                Yes
# 249                                                Yes
# 285                                                Yes
# 395                                                Yes
# 427                                                Yes
# 460                                                Yes
# 466                                                 No
# 480                                                Yes
# 554                                                 No
# 559                                                Yes
# 560                                                Yes
# 569                                                 No
# 570                                                Yes
# 571                                                Yes
# 579                                                Yes
# 580                                                Yes
# 581                                                 No
# 582                                                 No
# 583                                                 No
# 584                                                 No
# 585                                                Yes
# 586                                                Yes
# 587                                                Yes
# 589                                                 No
# 590                                                Yes
# 592                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 0                 Dairy                                     In-State
# 1                 Dairy                                     In-State
# 5             Non-dairy                                     In-State
# 7             Non-dairy                                     In-State
# 31                Dairy                                 Out-of-State
# 32                Dairy                                     In-State
# 41                Dairy                                     In-State
# 44            Non-dairy                                     In-State
# 70                Dairy                                     In-State
# 73                Dairy                                     In-State
# 75                Dairy                                     In-State
# 77                Dairy                                 Out-of-State
# 86                Dairy                                 Out-of-State
# 109               Dairy                                 Out-of-State
# 130               Dairy                                 Out-of-State
# 137               Dairy                                     In-State
# 144               Dairy                                 Out-of-State
# 146               Dairy                                 Out-of-State
# 160           Non-dairy                                     In-State
# 164               Dairy                                     In-State
# 175           Non-dairy                                     In-State
# 189           Non-dairy                                     In-State
# 196           Non-dairy                                 Out-of-State
# 204           Non-dairy                                     In-State
# 205               Dairy                                     In-State
# 229               Dairy                                     In-State
# 231               Dairy                                 Out-of-State
# 236           Non-dairy                                     In-State
# 249               Dairy                                     In-State
# 285               Dairy                                 Out-of-State
# 395               Dairy                                     In-State
# 427               Dairy                                     In-State
# 460           Non-dairy                                     In-State
# 466               Dairy                                 Out-of-State
# 480               Dairy                                 Out-of-State
# 554           Non-dairy                                 Out-of-State
# 559           Non-dairy                                 Out-of-State
# 560               Dairy                                     In-State
# 569               Dairy                                 Out-of-State
# 570               Dairy                                 Out-of-State
# 571           Non-dairy                                 Out-of-State
# 579               Dairy                                     In-State
# 580               Dairy                                 Out-of-State
# 581               Dairy                                 Out-of-State
# 582               Dairy                                 Out-of-State
# 583               Dairy                                     In-State
# 584               Dairy                                 Out-of-State
# 585               Dairy                                     In-State
# 586               Dairy                                     In-State
# 587               Dairy                                 Out-of-State
# 589               Dairy                                 Out-of-State
# 590               Dairy                                 Out-of-State
# 592               Dairy                                 Out-of-State
#
#     Have you watched Saltburn?  ... Favorite on campus restaurant?   \
# 0                          Yes  ...                            Za's
# 1                           No  ...                  Shawarma Joint
# 5                          Yes  ...                     thai fusion
# 7                          Yes  ...                    bangkok thai
# 31                          No  ...                  Shawarma Joint
# 32                          No  ...                  Dee Dee's Beef
# 41                         Yes  ...                       KoFushion
# 44                          No  ...                        Mia Za’s
# 70                          No  ...               Yatai Restaurant
# 73                          No  ...                  Forage Kitchen
# 75                          No  ...                    Bangkok Thai
# 77                          No  ...                          Kungfu
# 86                          No  ...                  Shawarma Joint
# 109                        Yes  ...                        sakanaya
# 130                         No  ...                           Iken
# 137                         No  ...                  Golden Harbour
# 144                        Yes  ...                    Bangkok thai
# 146                         No  ...                     Kung Fu BBQ
# 160                        Yes  ...                  Forage Kitchen
# 164                         No  ...                        Mia Za’s
# 175                        Yes  ...                  Shawarma Joint
# 189                        Yes  ...               The Bread Company
# 196                         No  ...                   Shwarma Joint
# 204                        Yes  ...                        Mia Za's
# 205                         No  ...                        mia za's
# 229                         No  ...                        Chipotle
# 231                         No  ...                    noodles & co
# 236                         No  ...                           maize
# 249                         No  ...                    Bangkok Thai
# 285                         No  ...                            Oozu
# 395                         No  ...                           Maize
# 427                         No  ...                        Bap Plus
# 460                         No  ...                          JibBap
# 466                         No  ...                  Lao shez Chuan
# 480                         No  ...                              -
# 554                         No  ...                   Panda Express
# 559                         No  ...                        Watson's
# 560                        Yes  ...                             Zas
# 569                         No  ...                            yogi
# 570                         No  ...                    Bangkok Thai
# 571                         No  ...               Mid Summer Lounge
# 579                         No  ...                        Chopstix
# 580                         No  ...                 Signature Grill
# 581                         No  ...                      Signature
# 582                         No  ...                            Yogi
# 583                         No  ...                     Thai Fusion
# 584                         No  ...                Northern Cuisine
# 585                        Yes  ...                        Mia za's
# 586                         No  ...                            Oozu
# 587                         No  ...                             ISR
# 589                         No  ...                 Signature Grill
# 590                         No  ...                     bangok thai
# 592                         No  ...                            Naya
#
#     Favorite place to study on campus?  \
# 0                        Cafe Paradiso
# 1                        Siebel Center
# 5                                  CIF
# 7                         main library
# 31                    Grainger Library
# 32                        My apartment
# 41                     Espresso Royale
# 44                             My dorm
# 70                    Grainger Library
# 73                           FUNK ACES
# 75                                 CIF
# 77        Grainger Engineering Library
# 86                            Grainger
# 109                   grainger library
# 130                                CIF
# 137                   Grainger Library
# 144                       main library
# 146                         Tech Plaza
# 160                           Grainger
# 164                           Grainger
# 175                       Main Library
# 189                       Main Library
# 196                                Arc
# 204                 Grainger 3rd floor
# 205                      main library
# 229                       My apartment
# 231                          siebel cs
# 236                              Union
# 249                                CIF
# 285           Siebel Center for Design
# 395                       Main Library
# 427                       Main Library
# 460                       Lincoln Hall
# 466                            Office
# 480                       Main Library
# 554                          Apartment
# 559                          Cafe Bene
# 560                           Grainger
# 569                  Graniger Library
# 570                       My apartment
# 571                          Cafe Bene
# 579                                CIF
# 580                            My Room
# 581                           Grainger
# 582                   Grainger Library
# 583                            My room
# 584                             office
# 585          Siebel Center for Design
# 586                                CIF
# 587                       Funk library
# 589                       My apartment
# 590                           Grainger
# 592                                CIF
#
#     What genre of music do you like the most?  \
# 0                                         pop
# 1                                         Pop
# 5                                   pop/indie
# 7                                         pop
# 31                                      K-Pop
# 32                                      Metal
# 41                            Alternative Rap
# 44                                       Rock
# 70                                        Pop
# 73                                      K-pop
# 75                               JRock or EDM
# 77                                  Cantonese
# 86                                    Hip hop
# 109                                       pop
# 130                                   Country
# 137                                       Pop
# 144                                       pop
# 146                                  Brit-pop
# 160                                      Rock
# 164                                       RnB
# 175                                       Pop
# 189                               Alternative
# 196                                 Reggaeton
# 204                                       R&B
# 205                                 indie pop
# 229                                       Pop
# 231                               alternative
# 236                                       pop
# 249                         Alternative/Indie
# 285                                 Classical
# 395                                       Pop
# 427                                      Kpop
# 460                                     Indie
# 466                                       Pop
# 480                                Indie Rock
# 554                                  pop rock
# 559                                       EDM
# 560                                     Indie
# 569                                     k-pop
# 570                                 Indie Pop
# 571                                 classical
# 579                                      Folk
# 580                                 Bollywood
# 581                                Classical
# 582                                       Pop
# 583                                       Pop
# 584                                       pop
# 585                                       Rap
# 586                                       R&B
# 587                                   hip-hop
# 589                                       Rap
# 590                                       Pop
# 592                                     Indie
#
#     What is your favorite school subject?  \
# 0                                    math
# 1                                      CS
# 5                                    Math
# 7                              statistics
# 31                            Mathematics
# 32                       Computer Science
# 41                                    Art
# 44                                   Math
# 70                             Statistics
# 73                         Communications
# 75                       Computer Science
# 77                             Statistics
# 86                                     CS
# 109                              calculus
# 130                              Science
# 137                                  Math
# 144                                  math
# 146                           Mathematics
# 160                                  Math
# 164                            Statistics
# 175                               Science
# 189                                   Art
# 196                                  Math
# 204                               English
# 205                                  math
# 229                          Data Science
# 231                                  math
# 236                               Culture
# 249                           Data Mining
# 285                                  STAT
# 395                                  Math
# 427                                 Math
# 460                            Statistics
# 466                                 Math
# 480                           Mathematics
# 554                                    CS
# 559                                  Math
# 560                                  Math
# 569                               history
# 570                               Science
# 571                               Chinese
# 579                                 Stats
# 580                               Physics
# 581                          Mathematics
# 582                                  Math
# 583                               Science
# 584                                  math
# 585                           Statistics
# 586                            Statistics
# 587                               Physics
# 589                                  Math
# 590                            algorithms
# 592                                  Math
#
#     What do you think is the hardest major at UIUC?  \
# 0                                  Computer Science
# 1                                  Computer Science
# 5                                              ECE
# 7                                               ece
# 31                                          Physics
# 32                                          Physics
# 41                                 Computer Science
# 44                                          Physics
# 70                             Computer Engineering
# 73                                          Physics
# 75                                     CS + Physics
# 77                                               CS
# 86                             Computer Engineering
# 109                                             ece
# 130                                Computer Science
# 137                            Computer Engineering
# 144                                          comp e
# 146                                     Mathematics
# 160                                Computer Science
# 164                                          Comp E
# 175                            Computer Engineering
# 189                                             ECE
# 196                                     Engineering
# 204                                             ECE
# 205                           chemical engineering
# 229                                              CE
# 231                                             ece
# 236                                           Music
# 249                          Electrical Engineering
# 285                                              CS
# 395                                         Physics
# 427                                             ECE
# 460                            Computer Engineering
# 466                                     Statistics
# 480                                     Mathematics
# 554                            Chemical Engineering
# 559                                             ECE
# 560                                             NaN
# 569                                              CS
# 570                            Computer Engineering
# 571                                             ECE
# 579                                Computer Science
# 580                                             ECE
# 581                                             ECE
# 582                                             ECE
# 583                                              CS
# 584                                            math
# 585                               Computer Science
# 586                                             ECE
# 587                                         physics
# 589                                             ECE
# 590                                              CS
# 592                                              CS
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 0                         Taylor Swift                              instagram
# 1                         Taylor Swift                                YouTube
# 5                      Phoebe Bridgers                              Instagram
# 7                        one direction                                twitter
# 31                            Newjeans                                Discord
# 32                          Tim Henson                                 Reddit
# 41                         Frank Ocean                              Instagram
# 44                      Kendrick Lamar                                Discord
# 70                          John Mayer                             Instagram
# 73                     Between Friends                                 Reddit
# 75             Porter Robinson for now                               LinkedIn
# 77                         Hilary Hahn                                 Wechat
# 86                           21 Savage                              Instagram
# 109                                SZA                              instagram
# 130                       Taylor Swift                                Discord
# 137                            Anirudh                              Instagram
# 144                       taylor swift                              pinterest
# 146                       Scott Joplin                              Instagram
# 160                      Fleetwood Mac                              Goodreads
# 164                              Drake                                Twitter
# 175                       Taylor Swift                              Goodreads
# 189                        Beach House                                Twitter
# 196                          Bad bunny                              Pinterest
# 204                        Don Toliver                              Instagram
# 205                     lizzy mcalpine                             pinterest
# 229                       Harry Styles                                YouTube
# 231                    phoebe bridgers                                 tumblr
# 236                       blood orange                              pinterest
# 249                         The Weeknd                                YouTube
# 285                              Punch                                    Ins
# 395                       Taylor Swift                              Instagram
# 427                            Enhypen                                 TikTok
# 460                       Lana Del Rey                                 TikTok
# 466                           Jay Chow                                WeChat
# 480                        Hilary Hahn                              Instagram
# 554                         Billy Joel                                 Reddit
# 559                           Coldplay                                 Reddit
# 560                      Weston Estate                                Spotify
# 569                          blackpink                                 WeChat
# 570                        Post Malone                              Instagram
# 571                          Faye Wong                                 wechat
# 579                         Zach Bryan                                 TikTok
# 580                       Arijit Singh                              Instagram
# 581                            Mozart                                 WhatApp
# 582                            Anirudh                                 BeReal
# 583                              Drake                                 Tiktok
# 584                     hall and oates                                 reddit
# 585                   Kacey Musgraves                               Instagram
# 586                  Tyler the Creator                               Snapchat
# 587                         Mac Miller                                Be.real
# 589                       Travis Scott                                Twitter
# 590                    Olivia Rodriguo                                  Insta
# 592                       Lukas Graham                              Instagram
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                           Code Names
# 1                                             Factorio
# 5                                             Fortnite
# 7                                       stardew valley
# 31                                           Football
# 32                                               Poker
# 41                                              Roblox
# 44                                          Best Saber
# 70                                           Valorant
# 73                                            Oxenfree
# 75                                               Poker
# 77                                         Real Soccer
# 86                                            Football
# 109  minesweeper... when I don't want to do my home...
# 130                                              Chess
# 137                                              Chess
# 144                                  settlers of catan
# 146                                          Minecraft
# 160                                     Battlefront II
# 164                                           Fortnite
# 175                                            Pokemon
# 189                       Animal Crossing New Horizons
# 196                                           Fortnite
# 204                                       Cooking Mama
# 205                                               clue
# 229                                              Poker
# 231                                              mafia
# 236                                           solitare
# 249                                         Basketball
# 285                                     Fifth Identity
# 395                                              Taboo
# 427                                         Overcooked
# 460                                         Mario Kart
# 466                                          Splatoon
# 480                                          Voleyball
# 554                                           Terraria
# 559                                               FIFA
# 560                                                ECE
# 569                                   Goose Goose Duck
# 570                                           Splendor
# 571                                               none
# 579                                           Palworld
# 580                                               FIFA
# 581                                          Overwatch
# 582                                             Tennis
# 583                                 I don’t play games
# 584                                          Cyberpunk
# 585                                     Brick Breakers
# 586                                     Papas Pizzeria
# 587                                         video game
# 589                                         Basketball
# 590                                              chess
# 592                                              Chess
#
#     Where is your dream vacation spot? Similarity Score
# 0                             Maldives                5
# 1                            Mountains                6
# 5                               Greece                5
# 7                                japan                6
# 31                               Dubai                4
# 32                          Antarctica                4
# 41                               Tokyo                7
# 44                                Rome                5
# 70                               Japan                5
# 73                         Seattle, WA                8
# 75                               Japan                6
# 77                              Hawaii                6
# 86                           Bora Bora                4
# 109                             Greece                7
# 130                            Hawaii                 5
# 137                             Alaska                3
# 144                    puerto vallarta                8
# 146                               Moon                4
# 160                              Italy                3
# 164                              Japan                5
# 175                              Japan                8
# 189                       Tokyo, Japan                8
# 196                        Switzerland                6
# 204                           Iceland                 8
# 205                            Greece                 4
# 229                          Barcelona                6
# 231                            iceland                5
# 236                              Italy                5
# 249                          Singapore                5
# 285                             Alaska                7
# 395                          Barcelona                5
# 427                             Seoul                 6
# 460                            Croatia                5
# 466                                Idk               10
# 480                        Scandinavia                4
# 554                            Nowhere                7
# 559                               Bali                4
# 560                        New Zealand                7
# 569                               Fuji                7
# 570                        Switzerland                5
# 571                            Iceland                7
# 579                            Jamaica                2
# 580                              Italy                8
# 581                           Istanbul                6
# 582                          Barcelona                4
# 583                           Iceland                 8
# 584                             Hawaii                6
# 585                              Italy                7
# 586                             Madrid                5
# 587                      space station                6
# 589                             Greece                7
# 590                             hawaii                4
# 592                              Dubai                7
#
# [53 rows x 134 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == PUZZLE 3.3 TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('df_staff' in vars()), "Your DataFrame of course staff should be named 'df_staff'."
assert(len(df_staff) == 53), "Check you've added all the course staff correctly."
assert(len(df_staff.columns.to_list()) == 134), "You should have all of the questions columns and the Similarity Score column in df_staff." 

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 3.5: Course Staff Twin!
#
# Now that we have the course staff responses in `df_staff`, find your course staff twin (the staff member who has the **highest Similarity Score** to you).

# %%
df_staff.nlargest(1, "Similarity Score")
# Out:
#              Name  Section Do you like sweet or savory food?  \
# 466  TA Chenyang   Y05 Y15                            Savory
#
#     Do you use Windows or Mac?  \
# 466                    Windows
#
#     Do you like doing your homework when it's released or in the end?  \
# 466                                       Near the end
#
#     Are you a morning person?  \
# 466      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 466                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 466               Dairy                                 Out-of-State
#
#     Have you watched Saltburn?  ... Favorite on campus restaurant?   \
# 466                         No  ...                  Lao shez Chuan
#
#     Favorite place to study on campus?  \
# 466                            Office
#
#     What genre of music do you like the most?  \
# 466                                       Pop
#
#     What is your favorite school subject?  \
# 466                                 Math
#
#     What do you think is the hardest major at UIUC?  \
# 466                                     Statistics
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 466                           Jay Chow                                WeChat
#
#     What is your favorite game to play (either video game or IRL)?  \
# 466                                          Splatoon
#
#     Where is your dream vacation spot? Similarity Score
# 466                                Idk               10
#
# [1 rows x 134 columns]

# %% [markdown]
# ### Analysis: Final Reflection
#
# **Q3: Do you think our method of finding similar people is effective? Why or why not? What could improve it?**

# %% [markdown]
# I think the method works for finding similar people to you. It is better when you add more questions to the list as it makes it finds someone that is more similar to you. The only thing I will point out is that it only considers binary questions and leaves out other questions that might be "important" to finding someone who is similar to you but I am unsure if there is a way to make that happen.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
