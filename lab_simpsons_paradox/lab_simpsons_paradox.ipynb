# %% [markdown]
# # Welcome to Lab: Simpson's Paradox 🔬
#
# Before this lab section, you learned about Simpson's Paradox and confounding variables in lecture.  This week, you will find Simpson's Paradox through analysis of a dataset in Python, and get some practice writing conditionals for pandas DataFrames!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant, your Course Aides, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Peng"
ca1_name = "Sophia"
ca2_name = "Qiran"
ca3_name = ""

# Say hello to each other!
# - Groups of 3 are ideal :)
# - However, groups of 2 or 4 are fine too!
#
# Question of the Day (QOTD) to Ask Your Group: "What is your favorite music artist (besides Taylor Swift)?"
partner1_name = "Shivani"
partner1_netid = "sr80"
partner1_artist = "drake"

partner2_name = "sofia"
partner2_netid = "sofia5"
partner2_artist = "the neighborhood"

partner3_name = "jenny"
partner3_netid = "jarreci2"
partner3_artist = "bad bunny"

partner4_name = "tori"
partner4_netid = "vrlee2"
partner4_artist = "the lumineers"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: The GPA Dataset
#
# Many of you have likely come across one of the GPA visualizations found at https://waf.cs.illinois.edu/discovery/gpa/, either out of
# curiosity or the need to investigate a mysterious GenEd class you signed up for.
#
# Regardless, these visualizations are built on the **GPA Dataset** of UIUC students across all course subjects. Today, you're going to do some analysis and discover a case of Simpson's Paradox within data taken from UIUC courses!

# %% [markdown]
# ## Load the GPA Dataset
#
# The most recent version of the "GPA Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/gpa.csv
# ```
#
# Use Python to load this dataset into a DataFrame called `df`:

# %%
import pandas as pd

df = pd.read_csv("https://waf.cs.illinois.edu/discovery/gpa.csv")
df
# Out:
#        Year    Term YearTerm Subject  Number                   Course Title  \
# 0      2023  Spring  2023-sp     AAS     100   Intro Asian American Studies
# 1      2023  Spring  2023-sp     AAS     100   Intro Asian American Studies
# 2      2023  Spring  2023-sp     AAS     100   Intro Asian American Studies
# 3      2023  Spring  2023-sp     AAS     200           U.S. Race and Empire
# 4      2023  Spring  2023-sp     AAS     215   US Citizenship Comparatively
# ...     ...     ...      ...     ...     ...                            ...
# 69064  2010  Summer  2010-su    STAT     410  Statistics and Probability II
# 69065  2010  Summer  2010-su    STAT     440    Statistical Data Management
# 69066  2010  Summer  2010-su     TAM     212          Introductory Dynamics
# 69067  2010  Summer  2010-su     TAM     251   Introductory Solid Mechanics
# 69068  2010  Summer  2010-su     TAM     335   Introductory Fluid Mechanics
#
#       Sched Type  A+   A  A-  ...  C+  C  C-  D+  D  D-  F  W  Students  \
# 0            DIS   0  11   5  ...   0  0   0   0  0   0  1  0        22
# 1            DIS   0  17   2  ...   0  0   0   0  0   0  0  1        23
# 2            DIS   0  13   2  ...   0  0   1   0  0   0  1  0        21
# 3            LCD   6  15   5  ...   0  0   0   0  1   0  1  0        33
# 4            LCD  16  12   2  ...   0  0   0   0  0   0  0  0        33
# ...          ...  ..  ..  ..  ...  .. ..  ..  .. ..  .. .. ..       ...
# 69064        LEC   5  10   2  ...   0  1   3   0  0   0  2  1        31
# 69065        LEC   4  12   8  ...   0  0   0   0  0   0  0  0        28
# 69066        LEC   0   1   3  ...   5  1   1   0  2   0  1  0        28
# 69067        LCD   1   2   2  ...   3  3   2   0  0   1  1  0        21
# 69068        LEC   5   8   9  ...   0  4   0   0  1   0  2  0        39
#
#              Primary Instructor
# 0                 Shin, Jeongsu
# 1                 Shin, Jeongsu
# 2                Lee, Sabrina Y
# 3                Sawada, Emilia
# 4                  Kwon, Soo Ah
# ...                         ...
# 69064        Stepanov, Alexei G
# 69065              Unger, David
# 69066         Morgan, William T
# 69067  Ott-Monsivais, Stephanie
# 69068          Keane, Richard D
#
# [69069 rows x 23 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert(len(df) == 69069 ), "This is not the GPA dataset you're looking for."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Data Cleaning: An Additional Column
#
# The GPA dataset contains raw GPA data and is not the easiest to work with if we want to analyze intricacies such as the average GPA or passing rate.  Luckily, DataFrames are modifiable, so we can **add more columns** based on what questions we want to answer.
#
# The process of modifying a dataset via deletion (cleaning up empty/unwanted values) or addition (adding new columns) is often called **data cleaning**. This is an important concept in Data Science, because you won't always receive your data in the perfect format for your purposes.
#
# With the GPA dataset, we want to investigate one innocent question posed by a theoretical incoming student:
# - *Is it easier to get an A in STAT or CS courses at UIUC?*
#
# To do this, we'll need to first perform some modifications on our loaded DataFrame, `df`. Specifically, we will need to create:
# - An `A_Grades` column, containing the total number of students receiving an A+, A, or A- in every course

# %% [markdown]
# ### Puzzle 1.1: Creating an `A_Grades` Column
#
# Create the new column `A_Grades` that stores the total number of "A"s given in every course.
#
# - We consider an "A" to be any type of A, in other words "A+", "A", or an "A-" are all included.
# - In our `df`, the number of students recieving a particular grade in a course is found in the `df['Grade']` column. For example, `df['A']` contains the number of students who recieved an A.

# %%
df['A_Grades'] = df["A+"] + df["A"] + df["A-"]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('A_Grades' in df), "Make sure you've named the A_Grades column properly and added it to the DataFrame."
assert(df['A_Grades'].sum() == 2325768), "Double check the values of your A_Grades column."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# # Working with the GPA Dataset
# Now that we have that extra column set up, we can perform basic mathematical analysis on the GPA Dataset to get insight towards our question:
# - *Is it easier to get an A in STAT or CS courses at UIUC?*
#
# Should be simple, right? Let's just see which subject, STAT or CS, has a greater percentage of A grades.

# %% [markdown]
# ### Puzzle 1.2: Subject DataFrames
#
# Select only the rows of the GPA dataset `df` with a `Subject` of `STAT`. Assign these rows to a new DataFrame, `df_STAT`.
# - Make sure your result only contains STAT courses!

# %%
df_STAT = df[df.Subject == "STAT"]
df_STAT
# Out:
#        Year    Term YearTerm Subject  Number                   Course Title  \
# 2118   2023  Spring  2023-sp    STAT     100                     Statistics
# 2119   2023  Spring  2023-sp    STAT     100                     Statistics
# 2120   2023  Spring  2023-sp    STAT     107         Data Science Discovery
# 2121   2023  Spring  2023-sp    STAT     200           Statistical Analysis
# 2122   2023  Spring  2023-sp    STAT     207       Data Science Exploration
# ...     ...     ...      ...     ...     ...                            ...
# 69061  2010  Summer  2010-su    STAT     100                     Statistics
# 69062  2010  Summer  2010-su    STAT     100                     Statistics
# 69063  2010  Summer  2010-su    STAT     400   Statistics and Probability I
# 69064  2010  Summer  2010-su    STAT     410  Statistics and Probability II
# 69065  2010  Summer  2010-su    STAT     440    Statistical Data Management
#
#       Sched Type  A+    A  A-  ...   C  C-  D+   D  D-   F  W  Students  \
# 2118         LEC  51  165  50  ...  24  15   7  14  10  19  3       478
# 2119         ONL  82  285  83  ...  51  23  17  19   6  41  3       849
# 2120         LEC  44  177  36  ...   7   5   2   0   0   8  0       341
# 2121         LEC  59   54  23  ...   3   0   2   0   0   1  0       178
# 2122         LEC  27   23   8  ...   6   3   1   0   0   3  0        93
# ...          ...  ..  ...  ..  ...  ..  ..  ..  ..  ..  .. ..       ...
# 69061        LCD   1   13   3  ...   2   2   3   1   1   1  0        39
# 69062        LCD   0   14   3  ...   3   0   0   1   0   3  1        28
# 69063        LEC   4   15   7  ...   2   2   0   1   0   3  1        47
# 69064        LEC   5   10   2  ...   1   3   0   0   0   2  1        31
# 69065        LEC   4   12   8  ...   0   0   0   0   0   0  0        28
#
#        Primary Instructor  A_Grades
# 2118    Flanagan, Karle A       266
# 2119    Flanagan, Karle A       450
# 2120    Flanagan, Karle A       257
# 2121           Yu, Albert       136
# 2122       Deeke, Julie M        58
# ...                   ...       ...
# 69061  Hirtz, Nathaniel R        17
# 69062    Dalpiaz, David M        17
# 69063      Monrad, Ditlev        26
# 69064  Stepanov, Alexei G        17
# 69065        Unger, David        24
#
# [1019 rows x 24 columns]

# %% [markdown]
# Select only the rows of the GPA dataset `df` with a `Subject` of `CS`. Assign these rows to a new DataFrame, `df_CS`.
# - Make sure your result only contains CS courses!

# %%
df_CS = df[df.Subject == "CS"]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df_STAT' in vars() ), "Make certain to name the STAT courses df_STAT."
assert( 'df_CS' in vars() ), "Make certain to name the CS courses df_CS."
assert( len(df_STAT[df_STAT.Subject != "STAT"] ) == 0 ), "It looks like you did not subset df_STAT to only STAT courses."
assert( len(df_CS[df_CS.Subject != "CS"] ) == 0 ), "It looks like you did not subset df_CS to only CS courses."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 1.3: Comparing Overall Percentages
#
# With our two new DataFrames of STAT and CS courses, use the following code cell to determine the **percentage** of A grades recieved in STAT and CS courses, storing them as variables `stat_a` and `cs_a` respectively.
#
# Print statements have been provided to show the values you calculate.
#
# As you work, remember:
# - To find the **% of As**, divide the total number of `A_Grades` by the total number of `Students` ($\space \frac{A \space Grades}{Students} \space$).
# - The `A_Grades` column you made earlier, and the `Students` column containing the total number of students in each course.
# - The syntax `sum(df['column_name'])` can be used to add up the values of all rows in a particular column of a DataFrame.
# - Your % should be a decimal between 0 and 1.

# %%
stat_a = sum(df_STAT["A_Grades"])/sum(df_STAT["Students"])
print(f'Overall % of As in STAT is: {stat_a}')

cs_a = sum(df_CS["A_Grades"])/sum(df_CS["Students"])
print(f'Overall % of As in CS is: {cs_a}')
# Out:
# Overall % of As in STAT is: 0.609647329889628
# Overall % of As in CS is: 0.6119729348794934

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
import math
assert(math.isclose(stat_a, 0.609647329889628)), "The overall percentage of A grades received in STAT courses does not appear to have been correctly calculated."
assert(math.isclose(cs_a, 0.6119729348794934)), "The overall percentage of A grades received in CS courses does not appear to have been correctly calculated."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Analysis: Good Comparison?
# **Q: What conclusion can you take from the overall percentages found above when asking the original question:**
# - *Is it significantly easier to get an A in STAT or CS courses at UIUC, or is so close it would be hard to make general conclusions?*

# %% [markdown]
# It would be hard to make a general conclusion since there are different factors that play into the result such as difficulty, class sizes, number of students enrolled in CS and STAT, etc..

# %% [markdown]
# **Q: Given what you've learned about experimental design, what are some reasons (specific to this dataset) you may not trust this conclusion? If you would trust it, explain why.**

# %% [markdown]
# The data set is over 10 years old and classes can change which can contribute to not trusting the conclusion.

# %% [markdown]
# ## An Extra Consideration
#
# If you look at the `Year` column of our GPA dataset, you might notice that we have some old data in our dataset - all the way back to **2010**! This means we aren't really answering our question from the perspective of a student now.
#
# If we want to know if it is easier to **currently** get an A in a STAT or CS course, we should control for the **date** of the data by looking at more **recent years** specifically.

# %% [markdown]
# ### Puzzle 1.4: More DataFrames
#
# Using the code cells below, define four new DataFrames by selecting from rows of our previously created `df_CS` and `df_STAT`.
#
# - `df_cs_recent`: all `CS` course data in *recent years* ($\space \geq 2021 \space$)
# - `df_stat_recent`: all `STAT` course data in *recent years* ($\space \geq 2021 \space$)
# - `df_cs_old`: all other, older `CS` course data ($\space < 2021 \space$)
# - `df_stat_old`: all other, older `STAT` course data ($\space < 2021 \space$)
#
# Define *recent years* as **any year after and including 2021**, and older years as any year before 2021.
#
# Feel free to use conditionals OR the `.isin()` syntax you learned in the last lab.

# %%
df_stat_recent = df_STAT[df_STAT.Year >= 2021]

# %%
df_cs_recent = df_CS[df_CS.Year >= 2021]

# %%
df_stat_old = df_STAT[df_STAT.Year < 2021]

# %%
df_cs_old = df_CS[df_CS.Year < 2021]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error our output, you PASSED all test cases!
# - If this cell results in any errors, check you previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df_stat_recent' in vars() ), "Make certain to name the recent STAT courses df_stat_recent."
assert( 'df_cs_recent' in vars() ), "Make certain to name the recent CS courses df_cs_recent."
assert( 'df_stat_old' in vars() ), "Make certain to name the old STAT courses df_stat_old."
assert( 'df_cs_old' in vars() ), "Make certain to name the old CS courses df_cs_old."

assert( len(df_stat_recent[df_stat_recent.Year < 2021] ) == 0 ), "Make sure only years after and including 2021 are in the df_stat_recent DataFrame."
assert( len(df_cs_recent[df_cs_recent.Year < 2021] ) == 0 ), "Make sure only years after and including 2021 are in the df_cs_recent DataFrame."
assert( len(df_stat_old[df_stat_old.Year >= 2021] ) == 0 ), "Make sure only years before 2021 are in the df_stat_old DataFrame."
assert( len(df_cs_old[df_cs_old.Year >= 2021] ) == 0 ), "Make sure only years before 2021 are in the df_cs_old DataFrame."

assert( len(df[ df.index.isin(df_stat_recent.index) & df.index.isin(df_stat_old.index) ]) == 0 ), "Check for duplicate values in your df_stat_recent and df_stat_old DataFrames."
assert( len(df[ df.index.isin(df_cs_recent.index) & df.index.isin(df_cs_old.index) ]) == 0 ), "Check for duplicate values in your df_cs_recent and df_cs_old DataFrames."
assert( len(df_cs_old) + len(df_cs_recent) == len(df_CS) ), "You're excluding some rows from df_cs_old or df_cs_recent. Please double check your conditionals."
assert( len(df_stat_old) + len(df_stat_recent) == len(df_STAT) ), "You're excluding some rows from df_stat_old or df_stat_recent. Please double check your conditionals."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 1.5: New Analysis
# Now that we've got all the DataFrames setup with GPA data of the `CS` and `STAT` courses separated by recency (2022 or newer being 'recent'), we can do more in-depth analysis to investigate our question.
#
# In the following code cells, **calculate the percentages** described by the comment in the cell. Your answer should always be a **decimal between 0 and 1**.
#
# Just like Puzzle 1.3, remember:
# - To find the % of As, divide the total number of As by the total number of students.
# - The `A_Grades` column you made earlier, and the `Students` column containing the total number of students in each course.
# - The syntax `sum(df['column_name'])` can be used to add up the values of all rows in a particular column of a DataFrame.

# %%
# Percentage of As received in CS in recent years
cs_recent_a = sum(df_cs_recent["A_Grades"])/sum(df_cs_recent["Students"])
print(f'Percentage of As received in CS in recent years: {cs_recent_a}')
# Out:
# Percentage of As received in CS in recent years: 0.7130059975764269

# %%
# Percentage of As received in STAT in recent years
stat_recent_a = sum(df_stat_recent["A_Grades"])/sum(df_stat_recent["Students"])
print(f'Percentage of As received in STAT in recent years: {stat_recent_a}')
# Out:
# Percentage of As received in STAT in recent years: 0.6505842595985506

# %%
# percentage of As received in CS in older years
cs_old_a = sum(df_cs_old["A_Grades"])/sum(df_cs_old["Students"])
print(f'Percentage of As received in CS in older years: {cs_old_a}')
# Out:
# Percentage of As received in CS in older years: 0.5714531786360225

# %%
# percentage of As received in STAT in older years
stat_old_a = sum(df_stat_old["A_Grades"])/sum(df_stat_old["Students"])
print(f'Percentage of As received in STAT in older years: {stat_old_a}')
# Out:
# Percentage of As received in STAT in older years: 0.5975443876015648

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert(math.isclose(cs_recent_a,  0.7130059975764269)), "The overall percentage of A grades received in CS courses recently does not appear to have been correctly calculated."
assert(math.isclose(stat_recent_a, 0.6505842595985506)), "The overall percentage of A grades received in STAT courses recently does not appear to have been correctly calculated."

assert(math.isclose(cs_old_a, 0.5714531786360225)), "The overall percentage of A grades received in CS courses in older years does not appear to have been correctly calculated."
assert(math.isclose(stat_old_a, 0.5975443876015648)), "The overall percentage of A grades received in STAT courses in older years does not appear to have been correctly calculated."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Observe the Results
# **Run the following cell** to format all of your answers as a DataFrame.
#
# Keep in mind that "Older" means data from courses **before 2021**, and "Recent" means courses held **during or after 2021**.

# %%
pd.DataFrame([
  {'Older % of A': cs_old_a, 'Recent % of A': cs_recent_a, 'Overall % of A': cs_a},
  {'Older % of A': stat_old_a, 'Recent % of A': stat_recent_a, 'Overall % of A': stat_a}
], index=['CS', 'STAT'])
# Out:
#       Older % of A  Recent % of A  Overall % of A
# CS        0.571453       0.713006        0.611973
# STAT      0.597544       0.650584        0.609647

# %% [markdown]
# Notice that when observing the "Overall % of A" grades received:
# - It appears that `STAT` and `CS` are **equally difficult** to get an `A_Grades` (61.197% vs. 60.965%).
# - However, if you look at the sub-group of the courses held in years of **2021 and later**, we see that `CS` actually has a higher `A_Grades` rate!
#
# This is **Simpson's Paradox**: a pattern within a population can appear, disappear, or reverse when you look at subpopulations.
#
# In more formal terms, Simpson's Paradox can cause you to observe a pattern reverse when you look at the overall group statistics versus statistics of groups post-stratification. In this case we are stratifying by time.

# %% [markdown]
# ### Analysis: Reflecting on New Observations

# %% [markdown]
# Now think about how would you now respond differently to the incoming student's question:
# - *Is it easier to get an A in STAT or CS courses at UIUC?*
#
# **Q: Which comparison of percentages do you trust more and why? Are there any other potential confounding variables when answering this question that could be investigated further? Respond with at least three full sentences.**

# %% [markdown]
# I would look at recent data percenatges as they would reflect a more accurate answer. I would rather look at recent data since the courses are probably still being offered and probably have smiliar material across 2021-2023. Again, some confoinding variables can be the enrollment in CS and STAT majors, difficulty of classes, courses offered, etc.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 2: Revisiting the Hello Dataset
#
# Enough about GPA (for now). Two weeks ago, you created a series of questions that made up the **Hello Dataset** and completed the survey by answering all of the questions made by students in DISCOVERY.
#
# Now, we will load this dataset again and briefly answer a few questions with data about YOU!

# %% [markdown]
# ## Load the Hello Dataset
#
# The "Hello Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/hello-sp24.csv
# ```
#
# Use Python to load this dataset into a DataFrame called `df_hello`:

# %%
df_hello = pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-sp24.csv")
df_hello
# Out:
#             Name Section Do you like sweet or savory food?  \
# 0    Prof. Karle     AL1                            Savory
# 1     Prof. Wade     AL1                            Savory
# 2        Raymond     Y17                            Savory
# 3          Keiji     Y13                             Sweet
# 4            Ash     Y17                             Sweet
# ..           ...     ...                               ...
# 606     Jonathan     Y20                             Sweet
# 607          Leo     Y19                             Sweet
# 608       Afnaan     Y01                            Savory
# 609       Nathan     Y17                             Sweet
# 610        Ellyn     Y2-                            Savory
#
#     Do you use Windows or Mac?  \
# 0                          Mac
# 1                      Windows
# 2                      Windows
# 3                      Windows
# 4                      Windows
# ..                         ...
# 606                        Mac
# 607                        Mac
# 608                        Mac
# 609                    Windows
# 610                        Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 0                                         Near the end
# 1                                   When it's released
# 2                                   When it's released
# 3                                   When it's released
# 4                                   When it's released
# ..                                                 ...
# 606                                 When it's released
# 607                                       Near the end
# 608                                       Near the end
# 609                                 When it's released
# 610                                       Near the end
#
#     Are you a morning person?  \
# 0        NOT a Morning Person
# 1        NOT a Morning Person
# 2              Morning Person
# 3              Morning Person
# 4        NOT a Morning Person
# ..                        ...
# 606            Morning Person
# 607      NOT a Morning Person
# 608      NOT a Morning Person
# 609            Morning Person
# 610      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                   No
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 606                                                 No
# 607                                                 No
# 608                                                 No
# 609                                                 No
# 610                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 0                 Dairy                                     In-State
# 1                 Dairy                                     In-State
# 2                 Dairy                                     In-State
# 3                 Dairy                                     In-State
# 4                 Dairy                                     In-State
# ..                  ...                                          ...
# 606           Non-dairy                                 Out-of-State
# 607               Dairy                                 Out-of-State
# 608               Dairy                                     In-State
# 609               Dairy                                     In-State
# 610               Dairy                                 Out-of-State
#
#     Have you watched Saltburn?  ...  \
# 0                          Yes  ...
# 1                           No  ...
# 2                           No  ...
# 3                           No  ...
# 4                           No  ...
# ..                         ...  ...
# 606                         No  ...
# 607                         No  ...
# 608                        Yes  ...
# 609                         No  ...
# 610                        Yes  ...
#
#     Besides the US, what country would you like to live in?  \
# 0                                             Maldives
# 1                                              Sweeden
# 2                                                China
# 3                                                japan
# 4                                                Italy
# ..                                                 ...
# 606                                              Japan
# 607                                             Taiwan
# 608                                              India
# 609                                             Norway
# 610                                              Korea
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 0                              Za's                      Cafe Paradiso
# 1                    Shawarma Joint                      Siebel Center
# 2                       Kung Fu BBQ                               Home
# 3                              yogi                               main
# 4                      Burrito King                      Cafe Paradiso
# ..                              ...                                ...
# 606                             Evo                               Dorm
# 607                Northern Cuisine                            My dorm
# 608                    Bangkok Thai                                CIF
# 609                       McDonalds                            Library
# 610                 Northern Cusine                                CIF
#
#     What genre of music do you like the most?  \
# 0                                         pop
# 1                                         Pop
# 2                                         RnB
# 3                                         rap
# 4                                         Pop
# ..                                        ...
# 606                                       Pop
# 607                                     J-pop
# 608                                       pop
# 609                                     R & B
# 610                                       Rap
#
#     What is your favorite school subject?  \
# 0                                    math
# 1                                      CS
# 2                                 History
# 3                                    math
# 4                                   Stats
# ..                                    ...
# 606                               Finance
# 607                                  Math
# 608                               Science
# 609                        Social Studies
# 610                               English
#
#     What do you think is the hardest major at UIUC?  \
# 0                                  Computer Science
# 1                                  Computer Science
# 2                                               ECE
# 3                                          pre med
# 4                                       Engineering
# ..                                              ...
# 606                                              EE
# 607                          Electrical Engineering
# 608                                              CS
# 609                            Computer Engineering
# 610                                        Comp Sci
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 0                         Taylor Swift                              instagram
# 1                         Taylor Swift                                YouTube
# 2                          Alan Walker                              Instagram
# 3                          post malone                                  insta
# 4           TAYLOR SWIFT!!!!!!!!!!!!!!                              Instagram
# ..                                 ...                                    ...
# 606                            Yoasobi                                   Line
# 607                Lilas Ikuta (Ikura)                               Facebook
# 608                              Drake                              Instagram
# 609                      Daniel Ceaser                              Instagram
# 610                        Don Toliver                                 Tiktok
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                           Code Names
# 1                                             Factorio
# 2                                            Minecraft
# 3                                      clash of clans
# 4                                              Pokemon
# ..                                                 ...
# 606                                            Genshin
# 607                                     Genshin Impact
# 608                                         Mario Kart
# 609                                           Fortnite
# 610                                      Hide and Seek
#
#     Where is your dream vacation spot?
# 0                             Maldives
# 1                            Mountains
# 2                                China
# 3                               greece
# 4                              Itality
# ..                                 ...
# 606                             Europe
# 607                             Hawaii
# 608                               Bali
# 609                      Venice, Italy
# 610                        Switzerland
#
# [611 rows x 133 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert(len(df_hello) >= 600 and len(df_hello) < 700), "This is not the Hello Dataset you're looking for. Check the URL."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Happiness vs. Battery Life
#
# There is a narrative that "Gen Zs are only happy when they're on their phone" -- let's explore the relationship between your happiness and your cell phone's battery life!
#
# With the Hello Dataset, there's two questions with numeric responses that can help us explore this:
# - From 1 to 10, how happy are you right now?
# - What is your phone battery percentage currently at?

# %% [markdown]
# ### Puzzle 2.1: Observation Subsets
#
# In this situation, let's define three levels of happiness:
# - You're **very happy** if you answered "how happy are you right now?" with a score of 9 or higher,
# - You're **unhappy** if you answered "how happy are you right now?" with a score of less than 3,
# - Otherwise, you're just **happy**.
#
# From this, create three DataFrames that contain subsets of the Hello Dataset:
# - `df_very_happy`: including everyone who is "very happy" ($\space \geq 9 \space$)
# - `df_happy`: including everyone who is "happy" ($\space <9 $ and $\geq 3 \space$)
# - `df_unhappy`: including everyone who is "unhappy" ($\space < 3 \space$)
#
# The `happiness_question` question has been provided to you as a **string** for ease of DataFrame column access.

# %%
happiness_question = 'From 1 to 10, how happy are you right now?'

df_very_happy = df_hello[df_hello[happiness_question] >= 9]
df_very_happy
# Out:
#              Name   Section Do you like sweet or savory food?  \
# 6             Max       Y02                            Savory
# 92      Michelle        Y03                             Sweet
# 107       Nathan        Y03                            Savory
# 115         Emily       Y03                            Savory
# 129          Cici       Y12                             Sweet
# 130     CA Qiran        Y02                             Sweet
# 131        Nathan       Y14                             Sweet
# 134         Affan       Y14                            Savory
# 145      Samantha       Y17                            Savory
# 184       William       Y10                             Sweet
# 212          Tony       Y06                            Savory
# 221          Xing       Y15                             Sweet
# 229     CA Anagha       Y--                            Savory
# 251          Adam       Y09                             Sweet
# 266         Paige       Y14                             Sweet
# 276          Neil       Y10                            Savory
# 280         Danny       Y12                             Sweet
# 281      Yongkang       Y12                            Savory
# 287          Nick       Y24                             Sweet
# 299          Zibo       Y05                             Sweet
# 315         Simon       Y17                            Savory
# 316        Yiming       Y10                             Sweet
# 330         David       Y18                            Savory
# 331         Shlok       Y07                             Sweet
# 332     Sebastian       Y08                             Sweet
# 341          Isha       Y01                             Sweet
# 355         Ethan       Y20                            Savory
# 364         Naomi       Y11                            Savory
# 375        Galen        Y09                             Sweet
# 387        Shalin       Y15                             Sweet
# 417         Ethan       Y18                            Savory
# 420        Vishal       Y03                             Sweet
# 456        Nathan       Y01                            Savory
# 476        Andrew       Y14                            Savory
# 480  TA Evangelos  Y07, Y13                            Savory
# 484           Gil       Y13                            Savory
# 485    Steven Cai       Y18                             Sweet
# 496        Zhilin       Y17                             Sweet
# 497          Nana       Y03                            Savory
# 500         Casey       Y01                            Savory
# 510        Yaxuan       Y13                             Sweet
# 514    Jiayang Xu       Y06                             Sweet
# 529         Jenny       Y11                             Sweet
# 530        Justin       Y20                            Savory
# 540         Shiyi       Y12                            Savory
# 543         Kevin       Y17                            Savory
# 546       Anthony       Y15                            Savory
# 561         Vedha       Y14                             Sweet
# 571        CA Xin       Y11                             Sweet
# 583     CA Anchal       Y04                            Savory
# 599          ecat       Y20                            Savory
# 601        Vedant       Y10                            Savory
# 607           Leo       Y19                             Sweet
# 608        Afnaan       Y01                            Savory
#
#     Do you use Windows or Mac?  \
# 6                      Windows
# 92                         Mac
# 107                    Windows
# 115                        Mac
# 129                        Mac
# 130                        Mac
# 131                    Windows
# 134                        Mac
# 145                        Mac
# 184                        Mac
# 212                        Mac
# 221                        Mac
# 229                        Mac
# 251                    Windows
# 266                        Mac
# 276                    Windows
# 280                        Mac
# 281                        Mac
# 287                    Windows
# 299                        Mac
# 315                        Mac
# 316                        Mac
# 330                    Windows
# 331                        Mac
# 332                        Mac
# 341                        Mac
# 355                    Windows
# 364                        Mac
# 375                        Mac
# 387                        Mac
# 417                    Windows
# 420                    Windows
# 456                    Windows
# 476                        Mac
# 480                    Windows
# 484                    Windows
# 485                        Mac
# 496                        Mac
# 497                        Mac
# 500                    Windows
# 510                        Mac
# 514                        Mac
# 529                        Mac
# 530                    Windows
# 540                        Mac
# 543                        Mac
# 546                    Windows
# 561                    Windows
# 571                        Mac
# 583                        Mac
# 599                        Mac
# 601                    Windows
# 607                        Mac
# 608                        Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 6                                         Near the end
# 92                                        Near the end
# 107                                       Near the end
# 115                                 When it's released
# 129                                 When it's released
# 130                                 When it's released
# 131                                       Near the end
# 134                                 When it's released
# 145                                       Near the end
# 184                                 When it's released
# 212                                 When it's released
# 221                                       Near the end
# 229                                       Near the end
# 251                                       Near the end
# 266                                 When it's released
# 276                                       Near the end
# 280                                 When it's released
# 281                                 When it's released
# 287                                 When it's released
# 299                                       Near the end
# 315                                       Near the end
# 316                                       Near the end
# 330                                 When it's released
# 331                                                NaN
# 332                                 When it's released
# 341                                 When it's released
# 355                                 When it's released
# 364                                       Near the end
# 375                                       Near the end
# 387                                       Near the end
# 417                                       Near the end
# 420                                 When it's released
# 456                                       Near the end
# 476                                       Near the end
# 480                                 When it's released
# 484                                       Near the end
# 485                                       Near the end
# 496                                       Near the end
# 497                                 When it's released
# 500                                       Near the end
# 510                                 When it's released
# 514                                       Near the end
# 529                                 When it's released
# 530                                       Near the end
# 540                                 When it's released
# 543                                       Near the end
# 546                                 When it's released
# 561                                       Near the end
# 571                                       Near the end
# 583                                       Near the end
# 599                                       Near the end
# 601                                       Near the end
# 607                                       Near the end
# 608                                       Near the end
#
#     Are you a morning person?  \
# 6        NOT a Morning Person
# 92       NOT a Morning Person
# 107      NOT a Morning Person
# 115      NOT a Morning Person
# 129            Morning Person
# 130            Morning Person
# 131      NOT a Morning Person
# 134            Morning Person
# 145            Morning Person
# 184            Morning Person
# 212      NOT a Morning Person
# 221            Morning Person
# 229      NOT a Morning Person
# 251            Morning Person
# 266      NOT a Morning Person
# 276      NOT a Morning Person
# 280      NOT a Morning Person
# 281      NOT a Morning Person
# 287      NOT a Morning Person
# 299      NOT a Morning Person
# 315            Morning Person
# 316            Morning Person
# 330            Morning Person
# 331      NOT a Morning Person
# 332            Morning Person
# 341      NOT a Morning Person
# 355      NOT a Morning Person
# 364            Morning Person
# 375      NOT a Morning Person
# 387      NOT a Morning Person
# 417            Morning Person
# 420            Morning Person
# 456      NOT a Morning Person
# 476      NOT a Morning Person
# 480            Morning Person
# 484      NOT a Morning Person
# 485            Morning Person
# 496      NOT a Morning Person
# 497            Morning Person
# 500      NOT a Morning Person
# 510      NOT a Morning Person
# 514      NOT a Morning Person
# 529            Morning Person
# 530      NOT a Morning Person
# 540      NOT a Morning Person
# 543      NOT a Morning Person
# 546      NOT a Morning Person
# 561      NOT a Morning Person
# 571            Morning Person
# 583      NOT a Morning Person
# 599            Morning Person
# 601      NOT a Morning Person
# 607      NOT a Morning Person
# 608      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 6                                                  Yes
# 92                                                  No
# 107                                                 No
# 115                                                 No
# 129                                                Yes
# 130                                                Yes
# 131                                                 No
# 134                                                 No
# 145                                                 No
# 184                                                 No
# 212                                                 No
# 221                                                 No
# 229                                                Yes
# 251                                                Yes
# 266                                                Yes
# 276                                                 No
# 280                                                 No
# 281                                                Yes
# 287                                                 No
# 299                                                 No
# 315                                                 No
# 316                                                 No
# 330                                                 No
# 331                                                 No
# 332                                                 No
# 341                                                 No
# 355                                                 No
# 364                                                Yes
# 375                                                 No
# 387                                                 No
# 417                                                 No
# 420                                                 No
# 456                                                 No
# 476                                                 No
# 480                                                Yes
# 484                                                 No
# 485                                                 No
# 496                                                 No
# 497                                                 No
# 500                                                 No
# 510                                                 No
# 514                                                Yes
# 529                                                Yes
# 530                                                Yes
# 540                                                 No
# 543                                                 No
# 546                                                 No
# 561                                                 No
# 571                                                Yes
# 583                                                 No
# 599                                                Yes
# 601                                                Yes
# 607                                                 No
# 608                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 6                 Dairy                                 Out-of-State
# 92            Non-dairy                                     In-State
# 107               Dairy                                     In-State
# 115               Dairy                                     In-State
# 129               Dairy                                 Out-of-State
# 130               Dairy                                 Out-of-State
# 131               Dairy                                     In-State
# 134               Dairy                                     In-State
# 145           Non-dairy                                     In-State
# 184               Dairy                                     In-State
# 212               Dairy                                 Out-of-State
# 221               Dairy                                     In-State
# 229               Dairy                                     In-State
# 251               Dairy                                     In-State
# 266               Dairy                                     In-State
# 276               Dairy                                     In-State
# 280               Dairy                                 Out-of-State
# 281           Non-dairy                                 Out-of-State
# 287               Dairy                                 Out-of-State
# 299               Dairy                                 Out-of-State
# 315               Dairy                                     In-State
# 316               Dairy                                 Out-of-State
# 330               Dairy                                     In-State
# 331               Dairy                                 Out-of-State
# 332               Dairy                                     In-State
# 341               Dairy                                     In-State
# 355           Non-dairy                                 Out-of-State
# 364               Dairy                                          NaN
# 375               Dairy                                     In-State
# 387               Dairy                                     In-State
# 417           Non-dairy                                     In-State
# 420               Dairy                                     In-State
# 456           Non-dairy                                     In-State
# 476           Non-dairy                                     In-State
# 480               Dairy                                 Out-of-State
# 484               Dairy                                     In-State
# 485               Dairy                                 Out-of-State
# 496               Dairy                                     In-State
# 497           Non-dairy                                     In-State
# 500           Non-dairy                                     In-State
# 510               Dairy                                     In-State
# 514               Dairy                                 Out-of-State
# 529               Dairy                                     In-State
# 530               Dairy                                 Out-of-State
# 540               Dairy                                 Out-of-State
# 543               Dairy                                     In-State
# 546               Dairy                                 Out-of-State
# 561               Dairy                                 Out-of-State
# 571           Non-dairy                                 Out-of-State
# 583               Dairy                                     In-State
# 599               Dairy                                     In-State
# 601               Dairy                                     In-State
# 607               Dairy                                 Out-of-State
# 608               Dairy                                     In-State
#
#     Have you watched Saltburn?  ...  \
# 6                           No  ...
# 92                         Yes  ...
# 107                         No  ...
# 115                         No  ...
# 129                         No  ...
# 130                         No  ...
# 131                         No  ...
# 134                        Yes  ...
# 145                         No  ...
# 184                         No  ...
# 212                         No  ...
# 221                        Yes  ...
# 229                         No  ...
# 251                        Yes  ...
# 266                        Yes  ...
# 276                         No  ...
# 280                         No  ...
# 281                         No  ...
# 287                         No  ...
# 299                         No  ...
# 315                         No  ...
# 316                         No  ...
# 330                         No  ...
# 331                         No  ...
# 332                         No  ...
# 341                        Yes  ...
# 355                         No  ...
# 364                        Yes  ...
# 375                         No  ...
# 387                        Yes  ...
# 417                         No  ...
# 420                         No  ...
# 456                        Yes  ...
# 476                         No  ...
# 480                         No  ...
# 484                         No  ...
# 485                        Yes  ...
# 496                         No  ...
# 497                         No  ...
# 500                         No  ...
# 510                        Yes  ...
# 514                         No  ...
# 529                        Yes  ...
# 530                         No  ...
# 540                         No  ...
# 543                         No  ...
# 546                        Yes  ...
# 561                         No  ...
# 571                         No  ...
# 583                         No  ...
# 599                        Yes  ...
# 601                        Yes  ...
# 607                         No  ...
# 608                        Yes  ...
#
#     Besides the US, what country would you like to live in?  \
# 6                                                China
# 92                                             Iceland
# 107                                        Switzerland
# 115                                            Ireland
# 129                                         Singapore
# 130                                              China
# 131                                             Mexico
# 134       middle east, so like kuwait oman bahrain etc
# 145                                        Switzerland
# 184                                             Mexico
# 212                                      In your heart
# 221                                              china
# 229                                              India
# 251                                            Thiland
# 266                                            Denmark
# 276                                             Canada
# 280                                        New Zealand
# 281                                              China
# 287                                             mexico
# 299                                              China
# 315                                             Europe
# 316                                              China
# 330                                             Mexico
# 331                                             India
# 332                                        New Zealand
# 341                                              Dubai
# 355                                             Taiwan
# 364                                             Canada
# 375                                             sweden
# 387                                       New Zealand
# 417                                              japan
# 420                                             Europe
# 456                                              Italy
# 476                                             europe
# 480                                    The Netherlands
# 484                                            England
# 485                                             China
# 496                                              China
# 497                                             Europe
# 500                                            Romania
# 510                                              china
# 514                                              China
# 529                                            vietnam
# 530                                        South Korea
# 540                                        Switzerland
# 543                                             Canada
# 546                                             Mexico
# 561                                              Paris
# 571                                              China
# 583                                         Australia
# 599                                              italy
# 601                                              India
# 607                                             Taiwan
# 608                                              India
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 6                          Chipotle                               Home
# 92                         chopstix                       main library
# 107                  Raising Cane's                        My bedroom
# 115                          miazas                       Reading Room
# 129                            yogi                           grainger
# 130                           Iken                                 CIF
# 131                      oozu ramen                             Libary
# 134                    bangkok thai                   iSchool building
# 145               Mid-Summer lounge                          Starbucks
# 184                           Canes                               Dorm
# 212                        Sakanaya                      main libarary
# 221                             isr                       main library
# 229                        Chipotle                       My apartment
# 251                              no                               dorm
# 266                      Oozu Ramen           Siebel Center for Design
# 276                  Shawarma Joint                       Study Lounge
# 280                        chipotle                               Biff
# 281                            iken                               home
# 287                      papa dells                                bif
# 299                              no                               Dorm
# 315                        Mia Za's                       Aces Library
# 316                             ISR                          Funk ACES
# 330                          Cane's                            My dorm
# 331                    Taco trucks                             library
# 332                       Chipotle                                 SCD
# 341                         Mia Zas                                BIF
# 355                    Bangkok Thai                       Funk Library
# 364                   Jimmy John’s                     Espresso Royale
# 375                            oozu                                BIF
# 387                          Subway                                CIF
# 417                            yogi                                cif
# 420                        Chipotle                           Grainger
# 456                        Chipotle                               Dorm
# 476                        Chipotle                                cif
# 480                              -                        Main Library
# 484                       McDonalds                            My room
# 485                           Youki                            library
# 496                    Illini Tower                   Grainger library
# 497                     Thai Fusion                              Union
# 500                        Mia Za's                        Orange Room
# 510                     spoon house                               home
# 514                    Illini Tower                            Library
# 529              pho noodle station                        coffee shop
# 530                        Evo Cafe                               Ciff
# 540                            yogi                       main library
# 543                        potbelly                       main library
# 546                           Canes                                Cif
# 561                        Sakanaya          Library- main or grainger
# 571               Mid Summer Lounge                          Cafe Bene
# 583                     Thai Fusion                            My room
# 599                     kung fu tea                       main library
# 601                            Yogi                          Dorm Room
# 607                Northern Cuisine                            My dorm
# 608                    Bangkok Thai                                CIF
#
#     What genre of music do you like the most?  \
# 6                                         Pop
# 92                                        pop
# 107                                 Synthwave
# 115                              classic rock
# 129                                       pop
# 130                                   Country
# 131                               Latin music
# 134                                 bollywood
# 145                                   Italian
# 184                                   Mexican
# 212                                       pop
# 221                                       all
# 229                                       Pop
# 251                                       pop
# 266                                       pop
# 276                                 Breakcore
# 280                                       rap
# 281                              taylor swift
# 287                                   country
# 299                              Chinese pop
# 315                           Underground Rap
# 316                                   Classic
# 330                                       RnB
# 331                                       rap
# 332                                Electronic
# 341                                   Country
# 355                                  Mandopop
# 364                                       Pop
# 375                                       rap
# 387                                       Rap
# 417                                       r&b
# 420                                       Rap
# 456                                   Country
# 476                                       rap
# 480                                Indie Rock
# 484                                 Hip - Hop
# 485                                       Rap
# 496                                 pop music
# 497                                       Rap
# 500                                   Country
# 510                                       pop
# 514                                       pop
# 529                                   country
# 530                                       Pop
# 540                                       r&b
# 543                                       pop
# 546                                   Mexican
# 561                                       NaN
# 571                                 classical
# 583                                       Pop
# 599                                     indie
# 601                                       Rap
# 607                                     J-pop
# 608                                       pop
#
#     What is your favorite school subject?  \
# 6                                   Stats
# 92                                English
# 107                               History
# 115                               History
# 129                               Stat107
# 130                              Science
# 131                            accounting
# 134                               history
# 145                   Information science
# 184                                  Math
# 212                              STAT 107
# 221                                  math
# 229                          Data Science
# 251                                    no
# 266                             chemistry
# 276                               Physics
# 280                                  math
# 281                                  Econ
# 287                                  math
# 299                                  ACCY
# 315              History / Social Science
# 316                                  STAT
# 330                               History
# 331                                  Math
# 332                               BUS 101
# 341                                  Math
# 355                                    CS
# 364                               English
# 375                                  math
# 387                                    CS
# 417                                  math
# 420                      Computer Science
# 456                                  Math
# 476                                  math
# 480                           Mathematics
# 484                                  ACCY
# 485                                  Econ
# 496                            psychology
# 497                                   Gym
# 500                          Data Science
# 510                                  math
# 514                          data science
# 529                                   art
# 530                      Computer Science
# 540                             marketing
# 543                                   art
# 546                                  Math
# 561                                  Math
# 571                               Chinese
# 583                               Science
# 599                                  math
# 601                                  STAT
# 607                                  Math
# 608                               Science
#
#     What do you think is the hardest major at UIUC?  \
# 6                                           Physics
# 92                                               CS
# 107                                              CS
# 115                          Mechanical Engineering
# 129                                              CS
# 130                                Computer Science
# 131                          Electrical Engineering
# 134                     engineering (idk which one)
# 145                                Computer science
# 184                                     Engineering
# 212                                              CS
# 221                                            math
# 229                                              CE
# 251                                              cs
# 266                            Computer Engineering
# 276                                             ECE
# 280                                         pre med
# 281                                              cs
# 287                                     engineering
# 299                                      accounting
# 315                                     Engineering
# 316                                              CS
# 330                            Chemical Engineering
# 331                                              CS
# 332                                           MECHE
# 341                                              CS
# 355                            Computer Engineering
# 364                                   Communication
# 375                                              cs
# 387                            Computer Engineering
# 417                                              cs
# 420                                             ECE
# 456                                     Engineering
# 476                                              cs
# 480                                     Mathematics
# 484                                Computer Science
# 485                               Computer scinece
# 496                                              EE
# 497                                              CS
# 500               Interdisciplinary Health Sciences
# 510                                              cs
# 514                                    data science
# 529                                              cs
# 530                                     Engineering
# 540                                              CS
# 543                                              CS
# 546                                              CS
# 561                                             NaN
# 571                                             ECE
# 583                                              CS
# 599                                              cs
# 601                             Computer Enginering
# 607                          Electrical Engineering
# 608                                              CS
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 6                             Coldplay                                WeChat
# 92                          The Weeknd                                 TikTok
# 107                       The Midnight                                Youtube
# 115                             Hozier                                Youtube
# 129                            taylor                                     ins
# 130                       Taylor Swift                                Discord
# 131                         Peso Pluma                              instagram
# 134                            aboogie                               snapchat
# 145                     Stevie Wonder                               Instagram
# 184                           Junior H                                 Tiktok
# 212                             Tswift                               snapchat
# 221                                all                                 wechat
# 229                       Harry Styles                                YouTube
# 251                             Taylor                                 wechat
# 266                            Rihanna                               Snapchat
# 276                               Yeat                              Instagram
# 280                              Kayne                               snapchat
# 281                       Taylor Swift                                 wechat
# 287                      morgan wallen                                  insta
# 299                                 Ye                                    ins
# 315                         Young Thug                              Instagram
# 316                             Talyor                                 Reddit
# 330                           Kyle Lux                              Instagram
# 331                           King von                               Snapchat
# 332                   Lost Frequencies                              INSTAGRAM
# 341                      Morgan Wallen                              Instagram
# 355                             Laufey                                YouTube
# 364                    Michael Jackson                              Instagram
# 375                         the weeknd                                 tiktok
# 387                              Drake                               Snapchat
# 417                        luke chiang                                tik tok
# 420                          Cold Play                              Instagram
# 456                      Morgan Wallen                               Snapchat
# 476                              Kanye                               Snapchat
# 480                        Hilary Hahn                              Instagram
# 484                          Lady Gaga                              Instagram
# 485                           Jay Chou                                Wechat
# 496                             JJ Lin                                 wechat
# 497                              Gunna                              Instagram
# 500                       Thomas Rhett                               Snapchat
# 510                                 ye                                 WeChat
# 514                       Travis Scott                                 wechat
# 529                       James authur                                tik tok
# 530                              Keshi                              Instagram
# 540                                 GD                                youtube
# 543                              drake                                      X
# 546                               Rauw                                  Insta
# 561                                NaN                              Instagram
# 571                          Faye Wong                                 wechat
# 583                              Drake                                 Tiktok
# 599                       Taylor swift                              pinterest
# 601                          21 Savage                              Instagram
# 607                Lilas Ikuta (Ikura)                               Facebook
# 608                              Drake                              Instagram
#
#     What is your favorite game to play (either video game or IRL)?  \
# 6                                          Hearthstone
# 92                                              Roblox
# 107                                          Ping Pong
# 115                                             Sims 4
# 129                                                TFT
# 130                                              Chess
# 131                                             Soccer
# 134                                             roblox
# 145                                               Coup
# 184                                               Fifa
# 212                                         Boom Beach
# 221                                        dying light
# 229                                              Poker
# 251                                                 cs
# 266                                   Papa's Freezeria
# 276                                           Valorant
# 280                                           baseball
# 281                                               APEX
# 287                                           fortnite
# 299                                   rock paper stone
# 315                                     Lego Star Wars
# 316                                           Palworld
# 330                                 Breath of the Wild
# 331                                    Clash of clans
# 332                                            Fallout
# 341                        Cup Pong (iMessage version)
# 355                                     Lethal Company
# 364                                     Scavenger Hunt
# 375                                               rust
# 387                                              Poker
# 417                                          minecraft
# 420                                         Basketball
# 456                                           Baseball
# 476                                               Golf
# 480                                          Voleyball
# 484                                               FIFA
# 485                                        Video game
# 496                                                TFT
# 497                                   Football Manager
# 500                                     Clash of Clans
# 510                                         video game
# 514                                           Valorant
# 529                                                tag
# 530                                  League of Legends
# 540                                               csgo
# 543                                           monopoly
# 546                                                GTA
# 561                                          Badminton
# 571                                               none
# 583                                 I don’t play games
# 599                              card against humanity
# 601                                                COD
# 607                                     Genshin Impact
# 608                                         Mario Kart
#
#     Where is your dream vacation spot?
# 6                             Maldives
# 92                            Maldives
# 107                             Hawaii
# 115                          Mountains
# 129                             Miami
# 130                            Hawaii
# 131                             Madrid
# 134                         luxembourg
# 145        Vancouver, British Columbia
# 184                             Mexico
# 212                             Hawaii
# 221                            florida
# 229                          Barcelona
# 251                              beach
# 266                      Paris, France
# 276                Mountain Hot Spring
# 280                                NaN
# 281                              China
# 287                              italy
# 299                            florida
# 315                         Costa Rica
# 316                    Hawaii US state
# 330                          Singapore
# 331                           Maldives
# 332                     Byron Bay, AUS
# 341                          Bora Bora
# 355                           Hokkaido
# 364                              Egypt
# 375                           Maldives
# 387                             Hawaii
# 417                              japan
# 420                             Hawaii
# 456                             Hawaii
# 476                          los cabos
# 480                        Scandinavia
# 484                   Spain, Barcelona
# 485                                 LA
# 496                           Ice land
# 497                             Brazil
# 500                          Naples FL
# 510                                bed
# 514                              China
# 529                              japan
# 530                              Japan
# 540                                idk
# 543                          guatamala
# 546                            Bahamas
# 561                             Greece
# 571                            Iceland
# 583                           Iceland
# 599                              italy
# 601                           Colorado
# 607                             Hawaii
# 608                               Bali
#
# [54 rows x 133 columns]

# %%
df_happy = df_hello[(df_hello[happiness_question] >= 3) & (df_hello[happiness_question] <9)]
df_happy
# Out:
#             Name Section Do you like sweet or savory food?  \
# 0    Prof. Karle     AL1                            Savory
# 1     Prof. Wade     AL1                            Savory
# 2        Raymond     Y17                            Savory
# 3          Keiji     Y13                             Sweet
# 4            Ash     Y17                             Sweet
# ..           ...     ...                               ...
# 602        Tasso     Y12                            Savory
# 603      Sathvik     Y20                            Savory
# 606     Jonathan     Y20                             Sweet
# 609       Nathan     Y17                             Sweet
# 610        Ellyn     Y2-                            Savory
#
#     Do you use Windows or Mac?  \
# 0                          Mac
# 1                      Windows
# 2                      Windows
# 3                      Windows
# 4                      Windows
# ..                         ...
# 602                    Windows
# 603                    Windows
# 606                        Mac
# 609                    Windows
# 610                        Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 0                                         Near the end
# 1                                   When it's released
# 2                                   When it's released
# 3                                   When it's released
# 4                                   When it's released
# ..                                                 ...
# 602                                       Near the end
# 603                                       Near the end
# 606                                 When it's released
# 609                                 When it's released
# 610                                       Near the end
#
#     Are you a morning person?  \
# 0        NOT a Morning Person
# 1        NOT a Morning Person
# 2              Morning Person
# 3              Morning Person
# 4        NOT a Morning Person
# ..                        ...
# 602      NOT a Morning Person
# 603      NOT a Morning Person
# 606            Morning Person
# 609            Morning Person
# 610      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                   No
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 602                                                 No
# 603                                                 No
# 606                                                 No
# 609                                                 No
# 610                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 0                 Dairy                                     In-State
# 1                 Dairy                                     In-State
# 2                 Dairy                                     In-State
# 3                 Dairy                                     In-State
# 4                 Dairy                                     In-State
# ..                  ...                                          ...
# 602               Dairy                                     In-State
# 603               Dairy                                     In-State
# 606           Non-dairy                                 Out-of-State
# 609               Dairy                                     In-State
# 610               Dairy                                 Out-of-State
#
#     Have you watched Saltburn?  ...  \
# 0                          Yes  ...
# 1                           No  ...
# 2                           No  ...
# 3                           No  ...
# 4                           No  ...
# ..                         ...  ...
# 602                        Yes  ...
# 603                         No  ...
# 606                         No  ...
# 609                         No  ...
# 610                        Yes  ...
#
#     Besides the US, what country would you like to live in?  \
# 0                                             Maldives
# 1                                              Sweeden
# 2                                                China
# 3                                                japan
# 4                                                Italy
# ..                                                 ...
# 602                                        switzerland
# 603                                              Japan
# 606                                              Japan
# 609                                             Norway
# 610                                              Korea
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 0                              Za's                      Cafe Paradiso
# 1                    Shawarma Joint                      Siebel Center
# 2                       Kung Fu BBQ                               Home
# 3                              yogi                               main
# 4                      Burrito King                      Cafe Paradiso
# ..                              ...                                ...
# 602                         mia zas                           room 102
# 603              Dave's Hot Chicken       Grainger Engineering Library
# 606                             Evo                               Dorm
# 609                       McDonalds                            Library
# 610                 Northern Cusine                                CIF
#
#     What genre of music do you like the most?  \
# 0                                         pop
# 1                                         Pop
# 2                                         RnB
# 3                                         rap
# 4                                         Pop
# ..                                        ...
# 602                                       rap
# 603                                       Rap
# 606                                       Pop
# 609                                     R & B
# 610                                       Rap
#
#     What is your favorite school subject?  \
# 0                                    math
# 1                                      CS
# 2                                 History
# 3                                    math
# 4                                   Stats
# ..                                    ...
# 602                               History
# 603                      Computer Science
# 606                               Finance
# 609                        Social Studies
# 610                               English
#
#     What do you think is the hardest major at UIUC?  \
# 0                                  Computer Science
# 1                                  Computer Science
# 2                                               ECE
# 3                                          pre med
# 4                                       Engineering
# ..                                              ...
# 602                                              CS
# 603                          Electrical Engineering
# 606                                              EE
# 609                            Computer Engineering
# 610                                        Comp Sci
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 0                         Taylor Swift                              instagram
# 1                         Taylor Swift                                YouTube
# 2                          Alan Walker                              Instagram
# 3                          post malone                                  insta
# 4           TAYLOR SWIFT!!!!!!!!!!!!!!                              Instagram
# ..                                 ...                                    ...
# 602                              drake                                  insta
# 603                        Don Toliver                              Instagram
# 606                            Yoasobi                                   Line
# 609                      Daniel Ceaser                              Instagram
# 610                        Don Toliver                                 Tiktok
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                           Code Names
# 1                                             Factorio
# 2                                            Minecraft
# 3                                      clash of clans
# 4                                              Pokemon
# ..                                                 ...
# 602                                           baseball
# 603                                              Zelda
# 606                                            Genshin
# 609                                           Fortnite
# 610                                      Hide and Seek
#
#     Where is your dream vacation spot?
# 0                             Maldives
# 1                            Mountains
# 2                                China
# 3                               greece
# 4                              Itality
# ..                                 ...
# 602                            iceland
# 603                              Japan
# 606                             Europe
# 609                      Venice, Italy
# 610                        Switzerland
#
# [519 rows x 133 columns]

# %%
df_unhappy = df_hello[df_hello[happiness_question] < 3]
df_unhappy
# Out:
#                    Name  Section Do you like sweet or savory food?  \
# 31               CA Ram      Y15                            Savory
# 78                Saint      Y13                            Savory
# 81                Anika      Y03                            Savory
# 86             CA Amaan      Y12                            Savory
# 94                Chris      Y19                            Savory
# 111               Blake      Y19                            Savory
# 126             Charley      Y08                             Sweet
# 128              Tracie      Y11                            Savory
# 169              Aditya      Y08                             Sweet
# 179                Zach      Y16                             Sweet
# 207                Chen      Y12                             Sweet
# 228               Sonia      Y03                             Sweet
# 243                  AJ      Y10                            Savory
# 264               Kaiti      Y09                            Savory
# 293               Haoyu      Y16                             Sweet
# 303              Alyssa      Y04                            Savory
# 305              Blythe      Y20                             Sweet
# 351              Steven      Y12                            Savory
# 359               Devon      Y11                             Sweet
# 399               Shaun      Y16                             Sweet
# 424             Cynthia      Y06                             Sweet
# 439              Andrew      Y18                            Savory
# 441               Jerry      Y08                             Sweet
# 462               Isaac      Y12                             Sweet
# 466        TA Chenyang   Y05 Y15                            Savory
# 483              Soumil      Y18                             Sweet
# 492  Fiyinfoluwa (fifi)      Y18                            Savory
# 503              Izhaan      Y17                            Savory
# 508             Leonard      Y08                             Sweet
# 509                judy      Y13                             Sweet
# 524     Marc Quillin Jr      Y02                            Savory
# 535                 Ben      Y05                            Savory
# 537               Yifei      Y02                             Sweet
# 553                Marc      Y15                            Savory
# 567             Neal Wu      Y19                             Sweet
# 605            LaKeisha      Y15                            Savory
#
#     Do you use Windows or Mac?  \
# 31                         Mac
# 78                     Windows
# 81                         Mac
# 86                         Mac
# 94                         Mac
# 111                    Windows
# 126                    Windows
# 128                        Mac
# 169                        Mac
# 179                    Windows
# 207                        Mac
# 228                    Windows
# 243                    Windows
# 264                        Mac
# 293                    Windows
# 303                        Mac
# 305                    Windows
# 351                    Windows
# 359                        Mac
# 399                        Mac
# 424                        Mac
# 439                    Windows
# 441                    Windows
# 462                    Windows
# 466                    Windows
# 483                        Mac
# 492                        Mac
# 503                        Mac
# 508                        Mac
# 509                    Windows
# 524                        Mac
# 535                        Mac
# 537                    Windows
# 553                    Windows
# 567                    Windows
# 605                        Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 31                                        Near the end
# 78                                  When it's released
# 81                                  When it's released
# 86                                  When it's released
# 94                                  When it's released
# 111                                 When it's released
# 126                                       Near the end
# 128                                 When it's released
# 169                                       Near the end
# 179                                 When it's released
# 207                                 When it's released
# 228                                       Near the end
# 243                                       Near the end
# 264                                       Near the end
# 293                                 When it's released
# 303                                       Near the end
# 305                                 When it's released
# 351                                 When it's released
# 359                                       Near the end
# 399                                       Near the end
# 424                                 When it's released
# 439                                       Near the end
# 441                                 When it's released
# 462                                       Near the end
# 466                                       Near the end
# 483                                       Near the end
# 492                                 When it's released
# 503                                       Near the end
# 508                                       Near the end
# 509                                 When it's released
# 524                                       Near the end
# 535                                       Near the end
# 537                                       Near the end
# 553                                       Near the end
# 567                                 When it's released
# 605                                 When it's released
#
#     Are you a morning person?  \
# 31             Morning Person
# 78       NOT a Morning Person
# 81             Morning Person
# 86             Morning Person
# 94             Morning Person
# 111      NOT a Morning Person
# 126      NOT a Morning Person
# 128      NOT a Morning Person
# 169      NOT a Morning Person
# 179            Morning Person
# 207      NOT a Morning Person
# 228      NOT a Morning Person
# 243            Morning Person
# 264            Morning Person
# 293      NOT a Morning Person
# 303      NOT a Morning Person
# 305            Morning Person
# 351            Morning Person
# 359            Morning Person
# 399      NOT a Morning Person
# 424      NOT a Morning Person
# 439      NOT a Morning Person
# 441      NOT a Morning Person
# 462      NOT a Morning Person
# 466      NOT a Morning Person
# 483      NOT a Morning Person
# 492      NOT a Morning Person
# 503      NOT a Morning Person
# 508      NOT a Morning Person
# 509            Morning Person
# 524            Morning Person
# 535      NOT a Morning Person
# 537      NOT a Morning Person
# 553      NOT a Morning Person
# 567      NOT a Morning Person
# 605      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 31                                                 Yes
# 78                                                  No
# 81                                                  No
# 86                                                 Yes
# 94                                                 Yes
# 111                                                 No
# 126                                                 No
# 128                                                Yes
# 169                                                 No
# 179                                                 No
# 207                                                 No
# 228                                                 No
# 243                                                 No
# 264                                                 No
# 293                                                Yes
# 303                                                 No
# 305                                                 No
# 351                                                 No
# 359                                                 No
# 399                                                Yes
# 424                                                Yes
# 439                                                 No
# 441                                                Yes
# 462                                                 No
# 466                                                 No
# 483                                                 No
# 492                                                 No
# 503                                                 No
# 508                                                 No
# 509                                                Yes
# 524                                                 No
# 535                                                 No
# 537                                                 No
# 553                                                 No
# 567                                                Yes
# 605                                                Yes
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 31                Dairy                                 Out-of-State
# 78                Dairy                                     In-State
# 81                Dairy                                     In-State
# 86                Dairy                                 Out-of-State
# 94                Dairy                                 Out-of-State
# 111               Dairy                                     In-State
# 126               Dairy                                     In-State
# 128               Dairy                                     In-State
# 169               Dairy                                 Out-of-State
# 179               Dairy                                     In-State
# 207           Non-dairy                                 Out-of-State
# 228               Dairy                                     In-State
# 243               Dairy                                     In-State
# 264           Non-dairy                                     In-State
# 293               Dairy                                 Out-of-State
# 303               Dairy                                     In-State
# 305               Dairy                                     In-State
# 351           Non-dairy                                     In-State
# 359               Dairy                                     In-State
# 399           Non-dairy                                 Out-of-State
# 424               Dairy                                 Out-of-State
# 439               Dairy                                 Out-of-State
# 441               Dairy                                 Out-of-State
# 462               Dairy                                     In-State
# 466               Dairy                                 Out-of-State
# 483               Dairy                                 Out-of-State
# 492               Dairy                                     In-State
# 503               Dairy                                     In-State
# 508           Non-dairy                                 Out-of-State
# 509               Dairy                                     In-State
# 524           Non-dairy                                     In-State
# 535           Non-dairy                                     In-State
# 537           Non-dairy                                 Out-of-State
# 553               Dairy                                     In-State
# 567               Dairy                                     In-State
# 605           Non-dairy                                     In-State
#
#     Have you watched Saltburn?  ...  \
# 31                          No  ...
# 78                          No  ...
# 81                         Yes  ...
# 86                          No  ...
# 94                         Yes  ...
# 111                         No  ...
# 126                         No  ...
# 128                         No  ...
# 169                         No  ...
# 179                         No  ...
# 207                         No  ...
# 228                         No  ...
# 243                         No  ...
# 264                         No  ...
# 293                        Yes  ...
# 303                         No  ...
# 305                         No  ...
# 351                         No  ...
# 359                         No  ...
# 399                         No  ...
# 424                         No  ...
# 439                         No  ...
# 441                         No  ...
# 462                         No  ...
# 466                         No  ...
# 483                         No  ...
# 492                         No  ...
# 503                         No  ...
# 508                         No  ...
# 509                        Yes  ...
# 524                        Yes  ...
# 535                         No  ...
# 537                         No  ...
# 553                         No  ...
# 567                        Yes  ...
# 605                         No  ...
#
#     Besides the US, what country would you like to live in?  \
# 31                                              Canada
# 78                                               china
# 81                                              France
# 86                                United Arab Emirates
# 94                                         philippines
# 111                                              Japan
# 126                                            Iceland
# 128                                              Korea
# 169                                        Switzerland
# 179                                             Canada
# 207                                              China
# 228                                             Europe
# 243                                              Italy
# 264                                              Spain
# 293                                              China
# 303                                            Canada
# 305                                             Mexico
# 351                                         Indonesia
# 359                                           Austria
# 399                                              Japan
# 424                                                NaN
# 439                                              China
# 441                                              China
# 462                                            Austria
# 466                                             China
# 483                                              India
# 492                                             canada
# 503                                                UAE
# 508                                                 UK
# 509                                              china
# 524                                             Canada
# 535                                              Spain
# 537                                          Australia
# 553                                             norway
# 567                                              China
# 605                                            Greece
#
#     Favorite on campus restaurant?     Favorite place to study on campus?  \
# 31                   Shawarma Joint                      Grainger Library
# 78                        Taco bell                                   ike
# 81                        Red lion                           Pi phi house
# 86                   Shawarma Joint                              Grainger
# 94                       basil thai                              grainger
# 111       Haven't eaten at any yet.                           Orange room
# 126               chinatown bufett                                my room
# 128                      Kungfu Tea                      Grainger Library
# 169                        Chipotle                                   Cif
# 179                           Canes  Gregory Hall - Communication Library
# 207                             Evo                               Library
# 228                        Chipotle                                  SDRP
# 243                          Cane’s                                Union
# 264                         Manolos                   Main library or SCD
# 293                   Panda Express                                  Home
# 303                            Yogi                                   ISR
# 305                        Chipotle                                  Dorm
# 351                  Juanitos Tacos                                   NaN
# 359                       Sakanaya                                    BIF
# 399                            Yogi                                  Funk
# 424                             NaN                                   NaN
# 439                Midsummer Lounge                          My apartment
# 441                          Cane's                                  dorm
# 462                         Cracked                      Grainger Library
# 466                  Lao shez Chuan                               Office
# 483                   Panda Express                          illini tower
# 492                        kofusion                                  dorm
# 503                         Bangkok                                   CIF
# 508                    bei wei xuan                                  dorm
# 509                       mcdonalds                                   612
# 524                        ChopStix                   Engineering library
# 535                         Bangkok                                   bif
# 537                        Sushiman                          Main library
# 553             Haven’t been to any                               My dorm
# 567                             老四川                                  home
# 605                        Juanitos                                   CIF
#
#     What genre of music do you like the most?  \
# 31                                      K-Pop
# 78                                        Pop
# 81                                        EDM
# 86                                    Hip hop
# 94                                  classical
# 111                                Electronic
# 126                                      rock
# 128                                Pop/Ballad
# 169                                     House
# 179                                     J-Pop
# 207                                       Pop
# 228                                     Indie
# 243                                       Pop
# 264                                  Alt rock
# 293                                    Hiphop
# 303                                       Rap
# 305                                  Corridos
# 351                                 Post Punk
# 359                                   R and b
# 399                                   Hip-hop
# 424                                       NaN
# 439                                       Rap
# 441                               Countryside
# 462                                      Jazz
# 466                                       Pop
# 483                                      Sad
# 492                                       sad
# 503                                 Bollywood
# 508                                   popular
# 509                                       rap
# 524                                   Hip-Hop
# 535                                    indie
# 537                                 pop music
# 553                                       Rap
# 567                                       pop
# 605                                   Hip hop
#
#     What is your favorite school subject?  \
# 31                            Mathematics
# 78                                history
# 81                           Art history
# 86                                     CS
# 94                                   math
# 111                      Computer Science
# 126                                  Math
# 128                                  MATH
# 169                                  Math
# 179                         World History
# 207                               STAT107
# 228                              English?
# 243                                  Math
# 264                                  Math
# 293                                  Accy
# 303                                  Math
# 305                                  Math
# 351                               History
# 359                              Business
# 399                                  Iken
# 424                                   NaN
# 439                            Accounting
# 441                       basketball game
# 462                                  Math
# 466                                 Math
# 483                               Science
# 492                                 Psych
# 503                                    CS
# 508                        micro economic
# 509                                  math
# 524                            Calculus 2
# 535                                  accy
# 537                                   art
# 553                                  Math
# 567                                  clcv
# 605                                   Idk
#
#     What do you think is the hardest major at UIUC?  \
# 31                                          Physics
# 78                                               cs
# 81                                         Physics
# 86                             Computer Engineering
# 94                                               CS
# 111                           Aerospace Engineering
# 126                                            NPRE
# 128                                         History
# 169                            Computer Engineering
# 179                                    Biochemistry
# 207                                            MATH
# 228                                Computer Science
# 243                            PhD in Swiftie-ology
# 264                                              CS
# 293                                              CS
# 303                                              CS
# 305                                     Engineering
# 351                                    Engineering
# 359                                              CS
# 399                                             ECE
# 424                                             NaN
# 439                                              CS
# 441                        Computer Science or Math
# 462                                             Law
# 466                                     Statistics
# 483                                        Business
# 492                                           Stats
# 503                                         Finance
# 508                                              cs
# 509                                              cs
# 524                                Computer Science
# 535                                        Comp Sci
# 537                                              CS
# 553                                             CS?
# 567                                        business
# 605                                         Physics
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 31                            Newjeans                                Discord
# 78                         nle choppa                                  tiktok
# 81                          Dj khaled                                Linkedin
# 86                           21 Savage                              Instagram
# 94                           new jeans                                 reddit
# 111                               Lorn                                 reddit
# 126                         Billy Joel                           none of them
# 128                               Many                                Youtube
# 169                              Drake                               Snapchat
# 179                       NBA Youngboy                                Youtube
# 207                           Jay Chou                                 WeChat
# 228                             Hozier                              Instagram
# 243                     Olivia rodrigo                                  Insta
# 264                         Twin Peaks                              Instagram
# 293                           Jay Chou                                 Tiktok
# 303                         The Weeknd                               tik tok
# 305                        Kevin Kaarl                                 TikTok
# 351                       Joy Division                                    NaN
# 359                       Lana del rey                                TikTok
# 399                                SZA                              Instagram
# 424                                NaN                                    NaN
# 439                             Eminem                                 Wechat
# 441                       Taylor Swift                                 WeChat
# 462                           Coldplay                              Instagram
# 466                           Jay Chow                                WeChat
# 483                       Arijit Singh                                SnapchT
# 492                      lana del rey                                  tiktok
# 503                           Pitbull                                Snapchat
# 508                       joe hisaishi                                 wechat
# 509                                 ye                                 wechat
# 524                     Kendrick Lamar                                 TikTok
# 535                         Peach Pit                                 Twitter
# 537                       Lana del ray                              Instagram
# 553                                JID                                 Tiktok
# 567                                 jb                                 WeChat
# 605                                Idk                                TikTok
#
#     What is your favorite game to play (either video game or IRL)?  \
# 31                                           Football
# 78                                           spikeball
# 81                                         Irish poker
# 86                                            Football
# 94                                      phoenix wright
# 111                                    Team Fortress 2
# 126                                       dark souls 3
# 128                                     Arena of Valor
# 169                                               Fifa
# 179                            Call Of Duty - Zombies
# 207                                                LOL
# 228                                              Mafia
# 243                                           Baseball
# 264                                          Minecraft
# 293                                              Video
# 303                                           Valorant
# 305                                        Candy Crush
# 351                                            Skate 3
# 359                                                NaN
# 399                                       Call of duty
# 424                                                NaN
# 439                                         Victoria 3
# 441                                              CS:GO
# 462                                               Risk
# 466                                          Splatoon
# 483                                            Cricket
# 492                                  plants vs zombies
# 503                                           Fortnite
# 508                                       subway scoot
# 509                                              video
# 524                                             Skyrim
# 535                                         Basketball
# 537                                The legend of Zelda
# 553                                        Valorant rn
# 567                                               王者荣耀
# 605                                              WiiU
#
#     Where is your dream vacation spot?
# 31                               Dubai
# 78                           hong kong
# 81          Antarctica (drake passage)
# 86                           Bora Bora
# 94                              manila
# 111                               Maui
# 126                             Alaska
# 128                              Paris
# 169                              Aruba
# 179                             Hawaii
# 207                           Maldives
# 228                              Italy
# 243                            Iceland
# 264                          Barcelona
# 293                              Aspen
# 303                        Switzerland
# 305                               Mars
# 351                         New Mexico
# 359                            Mexico
# 399                               Cuba
# 424                            Corsica
# 439                              Swiss
# 441                            Iceland
# 462                             Greece
# 466                                Idk
# 483                            Mykonos
# 492                            Jamaica
# 503                             Turkey
# 508                           shanghai
# 509                                bed
# 524                    Turks and cacos
# 535           Overwater bungalow (any)
# 537                              Italy
# 553                Traveling the world
# 567                            Chengdu
# 605                          Bora Bora
#
# [36 rows x 133 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert(len(df_very_happy) == 54 ), "Double check your conditional used to create df_very_happy."
assert(len(df_happy) == 519 ), "Double check your conditional used to create df_happy."
assert(len(df_unhappy) == 36 ), "Double check your conditional used to create df_unhappy."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Puzzle 2.2: Average Phone Battery Percentage by Group
#
# Now find the **average phone battery percentage** of each group (`df_very_happy`, `df_happy`, and `df_unhappy`):
#
# - The `df['column name'].mean()` function returns the mean of all values in the specified column of `df`.
# - The `phone_battery_question` question has been provided to you as a **string** for ease of DataFrame column access.

# %%
phone_battery_question = 'What is your phone battery percentage currently at?'

very_happy_people_avg_phone_battery = df_very_happy[phone_battery_question].mean()
very_happy_people_avg_phone_battery
# Out:
# 56.96296296296296

# %%
happy_people_avg_phone_battery = df_happy[phone_battery_question].mean()
happy_people_avg_phone_battery
# Out:
# 59.335907335907336

# %%
unhappy_people_avg_phone_battery = df_unhappy[phone_battery_question].mean()
unhappy_people_avg_phone_battery
# Out:
# 56.02777777777778

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert(math.isclose(very_happy_people_avg_phone_battery,  56.96296296296296)), "The average phone battery percentage for very happy people does not appear to have been correctly calculated."
assert(math.isclose(happy_people_avg_phone_battery,  59.335907335907336)), "The average phone battery percentage for happy people does not appear to have been correctly calculated."
assert(math.isclose(unhappy_people_avg_phone_battery,  56.02777777777778)), "The average phone battery percentage for unhappy people does not appear to have been correctly calculated."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ### Analysis: Happiness vs. Phone Battery

# %% [markdown]
# **Q: What is the relationship between happiness and phone battery?  Can you think of a possible *confounding variable* in the observed relationship (or lack thereof) between happiness and phone battery?**  Write at least three complete sentences that includes:
# - Your analysis of the relationship between the two variables,
# - Your third, possibly confounding, variable that might be impacting the results, **AND**
# - Your analysis on why this third variable could be a possible confounder.
# - Any additional analysis on other variables or possible confounders.

# %% [markdown]
# The results of the variables indicate that happy people tend to have higher battery percentages. A third confounding variable could be the fact that the battery life on someone who is unhappy is very low and bad contributing to the low battery. they might be happy and their battery is low but it does not necessarily mean that they are unhappy.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
