# %% [markdown]
# # Welcome to Lab: Experimental Design 👨‍🔬⚗️🧪
#
# Before this lab section, you completed the "Hello Survey" based on the questions you generated with your groups.  This week, you will do an analysis of the results and explore techniques to do great experimental design in Python!
#
# A few tips to remember:
#
# - **You are not alone on your journey in learning programming!**  You have your lab Teaching Assistant, your Course Aides, your lab group, and the professors (Prof. Wade and Prof. Karle), who are all here to help you out!
# - If you find yourself stuck for more than a few minutes, ask a neighbor or course staff for help!  When you are giving help to your neighbor, explain the **idea and approach** to the problem without sharing the answer itself so they can have the same **<i>ah-hah</i>** moment!
# - We are here to help you!  Don't feel embarrassed or shy to ask us for help!
#
# Let's get started!

# %% [markdown]
# <hr style="color: #DD3403;">

# %%
# Meet your CAs and TA if you haven't already!
# ...first name is enough, we'll know who they are! :)
ta_name = "Peng"
ca1_name = "Qiran"
ca2_name = "Sophia"
ca3_name = ""

# Say hello to each other!
# - Groups of 3 are ideal :)
# - However groups of 2 or 4 are fine too!
partner1_name = "sofia"
partner1_netid = "sofia5"
partner1_inYourGroupLastWeek = "yes"

partner2_name = "jennifer"
partner2_netid = "jarreci2"
partner2_inYourGroupLastWeek = "yes"

partner3_name = "shivani"
partner3_netid = "sr80"
partner3_inYourGroupLastWeek = "yes"

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 1: Hello Dataset Analysis
#
# In lab last week, you created a series of questions that made up the **"Hello Dataset"**.  Before lab, you completed this survey along with the entire course.  Today, you're going to do analysis on this dataset! :)

# %% [markdown]
# ## Your Binary Question Analysis
#
# You will be analyzing the **binary question** your group asked the class from `lab_pandas` -- record it below.  If multiple people from your group had different binary questions, decide which one to use and record that question below.

# %% [markdown]
# *(✏️even or odd✏️)*

# %% [markdown]
# ## Load the Hello Dataset
#
# The "Hello Dataset" is available here:
# ```
# https://waf.cs.illinois.edu/discovery/hello-sp24.csv
# ```
#
# Use Python to load this dataset into a DataFrame called `df` -- and **don't forget to import pandas**! :)

# %%
import pandas as pd

# %%
df = pd.read_csv("https://waf.cs.illinois.edu/discovery/hello-sp24.csv")
df
# Out:
#             Name Section Do you like sweet or savory food?  \
# 0    Prof. Karle     AL1                            Savory
# 1     Prof. Wade     AL1                            Savory
# 2        Raymond     Y17                            Savory
# 3          Keiji     Y13                             Sweet
# 4            Ash     Y17                             Sweet
# ..           ...     ...                               ...
# 571       CA Xin     Y!!                             Sweet
# 572       Sayuj      Y08                             Sweet
# 573         Jack     Y11                            Savory
# 574        Hanna     Y08                            Savory
# 575       Rayhan     Y17                            Savory
#
#     Do you use Windows or Mac?  \
# 0                          Mac
# 1                      Windows
# 2                      Windows
# 3                      Windows
# 4                      Windows
# ..                         ...
# 571                        Mac
# 572                    Windows
# 573                    Windows
# 574                        Mac
# 575                    Windows
#
#     Do you like doing your homework when it's released or in the end?  \
# 0                                         Near the end
# 1                                   When it's released
# 2                                   When it's released
# 3                                   When it's released
# 4                                   When it's released
# ..                                                 ...
# 571                                       Near the end
# 572                                 When it's released
# 573                                       Near the end
# 574                                 When it's released
# 575                                       Near the end
#
#     Are you a morning person?  \
# 0        NOT a Morning Person
# 1        NOT a Morning Person
# 2              Morning Person
# 3              Morning Person
# 4        NOT a Morning Person
# ..                        ...
# 571            Morning Person
# 572            Morning Person
# 573      NOT a Morning Person
# 574            Morning Person
# 575      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                   No
# 3                                                  Yes
# 4                                                   No
# ..                                                 ...
# 571                                                Yes
# 572                                                Yes
# 573                                                 No
# 574                                                 No
# 575                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 0                 Dairy                                     In-State
# 1                 Dairy                                     In-State
# 2                 Dairy                                     In-State
# 3                 Dairy                                     In-State
# 4                 Dairy                                     In-State
# ..                  ...                                          ...
# 571           Non-dairy                                 Out-of-State
# 572               Dairy                                 Out-of-State
# 573               Dairy                                     In-State
# 574           Non-dairy                                     In-State
# 575               Dairy                                     In-State
#
#     Have you watched Saltburn?  ...  \
# 0                          Yes  ...
# 1                           No  ...
# 2                           No  ...
# 3                           No  ...
# 4                           No  ...
# ..                         ...  ...
# 571                         No  ...
# 572                        Yes  ...
# 573                        Yes  ...
# 574                        Yes  ...
# 575                         No  ...
#
#     Besides the US, what country would you like to live in?  \
# 0                                             Maldives
# 1                                              Sweeden
# 2                                                China
# 3                                                japan
# 4                                                Italy
# ..                                                 ...
# 571                                              China
# 572                                             India
# 573                                        Netherlands
# 574                                         Australia
# 575                                                 UK
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 0                              Za's                      Cafe Paradiso
# 1                    Shawarma Joint                      Siebel Center
# 2                       Kung Fu BBQ                               Home
# 3                              yogi                               main
# 4                      Burrito King                      Cafe Paradiso
# ..                              ...                                ...
# 571               Mid Summer Lounge                          Cafe Bene
# 572                       Taco bell                               Cif
# 573                    Bangkok Thai                       ACES Library
# 574   I haven't really tried many!                    Expresso Royale
# 575                  Shawarma Joint                            Library
#
#     What genre of music do you like the most?  \
# 0                                         pop
# 1                                         Pop
# 2                                         RnB
# 3                                         rap
# 4                                         Pop
# ..                                        ...
# 571                                 classical
# 572                                       Rap
# 573                              Classic Rock
# 574                                      Kpop
# 575                                      Rap
#
#     What is your favorite school subject?  \
# 0                                    math
# 1                                      CS
# 2                                 History
# 3                                    math
# 4                                   Stats
# ..                                    ...
# 571                               Chinese
# 572                                  Math
# 573                                   Art
# 574                                 Stats
# 575                                   Gym
#
#     What do you think is the hardest major at UIUC?  \
# 0                                  Computer Science
# 1                                  Computer Science
# 2                                               ECE
# 3                                          pre med
# 4                                       Engineering
# ..                                              ...
# 571                                             ECE
# 572                               Computer science
# 573                                Computer Science
# 574                                         Physics
# 575                                        Comp Sci
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 0                         Taylor Swift                              instagram
# 1                         Taylor Swift                                YouTube
# 2                          Alan Walker                              Instagram
# 3                          post malone                                  insta
# 4           TAYLOR SWIFT!!!!!!!!!!!!!!                              Instagram
# ..                                 ...                                    ...
# 571                          Faye Wong                                 wechat
# 572                           Coldplay                                  Insta
# 573                        The Beatles                               Snapchat
# 574                          Seventeen                                 TikTok
# 575                       Travis Scott                              Instagram
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                           Code Names
# 1                                             Factorio
# 2                                            Minecraft
# 3                                      clash of clans
# 4                                              Pokemon
# ..                                                 ...
# 571                                               none
# 572                                          Fortnite
# 573                                  Settlers of Catan
# 574                                        Lego Batman
# 575                                           Football
#
#     Where is your dream vacation spot?
# 0                             Maldives
# 1                            Mountains
# 2                                China
# 3                               greece
# 4                              Itality
# ..                                 ...
# 571                            Iceland
# 572                          Maldives
# 573                         Swiss Alps
# 574                        Switzerland
# 575                    Northern Lights
#
# [576 rows x 133 columns]

# %% [markdown]
# ## Find The Variable for Your Question
#
# The command `df.columns.tolist()` will **list all of the columns (variables)** in a DataFrame.  Use `df.columns.tolist()` and read the output until you find the column name for your binary question.
#
# - You may see the message: `Output exceeds the __size limit__. Open the full output data __in a text editor__`
# - If you do, click the **`__in a text editor__`** link to open the whole list in a new tab. :)

# %%
df.columns.tolist()
# Out:
# ['Name',
#  'Section',
#  'Do you like sweet or savory food?',
#  'Do you use Windows or Mac?',
#  "Do you like doing your homework when it's released or in the end?",
#  'Are you a morning person?',
#  'Are you following the data science duo on Instagram? @datascienceduo',
#  'Dairy or non-dairy?',
#  'Are you an In-State or Out-of-State student?',
#  'Have you watched Saltburn?',
#  "In the last lecture, did you sit on the left side or the right of the lecture room (if you're facing Karle and Wade)?",
#  'KAMS (Key Axioms in Mathematical Statistics) or LION (Linearly Independent Orthogonal Nullspaces)',
#  'Cool Ranch Doritos or Nacho Cheese Doritos? ',
#  'Do you like math or not?',
#  'Chocolate or Vanilla Ice Cream?',
#  'Flip a coin, is it heads or tails?',
#  'Did you live in the six-pack/IKE your freshman year?',
#  'Do you prefer pizza or burgers?',
#  'Are you an introvert or extrovert?',
#  'Do you prefer coffee or tea?',
#  'Check the time -- is it even or odd?',
#  'Do you prefer waffles or pancakes?',
#  'Do you prefer to wear dark colors or light colors?',
#  'What came first, the chicken or the egg?',
#  'Do you prefer Taylor Swift or Beyoncé?',
#  'Do you prefer shows or movies?',
#  'Are you a Swiftie?',
#  'Is water wet?',
#  'Do you like pineapple on pizza?',
#  'Do you prefer Home Alone 1 or Home Alone 2?',
#  'Do you prefer salty or sweet snacks?',
#  'Do you think there are more doors or wheels in the world?',
#  'Do you prefer summer or winter?',
#  'Would you rather the super power of invisibility or of reading minds?',
#  'Did you go to DISCOVERY on Friday?',
#  'Out of these 2 numbers which one do you like more? 239,238,134,821 or 239,238,124,821?',
#  'Is your major in the college of LAS?',
#  'Are you from the greater Chicagoland area?',
#  'Do you have a pet?',
#  'Did you watch SpongeBob growing up?',
#  'Is this your first year in college?',
#  'What is scarier: Snakes or Spiders?',
#  'Pick one A or B?',
#  'American Football or Basketball?',
#  'Are you male?',
#  'Do you like Barbie or Oppenheimer more?',
#  'Do you prefer Spring or Fall?',
#  'McDonalds or Burger King?',
#  'What type of weather do you prefer, hot or cold?',
#  'Do you prefer Pop or Hip-Hop music?',
#  'Is DISCOVERY hard?',
#  'What is your favorite baseball team?',
#  'Are all of your class buildings on the main quad?',
#  'Do you prefer red or blue?',
#  'Do you prefer Dr. Pepper or Pepsi?',
#  'Coke or Pepsi? ',
#  'Does your UIN end in an even or odd number?',
#  'Do you prefer eating chicken or beef?',
#  'Have you attend a football game in UIUC?',
#  'Do you like breakfast or lunch better?',
#  'Which number do you like more, 3 or 5?',
#  'Is DISCOVERY required for you?',
#  'Do you prefer Ketchup or Mustard?',
#  'Statistics or Computer Science',
#  'Is the dress debate from 2015 blue/black or white/gold?  (Search "the dress" to find the picture if you don\'t remember it!)',
#  'Do you prefer the color black or white?',
#  'Do you have a birthday in the first 6 month or the last 6 months?',
#  'Do you prefer spicy or sweet food?',
#  'Do you prefer tacos or burgers?',
#  'Would you rather drink coke or sprite for the rest of your life?',
#  'Do you prefer Christmas or Halloween?',
#  'Would you rather be able to forget your worst memory or be able to remember your best memory better?',
#  'Would you rather attend classes in the morning or in the afternoon?',
#  'Would you rather drive or be the passenger?',
#  'Are you a morning or night person?',
#  'Do you like iced or hot coffee?',
#  'Do you like your dad more or your mom more?',
#  'Do you prefer Italian food or Mexican food?',
#  'Do you have hair long hair?',
#  'Light mode or dark mode?',
#  'Do you prefer cool colors or warm colors?',
#  'Do you listen to music on your way to classes?',
#  'Do you have a job?',
#  'Is math red or blue?',
#  'Would you prefer group work or solo work?',
#  'Do you prefer pop or rap music?',
#  'Do you prefer math or english more?',
#  'Do you prefer coffee or milk? ',
#  'Do you like dogs?',
#  'Were you born in China?',
#  'Do you like exercising?',
#  'Are you a statistics major?',
#  'Where you born in 2004? ',
#  'Do you prefer books or movies?',
#  'Do you prefer pasta or pizza?',
#  'Is your weekly STAT107 lab session before or after 10:55 am on Thursday?',
#  'Are you in Gies or trying to get into Gies?',
#  'Dark Chocolate or Milk Chocolate?',
#  'Starbucks or Dunkin?',
#  'Do you live a dorm?',
#  'Do you prefer apple juice or orange juice?',
#  'Do you like ice cream in winter?',
#  'Do you sleep more than 7 hours a night?',
#  'Do you need a prescription to see?',
#  'Do you play games?',
#  'Apples or pears?',
#  'Do you plan to double major?',
#  'Are you an international student or a domestic student?',
#  'Do you prefer to sit in the front or the back of a class?',
#  'Do you prefer Nike or Adidas?',
#  'Do you take the bus to class?',
#  'Do you prefer in-person or online classes? ',
#  'Do you prefer the zoo or the aquarium?',
#  'How many classes are you taking this semester?',
#  'How many credit hours are you taking?',
#  'How many hours do you sleep in a night?',
#  'How many siblings do you have?',
#  'Pick a number between 1 and 10. ',
#  'What is your shoe size (US size)?',
#  'How many cups (8 oz.) of water do you drink a day?',
#  'From 1 to 10, how happy are you right now?',
#  'How many people is the ideal number of people at a party?',
#  'What is your phone battery percentage currently at?',
#  'Besides the US, what country would you like to live in?',
#  'Favorite on campus restaurant? ',
#  'Favorite place to study on campus?',
#  'What genre of music do you like the most?',
#  'What is your favorite school subject?',
#  'What do you think is the hardest major at UIUC?',
#  'Who is your favorite music artist?',
#  "What's your favorite social media app?",
#  'What is your favorite game to play (either video game or IRL)?',
#  'Where is your dream vacation spot?']

# %% [markdown]
# ## Record the Variable for Your Question
#
# In the cell below, record your question's column name as a **string** variable named `analysis_column`.  You'll need that exact column name to reference data from that cell.

# %%
analysis_column =  "Do you prefer Italian food or Mexican food?"
analysis_column
# Out:
# 'Do you prefer Italian food or Mexican food?'

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert('df' in vars()), "You do not have a DataFrame called `df`."
assert(len(df) >= 576 and len(df) < 700), "You have not loaded the correct Hello Dataset."
assert(analysis_column in df), "Make certain your analysis_column string is EXACTLY as it appears in the Hello Dataset."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Column Subset: View Only Your Question's Responses
#
# To begin your question's analysis, you first want to **focus only on your question**.  In lecture, we have primarily focused on creating subsets of rows. However, you can also create a subset of columns!
#
# To create a DataFrame with just a single column, you can use the syntax:
# ```
# df[ ["column name"] ]
# ```
# - Notice the **double set of square brackets**.  You need the outer set for `df`, and the inner set for the column name.
# - Because we've already loaded your question into `analysis_column`, you won't need the quotation marks this time.
# - You can find this syntax under the "Subset Variables (Columns)" on your Pandas cheat sheet!
#
# With the `analysis_column` variable from above, use Python to display only the column you're analyzing.  This will make it easy to see what the two options were for your question:

# %%
df[[analysis_column]]
# Out:
#     Do you prefer Italian food or Mexican food?
# 0                                  Mexican Food
# 1                                  Mexican Food
# 2                                  Mexican Food
# 3                                  Italian Food
# 4                                  Mexican Food
# ..                                          ...
# 571                                Mexican Food
# 572                                Mexican Food
# 573                                Italian Food
# 574                                Mexican Food
# 575                                Mexican Food
#
# [576 rows x 1 columns]

# %% [markdown]
# ## DataFrame: Group One
#
# Create a DataFrame, `df1`, that contains everyone who picked the first option of your two answers.  *(Make sure to make this a subset of the original `df`, and not just your one column.)*

# %%
df1 = df[df["Do you prefer Italian food or Mexican food?"] == "Italian Food"]
df1
# Out:
#            Name   Section Do you like sweet or savory food?  \
# 3         Keiji       Y13                             Sweet
# 7     CA Alyssa       Y07                             Sweet
# 12    Shubhayon       Y19                            Savory
# 19       Priyal       Y10                            Savory
# 24         Zach       Y11                             Sweet
# ..          ...       ...                               ...
# 565      Vishal       Y18                            Savory
# 566    Aakanksh       Y07                            Savory
# 567     Neal Wu       Y19                             Sweet
# 569  TA Shuning  Y06, Y12                            Savory
# 573        Jack       Y11                            Savory
#
#     Do you use Windows or Mac?  \
# 3                      Windows
# 7                          Mac
# 12                     Windows
# 19                     Windows
# 24                         Mac
# ..                         ...
# 565                    Windows
# 566                        Mac
# 567                    Windows
# 569                        Mac
# 573                    Windows
#
#     Do you like doing your homework when it's released or in the end?  \
# 3                                   When it's released
# 7                                         Near the end
# 12                                  When it's released
# 19                                        Near the end
# 24                                  When it's released
# ..                                                 ...
# 565                                       Near the end
# 566                                 When it's released
# 567                                 When it's released
# 569                                       Near the end
# 573                                       Near the end
#
#     Are you a morning person?  \
# 3              Morning Person
# 7              Morning Person
# 12       NOT a Morning Person
# 19       NOT a Morning Person
# 24             Morning Person
# ..                        ...
# 565            Morning Person
# 566            Morning Person
# 567      NOT a Morning Person
# 569      NOT a Morning Person
# 573      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 3                                                  Yes
# 7                                                  Yes
# 12                                                  No
# 19                                                  No
# 24                                                  No
# ..                                                 ...
# 565                                                 No
# 566                                                 No
# 567                                                Yes
# 569                                                 No
# 573                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 3                 Dairy                                     In-State
# 7             Non-dairy                                     In-State
# 12                Dairy                                 Out-of-State
# 19                Dairy                                 Out-of-State
# 24                Dairy                                     In-State
# ..                  ...                                          ...
# 565               Dairy                                     In-State
# 566               Dairy                                 Out-of-State
# 567               Dairy                                     In-State
# 569               Dairy                                 Out-of-State
# 573               Dairy                                     In-State
#
#     Have you watched Saltburn?  ...  \
# 3                           No  ...
# 7                          Yes  ...
# 12                          No  ...
# 19                          No  ...
# 24                          No  ...
# ..                         ...  ...
# 565                        Yes  ...
# 566                        Yes  ...
# 567                        Yes  ...
# 569                         No  ...
# 573                        Yes  ...
#
#     Besides the US, what country would you like to live in?  \
# 3                                                japan
# 7                                              england
# 12                                                 NaN
# 19                                              France
# 24                                              Canada
# ..                                                 ...
# 565                                        Switzerland
# 566                                              India
# 567                                              China
# 569                                       Switzerland
# 573                                        Netherlands
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 3                              yogi                               main
# 7                      bangkok thai                       main library
# 12                              NaN                          Dorm room
# 19                             Naya                            My room
# 24                      Kung Fu Tea                            My room
# ..                              ...                                ...
# 565                        Chopstix                                CIF
# 566                        Chipotle                                Hoe
# 567                             老四川                               home
# 569                            yogi                  Graniger Library
# 573                    Bangkok Thai                       ACES Library
#
#     What genre of music do you like the most?  \
# 3                                         rap
# 7                                         pop
# 12                                        NaN
# 19                                Dance music
# 24                                        Pop
# ..                                        ...
# 565                                       R&B
# 566                                       R&B
# 567                                       pop
# 569                                     k-pop
# 573                              Classic Rock
#
#     What is your favorite school subject?  \
# 3                                    math
# 7                              statistics
# 12                                   Math
# 19                               Accounts
# 24                         Social Studies
# ..                                    ...
# 565                                  math
# 566                                  Math
# 567                                  clcv
# 569                               history
# 573                                   Art
#
#     What do you think is the hardest major at UIUC?  \
# 3                                          pre med
# 7                                               ece
# 12                                              ECE
# 19                                               CS
# 24                                      Engineering
# ..                                              ...
# 565                                        CS+Stats
# 566                          Mechanical Engineering
# 567                                        business
# 569                                              CS
# 573                                Computer Science
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 3                          post malone                                  insta
# 7                        one direction                                twitter
# 12                                 NaN                                Twitter
# 19                        Taylor Swift                              Instagram
# 24                                 WWE                                YouTube
# ..                                 ...                                    ...
# 565                         Tory Lanez                                Twitter
# 566                        Chris Brown                              Instagram
# 567                                 jb                                 WeChat
# 569                          blackpink                                 WeChat
# 573                        The Beatles                               Snapchat
#
#     What is your favorite game to play (either video game or IRL)?  \
# 3                                      clash of clans
# 7                                       stardew valley
# 12                                         Basketball
# 19                                                 GTA
# 24                                              Soccer
# ..                                                 ...
# 565                                           Fortnite
# 566                                               FIFA
# 567                                               王者荣耀
# 569                                   Goose Goose Duck
# 573                                  Settlers of Catan
#
#     Where is your dream vacation spot?
# 3                               greece
# 7                                japan
# 12                                 NaN
# 19                               Paris
# 24               San Diego, California
# ..                                 ...
# 565                               Bali
# 566                              Miami
# 567                            Chengdu
# 569                               Fuji
# 573                         Swiss Alps
#
# [295 rows x 133 columns]

# %% [markdown]
# ## DataFrame: Group Two
#
# Create a new DataFrame, `df2`, that contains everyone who picked the other answer:

# %%
df2 = df[df["Do you prefer Italian food or Mexican food?"] == "Mexican Food"]
df2
# Out:
#             Name   Section Do you like sweet or savory food?  \
# 0    Prof. Karle       AL1                            Savory
# 1     Prof. Wade       AL1                            Savory
# 2        Raymond       Y17                            Savory
# 4            Ash       Y17                             Sweet
# 5      CA Sophia       Y02                            Savory
# ..           ...       ...                               ...
# 570   CA Jessica  Y05, Y18                             Sweet
# 571       CA Xin       Y!!                             Sweet
# 572       Sayuj        Y08                             Sweet
# 574        Hanna       Y08                            Savory
# 575       Rayhan       Y17                            Savory
#
#     Do you use Windows or Mac?  \
# 0                          Mac
# 1                      Windows
# 2                      Windows
# 4                      Windows
# 5                          Mac
# ..                         ...
# 570                        Mac
# 571                        Mac
# 572                    Windows
# 574                        Mac
# 575                    Windows
#
#     Do you like doing your homework when it's released or in the end?  \
# 0                                         Near the end
# 1                                   When it's released
# 2                                   When it's released
# 4                                   When it's released
# 5                                   When it's released
# ..                                                 ...
# 570                                 When it's released
# 571                                       Near the end
# 572                                 When it's released
# 574                                 When it's released
# 575                                       Near the end
#
#     Are you a morning person?  \
# 0        NOT a Morning Person
# 1        NOT a Morning Person
# 2              Morning Person
# 4        NOT a Morning Person
# 5              Morning Person
# ..                        ...
# 570      NOT a Morning Person
# 571            Morning Person
# 572            Morning Person
# 574            Morning Person
# 575      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 0                                                  Yes
# 1                                                  Yes
# 2                                                   No
# 4                                                   No
# 5                                                  Yes
# ..                                                 ...
# 570                                                Yes
# 571                                                Yes
# 572                                                Yes
# 574                                                 No
# 575                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 0                 Dairy                                     In-State
# 1                 Dairy                                     In-State
# 2                 Dairy                                     In-State
# 4                 Dairy                                     In-State
# 5             Non-dairy                                     In-State
# ..                  ...                                          ...
# 570               Dairy                                 Out-of-State
# 571           Non-dairy                                 Out-of-State
# 572               Dairy                                 Out-of-State
# 574           Non-dairy                                     In-State
# 575               Dairy                                     In-State
#
#     Have you watched Saltburn?  ...  \
# 0                          Yes  ...
# 1                           No  ...
# 2                           No  ...
# 4                           No  ...
# 5                          Yes  ...
# ..                         ...  ...
# 570                         No  ...
# 571                         No  ...
# 572                        Yes  ...
# 574                        Yes  ...
# 575                         No  ...
#
#     Besides the US, what country would you like to live in?  \
# 0                                             Maldives
# 1                                              Sweeden
# 2                                                China
# 4                                                Italy
# 5                                               Greece
# ..                                                 ...
# 570                                        Switzerland
# 571                                              China
# 572                                             India
# 574                                         Australia
# 575                                                 UK
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 0                              Za's                      Cafe Paradiso
# 1                    Shawarma Joint                      Siebel Center
# 2                       Kung Fu BBQ                               Home
# 4                      Burrito King                      Cafe Paradiso
# 5                       thai fusion                                CIF
# ..                              ...                                ...
# 570                    Bangkok Thai                       My apartment
# 571               Mid Summer Lounge                          Cafe Bene
# 572                       Taco bell                               Cif
# 574   I haven't really tried many!                    Expresso Royale
# 575                  Shawarma Joint                            Library
#
#     What genre of music do you like the most?  \
# 0                                         pop
# 1                                         Pop
# 2                                         RnB
# 4                                         Pop
# 5                                   pop/indie
# ..                                        ...
# 570                                 Indie Pop
# 571                                 classical
# 572                                       Rap
# 574                                      Kpop
# 575                                      Rap
#
#     What is your favorite school subject?  \
# 0                                    math
# 1                                      CS
# 2                                 History
# 4                                   Stats
# 5                                    Math
# ..                                    ...
# 570                               Science
# 571                               Chinese
# 572                                  Math
# 574                                 Stats
# 575                                   Gym
#
#     What do you think is the hardest major at UIUC?  \
# 0                                  Computer Science
# 1                                  Computer Science
# 2                                               ECE
# 4                                       Engineering
# 5                                              ECE
# ..                                              ...
# 570                            Computer Engineering
# 571                                             ECE
# 572                               Computer science
# 574                                         Physics
# 575                                        Comp Sci
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 0                         Taylor Swift                              instagram
# 1                         Taylor Swift                                YouTube
# 2                          Alan Walker                              Instagram
# 4           TAYLOR SWIFT!!!!!!!!!!!!!!                              Instagram
# 5                      Phoebe Bridgers                              Instagram
# ..                                 ...                                    ...
# 570                        Post Malone                              Instagram
# 571                          Faye Wong                                 wechat
# 572                           Coldplay                                  Insta
# 574                          Seventeen                                 TikTok
# 575                       Travis Scott                              Instagram
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                           Code Names
# 1                                             Factorio
# 2                                            Minecraft
# 4                                              Pokemon
# 5                                             Fortnite
# ..                                                 ...
# 570                                           Splendor
# 571                                               none
# 572                                          Fortnite
# 574                                        Lego Batman
# 575                                           Football
#
#     Where is your dream vacation spot?
# 0                             Maldives
# 1                            Mountains
# 2                                China
# 4                              Itality
# 5                               Greece
# ..                                 ...
# 570                        Switzerland
# 571                            Iceland
# 572                          Maldives
# 574                        Switzerland
# 575                    Northern Lights
#
# [277 rows x 133 columns]

# %% [markdown]
# ## Analysis
#
# Discuss the following questions with your group and then write down your response!

# %% [markdown]
# **Q1: What percentage of people chose each of your two binary options?**

# %% [markdown]
# 295 people out of 576 chose Italian Food and 277 people out of 576 chose Mexicn Food.

# %% [markdown]
# **Q2: Did this surprise you? Why or why not? Write at least one complete sentence.**

# %% [markdown]
# Not really, I think both foods are liked by a lot of people which explains why it is semi 50/50.

# %% [markdown]
# **Q3: Do you think your question was the closest to a perfect 50/50 split among the whole class?**

# %% [markdown]
# Maybe.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# ## Part 2: Creating Treatment and Control Groups
#
# For the rest of this lab, we will consider the "Hello Dataset" to be a pre-survey of randomly selected participants for an upcoming experiment.  In lecture, you learned that a good experiment will split the participants into two groups: the "treatment" group and the "control" group.
#
# Recall that it is necessary to have both groups:
#
# - The "control" group is a comparison group that will receive a placebo and will act as a control to ensure that the treatment has an effect.
# - The "treatment" group will receive a treatment and we will look for differences between the results of this treatment group and the control group.

# %% [markdown]
# ## Part 2.1: Select a Treatment Group
#
# **Randomly** select half (50%) of the participants from our original `df` to be in the treatment group and place them into a DataFrame called `treatment`.
# - Remember, you can ask your CAs, TAs, or use your **pandas cheat sheet** to help you out!

# %%
treatment = df.sample(frac = 0.50)
treatment
# Out:
#           Name Section Do you like sweet or savory food?  \
# 147     Akshaj     Y04                             Sweet
# 116      Aidan     Y19                            Savory
# 61       Bala      Y04                             Sweet
# 187       Sara     Y01                            Savory
# 12   Shubhayon     Y19                            Savory
# ..         ...     ...                               ...
# 62     Mansha      Y07                             Sweet
# 475     Zeshun     Y05                            Savory
# 22       Akash     Y08                            Savory
# 567    Neal Wu     Y19                             Sweet
# 11   Christian     Y13                             Sweet
#
#     Do you use Windows or Mac?  \
# 147                        Mac
# 116                        Mac
# 61                     Windows
# 187                    Windows
# 12                     Windows
# ..                         ...
# 62                         Mac
# 475                        Mac
# 22                         Mac
# 567                    Windows
# 11                         Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 147                                 When it's released
# 116                                       Near the end
# 61                                        Near the end
# 187                                 When it's released
# 12                                  When it's released
# ..                                                 ...
# 62                                  When it's released
# 475                                 When it's released
# 22                                  When it's released
# 567                                 When it's released
# 11                                        Near the end
#
#     Are you a morning person?  \
# 147            Morning Person
# 116            Morning Person
# 61             Morning Person
# 187      NOT a Morning Person
# 12       NOT a Morning Person
# ..                        ...
# 62       NOT a Morning Person
# 475      NOT a Morning Person
# 22       NOT a Morning Person
# 567      NOT a Morning Person
# 11       NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 147                                                 No
# 116                                                 No
# 61                                                  No
# 187                                                 No
# 12                                                  No
# ..                                                 ...
# 62                                                  No
# 475                                                Yes
# 22                                                  No
# 567                                                Yes
# 11                                                  No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 147               Dairy                                     In-State
# 116               Dairy                                     In-State
# 61                Dairy                                     In-State
# 187           Non-dairy                                     In-State
# 12                Dairy                                 Out-of-State
# ..                  ...                                          ...
# 62            Non-dairy                                     In-State
# 475               Dairy                                     In-State
# 22                Dairy                                 Out-of-State
# 567               Dairy                                     In-State
# 11                Dairy                                     In-State
#
#     Have you watched Saltburn?  ...  \
# 147                         No  ...
# 116                         No  ...
# 61                          No  ...
# 187                         No  ...
# 12                          No  ...
# ..                         ...  ...
# 62                         Yes  ...
# 475                        Yes  ...
# 22                         Yes  ...
# 567                        Yes  ...
# 11                          No  ...
#
#     Besides the US, what country would you like to live in?  \
# 147                                              spain
# 116                                            Germany
# 61                                                  UK
# 187                                        New Zealand
# 12                                                 NaN
# ..                                                 ...
# 62                                              The Uk
# 475                                              china
# 22                                           Australia
# 567                                              China
# 11                                             England
#
#             Favorite on campus restaurant?   \
# 147                              Oozu Ramen
# 116                          Schwarma Joint
# 61                              Oozu Ramen
# 187                                Shawarma
# 12                                      NaN
# ..                                      ...
# 62   Jimmy John’s hits the spot every time
# 475                                      no
# 22                                 Chipotle
# 567                                     老四川
# 11                                 Chipotle
#
#     Favorite place to study on campus?  \
# 147                         Union Cafe
# 116                       Reading Room
# 61                        Main Library
# 187                           Grainger
# 12                           Dorm room
# ..                                 ...
# 62         Illini union colonial room
# 475                            library
# 22                          My Room :)
# 567                               home
# 11                             My dorm
#
#     What genre of music do you like the most?  \
# 147                                      Rock
# 116                                     Indie
# 61                                        Pop
# 187                                     Indie
# 12                                        NaN
# ..                                        ...
# 62                             Sped up songs
# 475                                       pop
# 22                                    Hip-Hop
# 567                                       pop
# 11                                        Rap
#
#     What is your favorite school subject?  \
# 147                                  Math
# 116                            Philosophy
# 61                                English
# 187                                  Math
# 12                                   Math
# ..                                    ...
# 62                                     PE
# 475                                  math
# 22                       Machine Learning
# 567                                  clcv
# 11                                History
#
#     What do you think is the hardest major at UIUC?  \
# 147                           Physical + Math minor
# 116                                             ECE
# 61                                     CS + Physics
# 187                                         Physics
# 12                                              ECE
# ..                                              ...
# 62                          Electrical engineering
# 475                                            math
# 22                             Computer Engineering
# 567                                        business
# 11                                      Engineering
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 147                            Rihanna                                Youtube
# 116                            Mt. Joy                              Instagram
# 61                          Renee Rapp                                Tik Tok
# 187                       Taylor Swift                                 TikTok
# 12                                 NaN                                Twitter
# ..                                 ...                                    ...
# 62                     Chase Atlantic                              Instagram
# 475                             jj lin                                    ins
# 22                          Juice WRLD                              Instagram
# 567                                 jb                                 WeChat
# 11                              Polo G                                Tik Tok
#
#     What is your favorite game to play (either video game or IRL)?  \
# 147                             Cards against Humanity
# 116                                             Madden
# 61                                          Mario Kart
# 187                                             Skyrim
# 12                                         Basketball
# ..                                                 ...
# 62                                         Hate games
# 475                                                tft
# 22                                        MLB The Show
# 567                                               王者荣耀
# 11                                                FIFA
#
#     Where is your dream vacation spot?
# 147                        New Zealand
# 116                        New Zealand
# 61                              France
# 187                        New Zealand
# 12                                 NaN
# ..                                 ...
# 62                              Paris
# 475                             Hawaii
# 22                     Florence, Italy
# 567                            Chengdu
# 11                              Taiwan
#
# [288 rows x 133 columns]

# %% [markdown]
# ## Part 2.2: Select a Control Group
#
# Using the **exact same technique and syntax** as you did above, also randomly select half (50%) of the participants to be in the control group.  Place them into a DataFrame called `control`. For now, it's okay if there are people who are in both groups.

# %%
control = df.sample(frac = 0.50)
control
# Out:
#              Name  Section Do you like sweet or savory food?  \
# 426         Randy      Y11                            Savory
# 115         Emily      Y03                            Savory
# 190          Zach      Y15                            Savory
# 325         Lucia      Y11                            Savory
# 378         Irene      Y12                            Savory
# ..            ...      ...                               ...
# 466  TA Chenyang   Y05 Y15                            Savory
# 301        Henrik      Y20                            Savory
# 522           Yue      Y15                            Savory
# 370          Hans      Y06                            Savory
# 140        Yongbo      Y03                            Savory
#
#     Do you use Windows or Mac?  \
# 426                        Mac
# 115                        Mac
# 190                    Windows
# 325                        Mac
# 378                        Mac
# ..                         ...
# 466                    Windows
# 301                    Windows
# 522                    Windows
# 370                    Windows
# 140                    Windows
#
#     Do you like doing your homework when it's released or in the end?  \
# 426                                 When it's released
# 115                                 When it's released
# 190                                 When it's released
# 325                                       Near the end
# 378                                       Near the end
# ..                                                 ...
# 466                                       Near the end
# 301                                       Near the end
# 522                                       Near the end
# 370                                 When it's released
# 140                                 When it's released
#
#     Are you a morning person?  \
# 426      NOT a Morning Person
# 115      NOT a Morning Person
# 190            Morning Person
# 325            Morning Person
# 378      NOT a Morning Person
# ..                        ...
# 466      NOT a Morning Person
# 301      NOT a Morning Person
# 522            Morning Person
# 370            Morning Person
# 140            Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 426                                                 No
# 115                                                 No
# 190                                                Yes
# 325                                                Yes
# 378                                                 No
# ..                                                 ...
# 466                                                 No
# 301                                                 No
# 522                                                Yes
# 370                                                Yes
# 140                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 426               Dairy                                     In-State
# 115               Dairy                                     In-State
# 190               Dairy                                     In-State
# 325               Dairy                                     In-State
# 378               Dairy                                     In-State
# ..                  ...                                          ...
# 466               Dairy                                 Out-of-State
# 301               Dairy                                     In-State
# 522               Dairy                                 Out-of-State
# 370               Dairy                                     In-State
# 140               Dairy                                 Out-of-State
#
#     Have you watched Saltburn?  ...  \
# 426                         No  ...
# 115                         No  ...
# 190                         No  ...
# 325                         No  ...
# 378                         No  ...
# ..                         ...  ...
# 466                         No  ...
# 301                         No  ...
# 522                         No  ...
# 370                        Yes  ...
# 140                         No  ...
#
#     Besides the US, what country would you like to live in?  \
# 426                                             Mexico
# 115                                            Ireland
# 190                                              japan
# 325                                              Japan
# 378                                             france
# ..                                                 ...
# 466                                             China
# 301                                        Switzerland
# 522                                              Japan
# 370                                             Sweden
# 140                                        New Zealand
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 426                        Chipotle                   Empty classrooms
# 115                          miazas                       Reading Room
# 190                    bangkok thai                       my apartment
# 325                   Raising Canes                   Grainger Library
# 378                        chipotle                                cif
# ..                              ...                                ...
# 466                  Lao shez Chuan                            Office
# 301                  Shawarma Joint                            My dorm
# 522                Northern Cuisine                       Main Library
# 370                        Chipotle                   Grainger Library
# 140                   Lao Sze Chuan                        In the dorm
#
#     What genre of music do you like the most?  \
# 426                                       EDM
# 115                              classic rock
# 190                                       pop
# 325                                 Pop music
# 378                                       pop
# ..                                        ...
# 466                                       Pop
# 301                                      Rock
# 522                                     R & B
# 370                                       Rap
# 140                     New Music (ニューミュージック)
#
#     What is your favorite school subject?  \
# 426                                  Math
# 115                               History
# 190                                  math
# 325                           Mathematics
# 378                              economic
# ..                                    ...
# 466                                 Math
# 301                               Finance
# 522                               Chinese
# 370                                  Math
# 140                              STAT 107
#
#     What do you think is the hardest major at UIUC?  \
# 426                                        Mech Eng
# 115                          Mechanical Engineering
# 190                                              cs
# 325             Electrical and Computer Engineering
# 378                                    neuroscience
# ..                                              ...
# 466                                     Statistics
# 301                Plasma Track Nuclear Engineering
# 522                                Computer Science
# 370                          Bio molecular science
# 140                                     Mathematics
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 426                           Junior H                               Snapchat
# 115                             Hozier                                Youtube
# 190                                AJR                               snapchat
# 325                     Kendrick Lamar                              Instagram
# 378                              keshi                              instagram
# ..                                 ...                                    ...
# 466                           Jay Chow                                WeChat
# 301                          Radiohead                              Instagram
# 522                       Hikaru Utada                            Xiaohongshu
# 370                       travis scott                               Snapchat
# 140                   Nakashima Miyuki                                 WeChat
#
#     What is your favorite game to play (either video game or IRL)?  \
# 426                                       Black Ops II
# 115                                             Sims 4
# 190                                         volleyball
# 325                                        Brawl Stars
# 378                                   i dont play game
# ..                                                 ...
# 466                                          Splatoon
# 301                                             Soccer
# 522                                                IRL
# 370                                             Tennis
# 140                                     Genshin Impact
#
#     Where is your dream vacation spot?
# 426                          Rotterdam
# 115                          Mountains
# 190                              japan
# 325                              Japan
# 378                           Maldives
# ..                                 ...
# 466                                Idk
# 301                    South of France
# 522                               Rome
# 370                   Chamonix, France
# 140                         Strasbourg
#
# [288 rows x 133 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any error in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( len(treatment) == len(control) ), "The `treatment` and `control` groups must be the same size."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`."
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Overlapping Selection?
#
# The following code will detect rows that are **both in your treatment and control** groups.
#
# Run the following cell to see everyone who is in both groups:

# %%
df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]
# Out:
#            Name   Section Do you like sweet or savory food?  \
# 1    Prof. Wade       AL1                            Savory
# 8        Prisha       Y10                            Savory
# 11    Christian       Y13                             Sweet
# 12    Shubhayon       Y19                            Savory
# 27       Andrew       Y14                            Savory
# ..          ...       ...                               ...
# 558    Aaryanna       Y05                            Savory
# 562      Shreni       Y14                            Savory
# 567     Neal Wu       Y19                             Sweet
# 570  CA Jessica  Y05, Y18                             Sweet
# 575      Rayhan       Y17                            Savory
#
#     Do you use Windows or Mac?  \
# 1                      Windows
# 8                          Mac
# 11                         Mac
# 12                     Windows
# 27                     Windows
# ..                         ...
# 558                        Mac
# 562                        Mac
# 567                    Windows
# 570                        Mac
# 575                    Windows
#
#     Do you like doing your homework when it's released or in the end?  \
# 1                                   When it's released
# 8                                         Near the end
# 11                                        Near the end
# 12                                  When it's released
# 27                                        Near the end
# ..                                                 ...
# 558                                 When it's released
# 562                                       Near the end
# 567                                 When it's released
# 570                                 When it's released
# 575                                       Near the end
#
#     Are you a morning person?  \
# 1        NOT a Morning Person
# 8        NOT a Morning Person
# 11       NOT a Morning Person
# 12       NOT a Morning Person
# 27       NOT a Morning Person
# ..                        ...
# 558            Morning Person
# 562      NOT a Morning Person
# 567      NOT a Morning Person
# 570      NOT a Morning Person
# 575      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 1                                                  Yes
# 8                                                  Yes
# 11                                                  No
# 12                                                  No
# 27                                                  No
# ..                                                 ...
# 558                                                 No
# 562                                                Yes
# 567                                                Yes
# 570                                                Yes
# 575                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 1                 Dairy                                     In-State
# 8                 Dairy                                     In-State
# 11                Dairy                                     In-State
# 12                Dairy                                 Out-of-State
# 27                Dairy                                     In-State
# ..                  ...                                          ...
# 558           Non-dairy                                     In-State
# 562               Dairy                                     In-State
# 567               Dairy                                     In-State
# 570               Dairy                                 Out-of-State
# 575               Dairy                                     In-State
#
#     Have you watched Saltburn?  ...  \
# 1                           No  ...
# 8                           No  ...
# 11                          No  ...
# 12                          No  ...
# 27                          No  ...
# ..                         ...  ...
# 558                         No  ...
# 562                         No  ...
# 567                        Yes  ...
# 570                         No  ...
# 575                         No  ...
#
#     Besides the US, what country would you like to live in?  \
# 1                                              Sweeden
# 8                                                Italy
# 11                                             England
# 12                                                 NaN
# 27                                              Canada
# ..                                                 ...
# 558                                             Europe
# 562                                             France
# 567                                              China
# 570                                        Switzerland
# 575                                                 UK
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 1                    Shawarma Joint                      Siebel Center
# 8                   Signature Grill                   Grainger Library
# 11                         Chipotle                            My dorm
# 12                              NaN                          Dorm room
# 27                           Culala                            My room
# ..                              ...                                ...
# 558                     Ambar India                  Friends apartment
# 562                        Chipotle                                Cif
# 567                             老四川                               home
# 570                    Bangkok Thai                       My apartment
# 575                  Shawarma Joint                            Library
#
#     What genre of music do you like the most?  \
# 1                                         Pop
# 8                                         Rap
# 11                                        Rap
# 12                                        NaN
# 27                                        EDM
# ..                                        ...
# 558                                    Reggae
# 562                                       pop
# 567                                       pop
# 570                                 Indie Pop
# 575                                      Rap
#
#     What is your favorite school subject?  \
# 1                                      CS
# 8                                    Math
# 11                                History
# 12                                   Math
# 27                                   Math
# ..                                    ...
# 558                 English Language Arts
# 562                                    CS
# 567                                  clcv
# 570                               Science
# 575                                   Gym
#
#     What do you think is the hardest major at UIUC?  \
# 1                                  Computer Science
# 8                            Electrical Engineering
# 11                                      Engineering
# 12                                              ECE
# 27                                 Computer science
# ..                                              ...
# 558                                    Neuroscience
# 562                                              CS
# 567                                        business
# 570                            Computer Engineering
# 575                                        Comp Sci
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 1                         Taylor Swift                                YouTube
# 8                                Drake                              Instagram
# 11                              Polo G                                Tik Tok
# 12                                 NaN                                Twitter
# 27                         Rush garcia                                Youtube
# ..                                 ...                                    ...
# 558                         Bob Marley                                    NaN
# 562                         The Weeknd                                Tik tok
# 567                                 jb                                 WeChat
# 570                        Post Malone                              Instagram
# 575                       Travis Scott                              Instagram
#
#     What is your favorite game to play (either video game or IRL)?  \
# 1                                             Factorio
# 8                                                World
# 11                                                FIFA
# 12                                         Basketball
# 27                                     Project zomboid
# ..                                                 ...
# 558                                         Basketball
# 562                                                NaN
# 567                                               王者荣耀
# 570                                           Splendor
# 575                                           Football
#
#     Where is your dream vacation spot?
# 1                            Mountains
# 8                                Italy
# 11                              Taiwan
# 12                                 NaN
# 27                                 Bed
# ..                                 ...
# 558                             Hawaii
# 562                           Maldives
# 567                            Chengdu
# 570                        Switzerland
# 575                    Northern Lights
#
# [144 rows x 133 columns]

# %% [markdown]
# **Q4: Why would your code result in some people being included in both groups? Write at least one complete sentence explaining why you think this might occur.**

# %% [markdown]
# Since it is randomly selected from the same sample group, the code could select the same person twice.

# %% [markdown]
# ## Part 2.3:
#
# Read the following guide on **using `.index.isin` to select all rows from a DataFrame not in another DataFrame**: https://discovery.cs.illinois.edu/guides/DataFrame-Row-Selection/dataframe-isin-selection/
#
# Finally, create a new `control` group that contains all of the participants from `df` that are not in `treatment`:

# %%
control = df[ ~df.index.isin(treatment.index) ]
control
# Out:
#             Name Section Do you like sweet or savory food?  \
# 0    Prof. Karle     AL1                            Savory
# 3          Keiji     Y13                             Sweet
# 4            Ash     Y17                             Sweet
# 7      CA Alyssa     Y07                             Sweet
# 13        Isaiah     Y02                             Sweet
# ..           ...     ...                               ...
# 566     Aakanksh     Y07                            Savory
# 568        Jiaqi     Y19                               NaN
# 571       CA Xin     Y!!                             Sweet
# 573         Jack     Y11                            Savory
# 574        Hanna     Y08                            Savory
#
#     Do you use Windows or Mac?  \
# 0                          Mac
# 3                      Windows
# 4                      Windows
# 7                          Mac
# 13                         Mac
# ..                         ...
# 566                        Mac
# 568                        Mac
# 571                        Mac
# 573                    Windows
# 574                        Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 0                                         Near the end
# 3                                   When it's released
# 4                                   When it's released
# 7                                         Near the end
# 13                                  When it's released
# ..                                                 ...
# 566                                 When it's released
# 568                                 When it's released
# 571                                       Near the end
# 573                                       Near the end
# 574                                 When it's released
#
#     Are you a morning person?  \
# 0        NOT a Morning Person
# 3              Morning Person
# 4        NOT a Morning Person
# 7              Morning Person
# 13       NOT a Morning Person
# ..                        ...
# 566            Morning Person
# 568            Morning Person
# 571            Morning Person
# 573      NOT a Morning Person
# 574            Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 0                                                  Yes
# 3                                                  Yes
# 4                                                   No
# 7                                                  Yes
# 13                                                  No
# ..                                                 ...
# 566                                                 No
# 568                                                 No
# 571                                                Yes
# 573                                                 No
# 574                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 0                 Dairy                                     In-State
# 3                 Dairy                                     In-State
# 4                 Dairy                                     In-State
# 7             Non-dairy                                     In-State
# 13                Dairy                                     In-State
# ..                  ...                                          ...
# 566               Dairy                                 Out-of-State
# 568               Dairy                                 Out-of-State
# 571           Non-dairy                                 Out-of-State
# 573               Dairy                                     In-State
# 574           Non-dairy                                     In-State
#
#     Have you watched Saltburn?  ...  \
# 0                          Yes  ...
# 3                           No  ...
# 4                           No  ...
# 7                          Yes  ...
# 13                          No  ...
# ..                         ...  ...
# 566                        Yes  ...
# 568                         No  ...
# 571                         No  ...
# 573                        Yes  ...
# 574                        Yes  ...
#
#     Besides the US, what country would you like to live in?  \
# 0                                             Maldives
# 3                                                japan
# 4                                                Italy
# 7                                              england
# 13                                              France
# ..                                                 ...
# 566                                              India
# 568                                              China
# 571                                              China
# 573                                        Netherlands
# 574                                         Australia
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 0                              Za's                      Cafe Paradiso
# 3                              yogi                               main
# 4                      Burrito King                      Cafe Paradiso
# 7                      bangkok thai                       main library
# 13                      Mcdonald’s                             My room
# ..                              ...                                ...
# 566                        Chipotle                                Hoe
# 568                             IKE                       Main library
# 571               Mid Summer Lounge                          Cafe Bene
# 573                    Bangkok Thai                       ACES Library
# 574   I haven't really tried many!                    Expresso Royale
#
#     What genre of music do you like the most?  \
# 0                                         pop
# 3                                         rap
# 4                                         Pop
# 7                                         pop
# 13                                        Rap
# ..                                        ...
# 566                                       R&B
# 568                                   hip-hop
# 571                                 classical
# 573                              Classic Rock
# 574                                      Kpop
#
#     What is your favorite school subject?  \
# 0                                    math
# 3                                    math
# 4                                   Stats
# 7                              statistics
# 13                                  Stats
# ..                                    ...
# 566                                  Math
# 568                            Psychology
# 571                               Chinese
# 573                                   Art
# 574                                 Stats
#
#     What do you think is the hardest major at UIUC?  \
# 0                                  Computer Science
# 3                                          pre med
# 4                                       Engineering
# 7                                               ece
# 13                                         Comp Sci
# ..                                              ...
# 566                          Mechanical Engineering
# 568                                              CS
# 571                                             ECE
# 573                                Computer Science
# 574                                         Physics
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 0                         Taylor Swift                              instagram
# 3                          post malone                                  insta
# 4           TAYLOR SWIFT!!!!!!!!!!!!!!                              Instagram
# 7                        one direction                                twitter
# 13                              J Cole                                Twitter
# ..                                 ...                                    ...
# 566                        Chris Brown                              Instagram
# 568                              G.E.M                                 WeChat
# 571                          Faye Wong                                 wechat
# 573                        The Beatles                               Snapchat
# 574                          Seventeen                                 TikTok
#
#     What is your favorite game to play (either video game or IRL)?  \
# 0                                           Code Names
# 3                                      clash of clans
# 4                                              Pokemon
# 7                                       stardew valley
# 13                                          Basketball
# ..                                                 ...
# 566                                               FIFA
# 568                                      King of Glory
# 571                                               none
# 573                                  Settlers of Catan
# 574                                        Lego Batman
#
#     Where is your dream vacation spot?
# 0                             Maldives
# 3                               greece
# 4                              Itality
# 7                                japan
# 13                              Brazil
# ..                                 ...
# 566                              Miami
# 568                           Maldives
# 571                            Iceland
# 573                         Swiss Alps
# 574                        Switzerland
#
# [288 rows x 133 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df' in vars() ), "You do not have a DataFrame called `df`."
assert( 'treatment' in vars() ), "You do not have a DataFrame called `treatment`."
assert( 'control' in vars() ), "You do not have a DataFrame called `control`."
assert( abs((len(df) / 2) - len(treatment)) <= 1 ), "The `treatment` group size must be 50% of the `df`."
assert( abs((len(df) / 2) - len(control)) <= 1 ), "The `control` group size must be 50% of the `df`."
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 2.4: Finding Yourself!
#
# Use the following cells to write Python code to find yourself in either the treatment group or control group.
# - **Hint**: How do you select a subset of rows?  What conditional will identify you??
# - If you did not fill out the "Hello Survey" then you are not in this dataset. :(
# - If you are not in this survey, find either "Prof. Wade" or "Prof. Karle" instead.  *(Those are the names we used in the `Name` column.)*

# %%
# Use this cell to find yourself in either `treatment` or `control` groups:

x = treatment[(treatment.Name == "Liz") & (treatment.Section == "Y02")]
y = control[(control.Name == "Liz") & (control.Section == "Y02")]
y



# ...feel free to add extra "Code" cells here if needed.
# Out:
#     Name Section Do you like sweet or savory food? Do you use Windows or Mac?  \
# 362  Liz     Y02                            Savory                        Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 362                                       Near the end
#
#     Are you a morning person?  \
# 362      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 362                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 362           Non-dairy                                     In-State
#
#     Have you watched Saltburn?  ...  \
# 362                        Yes  ...
#
#     Besides the US, what country would you like to live in?  \
# 362                                             Mexico
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 362                             NaN                    psych building
#
#     What genre of music do you like the most?  \
# 362                                       NaN
#
#     What is your favorite school subject?  \
# 362                                  Math
#
#     What do you think is the hardest major at UIUC?  \
# 362                                             NaN
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 362                                NaN                                    NaN
#
#     What is your favorite game to play (either video game or IRL)?  \
# 362                                                NaN
#
#     Where is your dream vacation spot?
# 362                                NaN
#
# [1 rows x 133 columns]

# %% [markdown]
# ## Analysis: Finding Yourself!
#
# **Q5: Which group where you in -- treatment or control?**

# %% [markdown]
# I am in the control group

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Part 3: Using Blocking to Create Treatment and Control Groups that are Balanced
#
# In your pre-experiment research, you have reason to believe that how the participants answer **your group's question** might influence the response of this experiment!  Oh no! Even though this is a large sample of participants, we want to block to be absolutely sure that the treatment and control groups are balanced with regard to your group's question!
#
# To control for this, we will using **blocking**!  Remember from lecture that blocking refers to creating subgroups for each response, selecting equal-sized treatment and control groups from each block, and then combining all the treatment groups together and all the control groups together to get the final groups. This ensures that your groups are balanced with regard to the variable you blocked on!
#
# You have already done some of this work:
# - Earlier in this notebook, you created `df1` that includes everyone who answered your group's question one way.
# - Earlier in this notebook, you created `df2` that includes everyone who answered your group's question the other way.

# %% [markdown]
# ## Part 3.1:
#
# Create a `df1_treatment` group that contains a random selection of 50% of the rows from `df1`.

# %%
df1_treatment = df1.sample(frac = 0.50)
df1_treatment
# Out:
#        Name Section Do you like sweet or savory food?  \
# 463  Aanya      Y05                            Savory
# 462   Isaac     Y12                             Sweet
# 448  Jennie     Y16                            Savory
# 140  Yongbo     Y03                            Savory
# 258  Runduo     Y01                             Sweet
# ..      ...     ...                               ...
# 246    Josh     Y18                             Sweet
# 224    Zeki     Y16                            Savory
# 326  Robert     Y16                             Sweet
# 207    Chen     Y12                             Sweet
# 34     Amba     Y06                             Sweet
#
#     Do you use Windows or Mac?  \
# 463                    Windows
# 462                    Windows
# 448                        Mac
# 140                    Windows
# 258                        Mac
# ..                         ...
# 246                        Mac
# 224                    Windows
# 326                    Windows
# 207                        Mac
# 34                     Windows
#
#     Do you like doing your homework when it's released or in the end?  \
# 463                                       Near the end
# 462                                       Near the end
# 448                                 When it's released
# 140                                 When it's released
# 258                                 When it's released
# ..                                                 ...
# 246                                 When it's released
# 224                                 When it's released
# 326                                       Near the end
# 207                                 When it's released
# 34                                  When it's released
#
#     Are you a morning person?  \
# 463            Morning Person
# 462      NOT a Morning Person
# 448      NOT a Morning Person
# 140            Morning Person
# 258      NOT a Morning Person
# ..                        ...
# 246      NOT a Morning Person
# 224      NOT a Morning Person
# 326            Morning Person
# 207      NOT a Morning Person
# 34       NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 463                                                Yes
# 462                                                 No
# 448                                                 No
# 140                                                 No
# 258                                                 No
# ..                                                 ...
# 246                                                 No
# 224                                                 No
# 326                                                 No
# 207                                                 No
# 34                                                  No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 463           Non-dairy                                     In-State
# 462               Dairy                                     In-State
# 448           Non-dairy                                 Out-of-State
# 140               Dairy                                 Out-of-State
# 258           Non-dairy                                 Out-of-State
# ..                  ...                                          ...
# 246               Dairy                                 Out-of-State
# 224               Dairy                                     In-State
# 326               Dairy                                     In-State
# 207           Non-dairy                                 Out-of-State
# 34                Dairy                                     In-State
#
#     Have you watched Saltburn?  ...  \
# 463                         No  ...
# 462                         No  ...
# 448                         No  ...
# 140                         No  ...
# 258                         No  ...
# ..                         ...  ...
# 246                         No  ...
# 224                         No  ...
# 326                         No  ...
# 207                         No  ...
# 34                          No  ...
#
#     Besides the US, what country would you like to live in?  \
# 463                                            Canada
# 462                                            Austria
# 448                                           Vietnam
# 140                                        New Zealand
# 258                                              dutch
# ..                                                 ...
# 246                                          Singapore
# 224                                              Dubai
# 326                                                 UK
# 207                                              China
# 34                                         Netherlands
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 463                   Nando Milano                      Caffe Paradiso
# 462                         Cracked                   Grainger Library
# 448                     Pho station                                CIF
# 140                   Lao Sze Chuan                        In the dorm
# 258                   raising canes                         gg library
# ..                              ...                                ...
# 246                        chipotle                       Main library
# 224                        Chipotle     The study rooms in Nugent Hall
# 326                         Mia Zas                            My Room
# 207                             Evo                            Library
# 34                          teamoji                               dorm
#
#     What genre of music do you like the most?  \
# 463                                  Hip-hop
# 462                                      Jazz
# 448                                       Pop
# 140                     New Music (ニューミュージック)
# 258                                       pop
# ..                                        ...
# 246                                       pop
# 224                                       Rap
# 326                                       Rap
# 207                                       Pop
# 34                                Alternative
#
#     What is your favorite school subject?  \
# 463                         Data Science
# 462                                  Math
# 448                                  Math
# 140                              STAT 107
# 258                                  math
# ..                                    ...
# 246                                  Math
# 224                                  Math
# 326                                  Math
# 207                               STAT107
# 34                                english
#
#     What do you think is the hardest major at UIUC?  \
# 463                                    Engineering
# 462                                             Law
# 448                                              CS
# 140                                     Mathematics
# 258                                              cs
# ..                                              ...
# 246                                             ECE
# 224                                Computer Science
# 326                                      Statistics
# 207                                            MATH
# 34                                      engineering
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 463                        Kanye West                               Instagram
# 462                           Coldplay                              Instagram
# 448                           Jungkook                              Instagram
# 140                   Nakashima Miyuki                                 WeChat
# 258                       Taylor Swift                                    ins
# ..                                 ...                                    ...
# 246                       Taylor Swift                                 tiktok
# 224                             Drake                               Instagram
# 326                            Ye West                                 TikTok
# 207                           Jay Chou                                 WeChat
# 34                                 AJR                                YouTube
#
#     What is your favorite game to play (either video game or IRL)?  \
# 463                                      Clash Royale
# 462                                               Risk
# 448                                               PUBG
# 140                                     Genshin Impact
# 258                                      Papers,please
# ..                                                 ...
# 246                                           Monopoly
# 224                                             Tennis
# 326                                          Minecraft
# 207                                                LOL
# 34                                                 uno
#
#     Where is your dream vacation spot?
# 463                            Greece
# 462                             Greece
# 448                              Korea
# 140                         Strasbourg
# 258                      the Himalayas
# ..                                 ...
# 246                              Italy
# 224                            Croatia
# 326                              Italy
# 207                           Maldives
# 34                               Spain
#
# [148 rows x 133 columns]

# %% [markdown]
# ## Part 3.2:
#
# Create a `df1_control` group that contains the other half of the rows from `df1`. *(You can refer back to Part 2 to refresh on how to do this, make sure you use `df1` and `df1_control` as your DataFrames.)*

# %%
df1_control = df1[ ~df1.index.isin(df1_treatment.index) ]
df1_control
# Out:
#            Name Section Do you like sweet or savory food?  \
# 3         Keiji     Y13                             Sweet
# 7     CA Alyssa     Y07                             Sweet
# 19       Priyal     Y10                            Savory
# 28       Esther     Y01                            Savory
# 32   CA Jackson       Y                            Savory
# ..          ...     ...                               ...
# 562      Shreni     Y14                            Savory
# 563        Brad     Y19                            Savory
# 564       Charu     Y10                            Savory
# 565      Vishal     Y18                            Savory
# 567     Neal Wu     Y19                             Sweet
#
#     Do you use Windows or Mac?  \
# 3                      Windows
# 7                          Mac
# 19                     Windows
# 28                         Mac
# 32                         Mac
# ..                         ...
# 562                        Mac
# 563                    Windows
# 564                    Windows
# 565                    Windows
# 567                    Windows
#
#     Do you like doing your homework when it's released or in the end?  \
# 3                                   When it's released
# 7                                         Near the end
# 19                                        Near the end
# 28                                        Near the end
# 32                                  When it's released
# ..                                                 ...
# 562                                       Near the end
# 563                                 When it's released
# 564                                       Near the end
# 565                                       Near the end
# 567                                 When it's released
#
#     Are you a morning person?  \
# 3              Morning Person
# 7              Morning Person
# 19       NOT a Morning Person
# 28       NOT a Morning Person
# 32             Morning Person
# ..                        ...
# 562      NOT a Morning Person
# 563      NOT a Morning Person
# 564            Morning Person
# 565            Morning Person
# 567      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 3                                                  Yes
# 7                                                  Yes
# 19                                                  No
# 28                                                  No
# 32                                                 Yes
# ..                                                 ...
# 562                                                Yes
# 563                                                 No
# 564                                                 No
# 565                                                 No
# 567                                                Yes
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 3                 Dairy                                     In-State
# 7             Non-dairy                                     In-State
# 19                Dairy                                 Out-of-State
# 28                Dairy                                 Out-of-State
# 32                Dairy                                     In-State
# ..                  ...                                          ...
# 562               Dairy                                     In-State
# 563               Dairy                                 Out-of-State
# 564               Dairy                                 Out-of-State
# 565               Dairy                                     In-State
# 567               Dairy                                     In-State
#
#     Have you watched Saltburn?  ...  \
# 3                           No  ...
# 7                          Yes  ...
# 19                          No  ...
# 28                         Yes  ...
# 32                          No  ...
# ..                         ...  ...
# 562                         No  ...
# 563                         No  ...
# 564                         No  ...
# 565                        Yes  ...
# 567                        Yes  ...
#
#     Besides the US, what country would you like to live in?  \
# 3                                                japan
# 7                                              england
# 19                                              France
# 28                                               Korea
# 32                                             Nowhere
# ..                                                 ...
# 562                                             France
# 563                                              Italy
# 564                                              India
# 565                                        Switzerland
# 567                                              China
#
#     Favorite on campus restaurant?   \
# 3                              yogi
# 7                      bangkok thai
# 19                             Naya
# 28                             Yogi
# 32                   Dee Dee's Beef
# ..                              ...
# 562                        Chipotle
# 563                        chipotle
# 564                         Destihl
# 565                        Chopstix
# 567                             老四川
#
#             Favorite place to study on campus?  \
# 3                                         main
# 7                                 main library
# 19                                     My room
# 28   Sidney Lu Mechanical Engineering Building
# 32                                My apartment
# ..                                         ...
# 562                                        Cif
# 563                               My apartment
# 564                               Funk Library
# 565                                        CIF
# 567                                       home
#
#     What genre of music do you like the most?  \
# 3                                         rap
# 7                                         pop
# 19                                Dance music
# 28                                        Pop
# 32                                      Metal
# ..                                        ...
# 562                                       pop
# 563                                   hip hop
# 564                                       Pop
# 565                                       R&B
# 567                                       pop
#
#     What is your favorite school subject?  \
# 3                                    math
# 7                              statistics
# 19                               Accounts
# 28                                 Design
# 32                       Computer Science
# ..                                    ...
# 562                                    CS
# 563                               history
# 564                               History
# 565                                  math
# 567                                  clcv
#
#     What do you think is the hardest major at UIUC?  \
# 3                                          pre med
# 7                                               ece
# 19                                               CS
# 28                                               Cs
# 32                                          Physics
# ..                                              ...
# 562                                              CS
# 563                          electrical engineering
# 564                                            Math
# 565                                        CS+Stats
# 567                                        business
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 3                          post malone                                  insta
# 7                        one direction                                twitter
# 19                        Taylor Swift                              Instagram
# 28                         Tate McRae                               Instagram
# 32                          Tim Henson                                 Reddit
# ..                                 ...                                    ...
# 562                         The Weeknd                                Tik tok
# 563                          21 savage                              instagram
# 564                              Liszt                                 Reddit
# 565                         Tory Lanez                                Twitter
# 567                                 jb                                 WeChat
#
#     What is your favorite game to play (either video game or IRL)?  \
# 3                                      clash of clans
# 7                                       stardew valley
# 19                                                 GTA
# 28                                         Candy crush
# 32                                               Poker
# ..                                                 ...
# 562                                                NaN
# 563                                    nba2k or madden
# 564                                            Cricket
# 565                                           Fortnite
# 567                                               王者荣耀
#
#     Where is your dream vacation spot?
# 3                               greece
# 7                                japan
# 19                               Paris
# 28                               Japan
# 32                          Antarctica
# ..                                 ...
# 562                           Maldives
# 563                             Hawaii
# 564                            Siberia
# 565                               Bali
# 567                            Chengdu
#
# [147 rows x 133 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df1_treatment' in vars() ), "You do not have a DataFrame called `df1_treatment`."
assert( 'df1_control' in vars() ), "You do not have a DataFrame called `df1_control`."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df1_control.index) ]) == 0), "The `df1_treatment` and `df1_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_treatment.index) & df.index.isin(df2.index) ]) == 0), "The `df1_treatment` and `df2` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df1_control.index) & df.index.isin(df2.index) ]) == 0), "The `df1_control` and `df2` groups have some overlap!  There must be no overlap."

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.3:
#
# Create a `df2_treatment` group that contains a random selection of 50% of the rows from `df2`.

# %%
df2_treatment = df2.sample(frac = 0.50)
df2_treatment
# Out:
#          Name Section Do you like sweet or savory food?  \
# 247   Haojie      Y19                            Savory
# 311       Ean     Y04                            Savory
# 436    Ioanna     Y08                             Sweet
# 195     Jason     Y05                            Savory
# 532    Olesya     Y07                            Savory
# ..        ...     ...                               ...
# 235   Giselle     Y06                            Savory
# 493  Mohammed     Y12                             Sweet
# 103     Leela     Y11                             Sweet
# 315     Simon     Y17                            Savory
# 328   Hanning     Y03                            Savory
#
#     Do you use Windows or Mac?  \
# 247                        Mac
# 311                    Windows
# 436                        Mac
# 195                    Windows
# 532                        Mac
# ..                         ...
# 235                        Mac
# 493                        Mac
# 103                        Mac
# 315                        Mac
# 328                        Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 247                                 When it's released
# 311                                 When it's released
# 436                                       Near the end
# 195                                       Near the end
# 532                                       Near the end
# ..                                                 ...
# 235                                       Near the end
# 493                                       Near the end
# 103                                 When it's released
# 315                                       Near the end
# 328                                       Near the end
#
#     Are you a morning person?  \
# 247            Morning Person
# 311            Morning Person
# 436      NOT a Morning Person
# 195      NOT a Morning Person
# 532      NOT a Morning Person
# ..                        ...
# 235      NOT a Morning Person
# 493      NOT a Morning Person
# 103            Morning Person
# 315            Morning Person
# 328      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 247                                                Yes
# 311                                                 No
# 436                                                 No
# 195                                                 No
# 532                                                 No
# ..                                                 ...
# 235                                                 No
# 493                                                 No
# 103                                                 No
# 315                                                 No
# 328                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 247           Non-dairy                                 Out-of-State
# 311               Dairy                                     In-State
# 436               Dairy                                     In-State
# 195               Dairy                                     In-State
# 532               Dairy                                     In-State
# ..                  ...                                          ...
# 235           Non-dairy                                 Out-of-State
# 493               Dairy                                     In-State
# 103               Dairy                                     In-State
# 315               Dairy                                     In-State
# 328               Dairy                                 Out-of-State
#
#     Have you watched Saltburn?  ...  \
# 247                         No  ...
# 311                        Yes  ...
# 436                         No  ...
# 195                         No  ...
# 532                        Yes  ...
# ..                         ...  ...
# 235                        Yes  ...
# 493                         No  ...
# 103                        Yes  ...
# 315                         No  ...
# 328                         No  ...
#
#     Besides the US, what country would you like to live in?  \
# 247                                              China
# 311                                             Europe
# 436                                        New Zealand
# 195                                             Canada
# 532                                              Spain
# ..                                                 ...
# 235                                              Japan
# 493                                                UAE
# 103                                              Spain
# 315                                             Europe
# 328                                             France
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 247                              No                       Main library
# 311                           Canes                                CIF
# 436                  Shawarma Joint                            The Hub
# 195                    Bangkok Thai                   JSM study lounge
# 532                        Chopstix                                BIF
# ..                              ...                                ...
# 235                 Norther cuisine                       Main library
# 493                  Shawarma Joint                            My dorm
# 103                       Taco Bell                                CIF
# 315                        Mia Za's                       Aces Library
# 328                    Lao Szechuan                   Grainger Library
#
#     What genre of music do you like the most?  \
# 247                                       Pop
# 311                                       Rap
# 436                                      Jazz
# 195                                       Rap
# 532                                   pop/rap
# ..                                        ...
# 235                                    Hippop
# 493                                       Rap
# 103                                       Pop
# 315                           Underground Rap
# 328                                       Pop
#
#     What is your favorite school subject?  \
# 247                           Psychology
# 311                              Business
# 436                        Social Studies
# 195                                  Math
# 532                               Science
# ..                                    ...
# 235                                   NaN
# 493                               History
# 103                                  Math
# 315              History / Social Science
# 328                            Philosophy
#
#     What do you think is the hardest major at UIUC?  \
# 247                                     Psychology
# 311                                Computer Science
# 436                            Computer Engineering
# 195                                             ECE
# 532                                     engineering
# ..                                              ...
# 235                                              CS
# 493                                Computer Science
# 103                                Computer Science
# 315                                     Engineering
# 328                                              CS
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 247                                Nct                        Little red book
# 311                          Radiohead                                Twitter
# 436                                 IU                              Instagram
# 195                           Not sure                                Youtube
# 532                          21 Savage                                Tik tok
# ..                                 ...                                    ...
# 235                       Lil Uzi vert                                 Wechat
# 493                          21 Savage                                 Tiktok
# 103                         Noah Kahan                                 TikTok
# 315                         Young Thug                              Instagram
# 328                         John Mayer                              Instagram
#
#     What is your favorite game to play (either video game or IRL)?  \
# 247                                              Timer
# 311                                           NBA 2k21
# 436                                    Legend of Zelda
# 195                                      Hollow Knight
# 532                                         Just Dance
# ..                                                 ...
# 235                                    Resident evil 7
# 493                                       Call Of Duty
# 103                                          Codenames
# 315                                     Lego Star Wars
# 328                                         Mario kart
#
#     Where is your dream vacation spot?
# 247                              Miami
# 311                            Jamaica
# 436                             Hawaii
# 195                              Japan
# 532                             Hawaii
# ..                                 ...
# 235                              Italy
# 493                             Monaco
# 103                            Bahamas
# 315                         Costa Rica
# 328                           Provence
#
# [138 rows x 133 columns]

# %% [markdown]
# ## Part 3.4:
#
# Create a `df2_control` group that contains the other half of the rows from `df2`.

# %%
df2_control = df2[ ~df2.index.isin(df2_treatment.index) ]
df2_control
# Out:
#            Name   Section Do you like sweet or savory food?  \
# 2       Raymond       Y17                            Savory
# 5     CA Sophia       Y02                            Savory
# 6           Max       Y02                            Savory
# 9         Elise       Y03                             Sweet
# 10        Chris       Y06                            Savory
# ..          ...       ...                               ...
# 550       Arjun       Y07                            Savory
# 552        Ryan       Y02                            Savory
# 553        Marc       Y15                            Savory
# 570  CA Jessica  Y05, Y18                             Sweet
# 571      CA Xin       Y!!                             Sweet
#
#     Do you use Windows or Mac?  \
# 2                      Windows
# 5                          Mac
# 6                      Windows
# 9                          Mac
# 10                     Windows
# ..                         ...
# 550                    Windows
# 552                    Windows
# 553                    Windows
# 570                        Mac
# 571                        Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 2                                   When it's released
# 5                                   When it's released
# 6                                         Near the end
# 9                                         Near the end
# 10                                  When it's released
# ..                                                 ...
# 550                                       Near the end
# 552                                 When it's released
# 553                                       Near the end
# 570                                 When it's released
# 571                                       Near the end
#
#     Are you a morning person?  \
# 2              Morning Person
# 5              Morning Person
# 6        NOT a Morning Person
# 9        NOT a Morning Person
# 10             Morning Person
# ..                        ...
# 550      NOT a Morning Person
# 552      NOT a Morning Person
# 553      NOT a Morning Person
# 570      NOT a Morning Person
# 571            Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 2                                                   No
# 5                                                  Yes
# 6                                                  Yes
# 9                                                  Yes
# 10                                                  No
# ..                                                 ...
# 550                                                 No
# 552                                                Yes
# 553                                                 No
# 570                                                Yes
# 571                                                Yes
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 2                 Dairy                                     In-State
# 5             Non-dairy                                     In-State
# 6                 Dairy                                 Out-of-State
# 9             Non-dairy                                          NaN
# 10            Non-dairy                                     In-State
# ..                  ...                                          ...
# 550               Dairy                                     In-State
# 552               Dairy                                     In-State
# 553               Dairy                                     In-State
# 570               Dairy                                 Out-of-State
# 571           Non-dairy                                 Out-of-State
#
#     Have you watched Saltburn?  ...  \
# 2                           No  ...
# 5                          Yes  ...
# 6                           No  ...
# 9                          Yes  ...
# 10                          No  ...
# ..                         ...  ...
# 550                         No  ...
# 552                        Yes  ...
# 553                         No  ...
# 570                         No  ...
# 571                         No  ...
#
#     Besides the US, what country would you like to live in?  \
# 2                                                China
# 5                                               Greece
# 6                                                China
# 9                                                  NaN
# 10                                               Italy
# ..                                                 ...
# 550                                               Fiji
# 552                                             Mexico
# 553                                             norway
# 570                                        Switzerland
# 571                                              China
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 2                       Kung Fu BBQ                               Home
# 5                       thai fusion                                CIF
# 6                          Chipotle                               Home
# 9                               NaN                                NaN
# 10               Spoonhouse kitchen                               Eceb
# ..                              ...                                ...
# 550                            Za's                               Dorm
# 552                        Chipotle                             My bed
# 553             Haven’t been to any                            My dorm
# 570                    Bangkok Thai                       My apartment
# 571               Mid Summer Lounge                          Cafe Bene
#
#     What genre of music do you like the most?  \
# 2                                         RnB
# 5                                   pop/indie
# 6                                         Pop
# 9                                         NaN
# 10                                   Alt-Rock
# ..                                        ...
# 550                                       Rap
# 552                                     House
# 553                                       Rap
# 570                                 Indie Pop
# 571                                 classical
#
#     What is your favorite school subject?  \
# 2                                 History
# 5                                    Math
# 6                                   Stats
# 9                                     NaN
# 10                                Physics
# ..                                    ...
# 550                               History
# 552                                  Accy
# 553                                  Math
# 570                               Science
# 571                               Chinese
#
#     What do you think is the hardest major at UIUC?  \
# 2                                               ECE
# 5                                              ECE
# 6                                           Physics
# 9                                               NaN
# 10                            Computer Engineering
# ..                                              ...
# 550                            Computer Engineering
# 552                                Computer Science
# 553                                             CS?
# 570                            Computer Engineering
# 571                                             ECE
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 2                          Alan Walker                              Instagram
# 5                      Phoebe Bridgers                              Instagram
# 6                             Coldplay                                WeChat
# 9                         taylor swift                              pinterest
# 10                                Muse                                  Venmo
# ..                                 ...                                    ...
# 550                              Lorde                                 TikTok
# 552                             Fisher                                Tik tok
# 553                                JID                                 Tiktok
# 570                        Post Malone                              Instagram
# 571                          Faye Wong                                 wechat
#
#     What is your favorite game to play (either video game or IRL)?  \
# 2                                            Minecraft
# 5                                             Fortnite
# 6                                          Hearthstone
# 9                                                  NaN
# 10                                         Gang beasts
# ..                                                 ...
# 550                                         Basketball
# 552                                               Chel
# 553                                        Valorant rn
# 570                                           Splendor
# 571                                               none
#
#     Where is your dream vacation spot?
# 2                                China
# 5                               Greece
# 6                             Maldives
# 9                                  NaN
# 10                                Mars
# ..                                 ...
# 550                              Paris
# 552                          Bora Bora
# 553                Traveling the world
# 570                        Switzerland
# 571                            Iceland
#
# [139 rows x 133 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( 'df2_treatment' in vars() ), "You do not have a DataFrame called `df2_treatment`."
assert( 'df2_control' in vars() ), "You do not have a DataFrame called `df2_control`."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df2_control.index) ]) == 0), "The `df2_treatment` and `df2_control` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_treatment.index) & df.index.isin(df1.index) ]) == 0), "The `df2_treatment` and `df1` groups have some overlap!  There must be no overlap."
assert( len(df[ df.index.isin(df2_control.index) & df.index.isin(df1.index) ]) == 0), "The `df2_control` and `df1` groups have some overlap!  There must be no overlap."


## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Part 3.5:
#
# Finally, read the guide: **Combining DataFrames by Concatenation** (https://discovery.cs.illinois.edu/guides/Combining-DataFrames/Combining-DataFrames-by-Concatenation/) to learn how to combine `df1_treatment` and `df2_treatment` together into one group called `treatment`.
#
# FYI, you will not need to reset the index here!

# %%
treatment = pd.concat([df1_treatment, df2_treatment])
treatment
# Out:
#          Name Section Do you like sweet or savory food?  \
# 463    Aanya      Y05                            Savory
# 462     Isaac     Y12                             Sweet
# 448    Jennie     Y16                            Savory
# 140    Yongbo     Y03                            Savory
# 258    Runduo     Y01                             Sweet
# ..        ...     ...                               ...
# 235   Giselle     Y06                            Savory
# 493  Mohammed     Y12                             Sweet
# 103     Leela     Y11                             Sweet
# 315     Simon     Y17                            Savory
# 328   Hanning     Y03                            Savory
#
#     Do you use Windows or Mac?  \
# 463                    Windows
# 462                    Windows
# 448                        Mac
# 140                    Windows
# 258                        Mac
# ..                         ...
# 235                        Mac
# 493                        Mac
# 103                        Mac
# 315                        Mac
# 328                        Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 463                                       Near the end
# 462                                       Near the end
# 448                                 When it's released
# 140                                 When it's released
# 258                                 When it's released
# ..                                                 ...
# 235                                       Near the end
# 493                                       Near the end
# 103                                 When it's released
# 315                                       Near the end
# 328                                       Near the end
#
#     Are you a morning person?  \
# 463            Morning Person
# 462      NOT a Morning Person
# 448      NOT a Morning Person
# 140            Morning Person
# 258      NOT a Morning Person
# ..                        ...
# 235      NOT a Morning Person
# 493      NOT a Morning Person
# 103            Morning Person
# 315            Morning Person
# 328      NOT a Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 463                                                Yes
# 462                                                 No
# 448                                                 No
# 140                                                 No
# 258                                                 No
# ..                                                 ...
# 235                                                 No
# 493                                                 No
# 103                                                 No
# 315                                                 No
# 328                                                 No
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 463           Non-dairy                                     In-State
# 462               Dairy                                     In-State
# 448           Non-dairy                                 Out-of-State
# 140               Dairy                                 Out-of-State
# 258           Non-dairy                                 Out-of-State
# ..                  ...                                          ...
# 235           Non-dairy                                 Out-of-State
# 493               Dairy                                     In-State
# 103               Dairy                                     In-State
# 315               Dairy                                     In-State
# 328               Dairy                                 Out-of-State
#
#     Have you watched Saltburn?  ...  \
# 463                         No  ...
# 462                         No  ...
# 448                         No  ...
# 140                         No  ...
# 258                         No  ...
# ..                         ...  ...
# 235                        Yes  ...
# 493                         No  ...
# 103                        Yes  ...
# 315                         No  ...
# 328                         No  ...
#
#     Besides the US, what country would you like to live in?  \
# 463                                            Canada
# 462                                            Austria
# 448                                           Vietnam
# 140                                        New Zealand
# 258                                              dutch
# ..                                                 ...
# 235                                              Japan
# 493                                                UAE
# 103                                              Spain
# 315                                             Europe
# 328                                             France
#
#     Favorite on campus restaurant?  Favorite place to study on campus?  \
# 463                   Nando Milano                      Caffe Paradiso
# 462                         Cracked                   Grainger Library
# 448                     Pho station                                CIF
# 140                   Lao Sze Chuan                        In the dorm
# 258                   raising canes                         gg library
# ..                              ...                                ...
# 235                 Norther cuisine                       Main library
# 493                  Shawarma Joint                            My dorm
# 103                       Taco Bell                                CIF
# 315                        Mia Za's                       Aces Library
# 328                    Lao Szechuan                   Grainger Library
#
#     What genre of music do you like the most?  \
# 463                                  Hip-hop
# 462                                      Jazz
# 448                                       Pop
# 140                     New Music (ニューミュージック)
# 258                                       pop
# ..                                        ...
# 235                                    Hippop
# 493                                       Rap
# 103                                       Pop
# 315                           Underground Rap
# 328                                       Pop
#
#     What is your favorite school subject?  \
# 463                         Data Science
# 462                                  Math
# 448                                  Math
# 140                              STAT 107
# 258                                  math
# ..                                    ...
# 235                                   NaN
# 493                               History
# 103                                  Math
# 315              History / Social Science
# 328                            Philosophy
#
#     What do you think is the hardest major at UIUC?  \
# 463                                    Engineering
# 462                                             Law
# 448                                              CS
# 140                                     Mathematics
# 258                                              cs
# ..                                              ...
# 235                                              CS
# 493                                Computer Science
# 103                                Computer Science
# 315                                     Engineering
# 328                                              CS
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 463                        Kanye West                               Instagram
# 462                           Coldplay                              Instagram
# 448                           Jungkook                              Instagram
# 140                   Nakashima Miyuki                                 WeChat
# 258                       Taylor Swift                                    ins
# ..                                 ...                                    ...
# 235                       Lil Uzi vert                                 Wechat
# 493                          21 Savage                                 Tiktok
# 103                         Noah Kahan                                 TikTok
# 315                         Young Thug                              Instagram
# 328                         John Mayer                              Instagram
#
#     What is your favorite game to play (either video game or IRL)?  \
# 463                                      Clash Royale
# 462                                               Risk
# 448                                               PUBG
# 140                                     Genshin Impact
# 258                                      Papers,please
# ..                                                 ...
# 235                                    Resident evil 7
# 493                                       Call Of Duty
# 103                                          Codenames
# 315                                     Lego Star Wars
# 328                                         Mario kart
#
#     Where is your dream vacation spot?
# 463                            Greece
# 462                             Greece
# 448                              Korea
# 140                         Strasbourg
# 258                      the Himalayas
# ..                                 ...
# 235                              Italy
# 493                             Monaco
# 103                            Bahamas
# 315                         Costa Rica
# 328                           Provence
#
# [286 rows x 133 columns]

# %% [markdown]
# ## Part 3.6:
#
# Using the same technique, combine `df1_control` and `df2_control` together into one group called `control`:

# %%
control = pd.concat([df1_control, df2_control])
control
# Out:
#            Name   Section Do you like sweet or savory food?  \
# 3         Keiji       Y13                             Sweet
# 7     CA Alyssa       Y07                             Sweet
# 19       Priyal       Y10                            Savory
# 28       Esther       Y01                            Savory
# 32   CA Jackson         Y                            Savory
# ..          ...       ...                               ...
# 550       Arjun       Y07                            Savory
# 552        Ryan       Y02                            Savory
# 553        Marc       Y15                            Savory
# 570  CA Jessica  Y05, Y18                             Sweet
# 571      CA Xin       Y!!                             Sweet
#
#     Do you use Windows or Mac?  \
# 3                      Windows
# 7                          Mac
# 19                     Windows
# 28                         Mac
# 32                         Mac
# ..                         ...
# 550                    Windows
# 552                    Windows
# 553                    Windows
# 570                        Mac
# 571                        Mac
#
#     Do you like doing your homework when it's released or in the end?  \
# 3                                   When it's released
# 7                                         Near the end
# 19                                        Near the end
# 28                                        Near the end
# 32                                  When it's released
# ..                                                 ...
# 550                                       Near the end
# 552                                 When it's released
# 553                                       Near the end
# 570                                 When it's released
# 571                                       Near the end
#
#     Are you a morning person?  \
# 3              Morning Person
# 7              Morning Person
# 19       NOT a Morning Person
# 28       NOT a Morning Person
# 32             Morning Person
# ..                        ...
# 550      NOT a Morning Person
# 552      NOT a Morning Person
# 553      NOT a Morning Person
# 570      NOT a Morning Person
# 571            Morning Person
#
#     Are you following the data science duo on Instagram? @datascienceduo  \
# 3                                                  Yes
# 7                                                  Yes
# 19                                                  No
# 28                                                  No
# 32                                                 Yes
# ..                                                 ...
# 550                                                 No
# 552                                                Yes
# 553                                                 No
# 570                                                Yes
# 571                                                Yes
#
#     Dairy or non-dairy? Are you an In-State or Out-of-State student?  \
# 3                 Dairy                                     In-State
# 7             Non-dairy                                     In-State
# 19                Dairy                                 Out-of-State
# 28                Dairy                                 Out-of-State
# 32                Dairy                                     In-State
# ..                  ...                                          ...
# 550               Dairy                                     In-State
# 552               Dairy                                     In-State
# 553               Dairy                                     In-State
# 570               Dairy                                 Out-of-State
# 571           Non-dairy                                 Out-of-State
#
#     Have you watched Saltburn?  ...  \
# 3                           No  ...
# 7                          Yes  ...
# 19                          No  ...
# 28                         Yes  ...
# 32                          No  ...
# ..                         ...  ...
# 550                         No  ...
# 552                        Yes  ...
# 553                         No  ...
# 570                         No  ...
# 571                         No  ...
#
#     Besides the US, what country would you like to live in?  \
# 3                                                japan
# 7                                              england
# 19                                              France
# 28                                               Korea
# 32                                             Nowhere
# ..                                                 ...
# 550                                               Fiji
# 552                                             Mexico
# 553                                             norway
# 570                                        Switzerland
# 571                                              China
#
#     Favorite on campus restaurant?   \
# 3                              yogi
# 7                      bangkok thai
# 19                             Naya
# 28                             Yogi
# 32                   Dee Dee's Beef
# ..                              ...
# 550                            Za's
# 552                        Chipotle
# 553             Haven’t been to any
# 570                    Bangkok Thai
# 571               Mid Summer Lounge
#
#             Favorite place to study on campus?  \
# 3                                         main
# 7                                 main library
# 19                                     My room
# 28   Sidney Lu Mechanical Engineering Building
# 32                                My apartment
# ..                                         ...
# 550                                       Dorm
# 552                                     My bed
# 553                                    My dorm
# 570                               My apartment
# 571                                  Cafe Bene
#
#     What genre of music do you like the most?  \
# 3                                         rap
# 7                                         pop
# 19                                Dance music
# 28                                        Pop
# 32                                      Metal
# ..                                        ...
# 550                                       Rap
# 552                                     House
# 553                                       Rap
# 570                                 Indie Pop
# 571                                 classical
#
#     What is your favorite school subject?  \
# 3                                    math
# 7                              statistics
# 19                               Accounts
# 28                                 Design
# 32                       Computer Science
# ..                                    ...
# 550                               History
# 552                                  Accy
# 553                                  Math
# 570                               Science
# 571                               Chinese
#
#     What do you think is the hardest major at UIUC?  \
# 3                                          pre med
# 7                                               ece
# 19                                               CS
# 28                                               Cs
# 32                                          Physics
# ..                                              ...
# 550                            Computer Engineering
# 552                                Computer Science
# 553                                             CS?
# 570                            Computer Engineering
# 571                                             ECE
#
#     Who is your favorite music artist? What's your favorite social media app?  \
# 3                          post malone                                  insta
# 7                        one direction                                twitter
# 19                        Taylor Swift                              Instagram
# 28                         Tate McRae                               Instagram
# 32                          Tim Henson                                 Reddit
# ..                                 ...                                    ...
# 550                              Lorde                                 TikTok
# 552                             Fisher                                Tik tok
# 553                                JID                                 Tiktok
# 570                        Post Malone                              Instagram
# 571                          Faye Wong                                 wechat
#
#     What is your favorite game to play (either video game or IRL)?  \
# 3                                      clash of clans
# 7                                       stardew valley
# 19                                                 GTA
# 28                                         Candy crush
# 32                                               Poker
# ..                                                 ...
# 550                                         Basketball
# 552                                               Chel
# 553                                        Valorant rn
# 570                                           Splendor
# 571                                               none
#
#     Where is your dream vacation spot?
# 3                               greece
# 7                                japan
# 19                               Paris
# 28                               Japan
# 32                          Antarctica
# ..                                 ...
# 550                              Paris
# 552                          Bora Bora
# 553                Traveling the world
# 570                        Switzerland
# 571                            Iceland
#
# [286 rows x 133 columns]

# %% [markdown]
# ### 🔬 Test Case Checkpoint 🔬

# %%
## == CHECKPOINT TEST CASES ==
# - This read-only cell contains test cases for your previous cell.
# - If this cell runs without any errors in your output, you PASSED all test cases!
# - If this cell results in any errors, check your previous cell, make changes, and RE-RUN your code and then this cell.
assert( len(df[ df.index.isin(treatment.index) & df.index.isin(control.index) ]) == 0), "The `treatment` and `control` groups have some overlap!  There must be no overlap."
assert(
  (len(treatment) + len(control) == len(df1) + len(df2)) or 
  (len(treatment) + len(control) == len(df))
), f"Not everyone in the dataset (or everyone who responded to the question being blocked) is included in one of the two groups -- someone is missing! :(\nPeople in treatment group: {len(treatment)}\nPeople in control group: {len(control)}\nTotal in treatment+control group: {len(control) + len(treatment)}\n== vs ==\nTotal people in dataset: {len(df)}\nTotal people with data for blocking: {len(df1) + len(df2)}"

## == SUCCESS MESSAGE ==
# You will only see this message (with the emoji showing) if you passed all test cases:
tada = "\N{PARTY POPPER}"
print(f"{tada} All tests passed! {tada}")
# Out:
# 🎉 All tests passed! 🎉

# %% [markdown]
# ## Analysis: Blocking

# %% [markdown]
# **Q6: In your own words, explain what blocking is and why it is useful to someone who has never taken a statistics course before! You can use what you did above as an example in your explanation if you'd like. Make sure to include what blocking is and why it is useful. Write at least three complete sentences to answer this question.**

# %% [markdown]
# Blocking allows for researchers to make sall groups that are relativetly homogenous and then they decide who is in the treatment and who is not. it is useful especially when a sample size is small or is a variable might influence the outcome. For example, in the code above we divided the sample of poeple who answered the question and then took that further down to split A or B into smaller groups to create d1 and d2 control and treatment.

# %% [markdown]
# <hr style="color: #DD3403;">

# %% [markdown]
# # Submission
#
# You're almost done!  All you need to do is to commit your lab to GitHub:
#
# 1.  ⚠️ **Make certain to save your work.** ⚠️ To do this, go to **File => Save All**
#
# 2.  After you have saved, exit this notebook and follow the Canvas instructions to commit this lab to your Git repository!
#
# 3. Your TA will grade your submission and provide you feedback after the lab is due. :)
